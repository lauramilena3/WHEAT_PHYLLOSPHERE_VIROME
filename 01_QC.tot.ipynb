# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpemm958qd/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95h\x00\x01\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNW_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNWd_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_T_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSE_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSEd_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSW_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSWd_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_T_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNW_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNWd_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_T_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSE_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSEd_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSW_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSWd_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_T_R2_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_merged_unpaired.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_merged_unpaired.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_unpaired_noEuk.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_unpaired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_unpaired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_unpaired_clean.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_unpaired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_unpaired_norm.tot_read_count.txt\x94\x95\x19\x00\x01\x00\x00\x00\x00\x00\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_unpaired_norm.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_unpaired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_unpaired_norm.tot_read_count.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_kmer_histogram.tot.csv\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_kmer_histogram.tot.csv\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_kmer_histogram.tot.csv\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/preQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/postQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNW_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNWd_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3A_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_T_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2C_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3B_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3C_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSE_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSEd_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSW_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSWd_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_T_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_R1_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_T_R1_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bF3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bFL_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN1_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN2_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bN3_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNW_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bNWd_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3A_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bO3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bOL_T_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS1C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS2C_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3B_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bS3C_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSE_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSEd_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSW_R2_read_count.txt\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bSWd_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ1_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ2_T_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_R2_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA/bZ3_T_R2_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_clean.tot_read_count.txt\x94e(\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_clean.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_clean.tot_read_count.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_forward_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_forward_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_reverse_paired_norm.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_reverse_paired_norm.tot_read_count.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF1A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF1B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF1C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF2A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF2B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF2C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF3A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF3B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bF3C_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bFL_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bFL_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN1_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN1_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN2_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN2_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN3_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bN3_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bNW_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bNWd_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO1A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO1B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO1C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO2A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO2B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO2C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO3A_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO3B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bO3C_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bOL_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bOL_T_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS1B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS1C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS2B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS2C_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS3B_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bS3C_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bSE_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bSEd_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bSW_stats_pcr_duplicates.log\x94\x8cV/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bSWd_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ1_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ1_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ2_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ2_T_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ3_stats_pcr_duplicates.log\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC/bZ3_T_stats_pcr_duplicates.log\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_kmer_count_histogram_pre.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_kmer_count_histogram_pre.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_kmer_count_histogram_post.tot.txt\x94\x95\xa2U\x00\x00\x00\x00\x00\x00\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_kmer_count_histogram_post.tot.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_kmer_count_histogram_post.tot.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_kmer_count_histogram_post.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF1C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF2C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bF3C_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bFL_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN1_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN2_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bN3_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNW_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bNWd_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO1C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO2C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3A_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bO3C_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bOL_T_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS1C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS2C_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3B_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bS3C_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSE_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSEd_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSW_kmer_count_peaks.tot.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bSWd_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ1_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ2_T_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_kmer_count_peaks.tot.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA/bZ3_T_kmer_count_peaks.tot.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\nhistograms\x94M\x84\x02M\xb2\x02\x86\x94\x8c\tpreqc_txt\x94M\xb2\x02N\x86\x94\x8c\npostqc_txt\x94M\xb3\x02N\x86\x94\x8c\x16read_count_raw_forward\x94M\xb4\x02M\xe2\x02\x86\x94\x8c\x16read_count_raw_reverse\x94M\xe2\x02M\x10\x03\x86\x94\x8c\x1aread_count_trimmed_forward\x94M\x10\x03M>\x03\x86\x94\x8c\x1aread_count_trimmed_reverse\x94M>\x03Ml\x03\x86\x94\x8c\x16read_count_euk_forward\x94Ml\x03M\x9a\x03\x86\x94\x8c\x16read_count_euk_reverse\x94M\x9a\x03M\xc8\x03\x86\x94\x8c\x16read_count_duk_forward\x94M\xc8\x03M\xf6\x03\x86\x94\x8c\x16read_count_duk_reverse\x94M\xf6\x03M$\x04\x86\x94\x8c\x17read_count_norm_forward\x94M$\x04MR\x04\x86\x94\x8c\x17read_count_norm_reverse\x94MR\x04M\x80\x04\x86\x94\x8c\x0csupper_dedup\x94M\x80\x04M\xae\x04\x86\x94\x8c\x12histogram_kmer_pre\x94M\xae\x04M\xdc\x04\x86\x94\x8c\x13histogram_kmer_post\x94M\xdc\x04M\n\x05\x86\x94\x8c\tpeak_kmer\x94M\n\x05M8\x05\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eji\x05\x00\x00\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(jo\x05\x00\x00)}\x94\x8c\x05_name\x94ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bjE\x05\x00\x00h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(j\x8e\x02\x00\x00j\x8f\x02\x00\x00j\x90\x02\x00\x00j\x91\x02\x00\x00j\x92\x02\x00\x00j\x93\x02\x00\x00j\x94\x02\x00\x00j\x95\x02\x00\x00j\x96\x02\x00\x00j\x97\x02\x00\x00j\x98\x02\x00\x00j\x99\x02\x00\x00j\x9a\x02\x00\x00j\x9b\x02\x00\x00j\x9c\x02\x00\x00j\x9d\x02\x00\x00j\x9e\x02\x00\x00j\x9f\x02\x00\x00j\xa0\x02\x00\x00j\xa1\x02\x00\x00j\xa2\x02\x00\x00j\xa3\x02\x00\x00j\xa4\x02\x00\x00j\xa5\x02\x00\x00j\xa6\x02\x00\x00j\xa7\x02\x00\x00j\xa8\x02\x00\x00j\xa9\x02\x00\x00j\xaa\x02\x00\x00j\xab\x02\x00\x00j\xac\x02\x00\x00j\xad\x02\x00\x00j\xae\x02\x00\x00j\xaf\x02\x00\x00j\xb0\x02\x00\x00j\xb1\x02\x00\x00j\xb2\x02\x00\x00j\xb3\x02\x00\x00j\xb4\x02\x00\x00j\xb5\x02\x00\x00j\xb6\x02\x00\x00j\xb7\x02\x00\x00j\xb8\x02\x00\x00j\xb9\x02\x00\x00j\xba\x02\x00\x00j\xbb\x02\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjG\x05\x00\x00j\xbc\x02\x00\x00jI\x05\x00\x00j\xbd\x02\x00\x00jK\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xbe\x02\x00\x00j\xbf\x02\x00\x00j\xc0\x02\x00\x00j\xc1\x02\x00\x00j\xc2\x02\x00\x00j\xc3\x02\x00\x00j\xc4\x02\x00\x00j\xc5\x02\x00\x00j\xc6\x02\x00\x00j\xc7\x02\x00\x00j\xc8\x02\x00\x00j\xc9\x02\x00\x00j\xca\x02\x00\x00j\xcb\x02\x00\x00j\xcc\x02\x00\x00j\xcd\x02\x00\x00j\xce\x02\x00\x00j\xcf\x02\x00\x00j\xd0\x02\x00\x00j\xd1\x02\x00\x00j\xd2\x02\x00\x00j\xd3\x02\x00\x00j\xd4\x02\x00\x00j\xd5\x02\x00\x00j\xd6\x02\x00\x00j\xd7\x02\x00\x00j\xd8\x02\x00\x00j\xd9\x02\x00\x00j\xda\x02\x00\x00j\xdb\x02\x00\x00j\xdc\x02\x00\x00j\xdd\x02\x00\x00j\xde\x02\x00\x00j\xdf\x02\x00\x00j\xe0\x02\x00\x00j\xe1\x02\x00\x00j\xe2\x02\x00\x00j\xe3\x02\x00\x00j\xe4\x02\x00\x00j\xe5\x02\x00\x00j\xe6\x02\x00\x00j\xe7\x02\x00\x00j\xe8\x02\x00\x00j\xe9\x02\x00\x00j\xea\x02\x00\x00j\xeb\x02\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjM\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xec\x02\x00\x00j\xed\x02\x00\x00j\xee\x02\x00\x00j\xef\x02\x00\x00j\xf0\x02\x00\x00j\xf1\x02\x00\x00j\xf2\x02\x00\x00j\xf3\x02\x00\x00j\xf4\x02\x00\x00j\xf5\x02\x00\x00j\xf6\x02\x00\x00j\xf7\x02\x00\x00j\xf8\x02\x00\x00j\xf9\x02\x00\x00j\xfa\x02\x00\x00j\xfb\x02\x00\x00j\xfc\x02\x00\x00j\xfd\x02\x00\x00j\xfe\x02\x00\x00j\xff\x02\x00\x00j\x00\x03\x00\x00j\x01\x03\x00\x00j\x02\x03\x00\x00j\x03\x03\x00\x00j\x04\x03\x00\x00j\x05\x03\x00\x00j\x06\x03\x00\x00j\x07\x03\x00\x00j\x08\x03\x00\x00j\t\x03\x00\x00j\n\x03\x00\x00j\x0b\x03\x00\x00j\x0c\x03\x00\x00j\r\x03\x00\x00j\x0e\x03\x00\x00j\x0f\x03\x00\x00j\x10\x03\x00\x00j\x11\x03\x00\x00j\x12\x03\x00\x00j\x13\x03\x00\x00j\x14\x03\x00\x00j\x15\x03\x00\x00j\x16\x03\x00\x00j\x17\x03\x00\x00j\x18\x03\x00\x00j\x19\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjO\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\x1a\x03\x00\x00j\x1b\x03\x00\x00j\x1c\x03\x00\x00j\x1d\x03\x00\x00j\x1e\x03\x00\x00j\x1f\x03\x00\x00j \x03\x00\x00j!\x03\x00\x00j"\x03\x00\x00j#\x03\x00\x00j$\x03\x00\x00j%\x03\x00\x00j&\x03\x00\x00j\'\x03\x00\x00j(\x03\x00\x00j)\x03\x00\x00j*\x03\x00\x00j+\x03\x00\x00j,\x03\x00\x00j-\x03\x00\x00j.\x03\x00\x00j/\x03\x00\x00j0\x03\x00\x00j1\x03\x00\x00j2\x03\x00\x00j3\x03\x00\x00j4\x03\x00\x00j5\x03\x00\x00j6\x03\x00\x00j7\x03\x00\x00j8\x03\x00\x00j9\x03\x00\x00j:\x03\x00\x00j;\x03\x00\x00j<\x03\x00\x00j=\x03\x00\x00j>\x03\x00\x00j?\x03\x00\x00j@\x03\x00\x00jA\x03\x00\x00jB\x03\x00\x00jC\x03\x00\x00jD\x03\x00\x00jE\x03\x00\x00jF\x03\x00\x00jG\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjQ\x05\x00\x00jz\x05\x00\x00)\x81\x94(jH\x03\x00\x00jI\x03\x00\x00jJ\x03\x00\x00jK\x03\x00\x00jL\x03\x00\x00jM\x03\x00\x00jN\x03\x00\x00jO\x03\x00\x00jP\x03\x00\x00jQ\x03\x00\x00jR\x03\x00\x00jS\x03\x00\x00jT\x03\x00\x00jU\x03\x00\x00jV\x03\x00\x00jW\x03\x00\x00jX\x03\x00\x00jY\x03\x00\x00jZ\x03\x00\x00j[\x03\x00\x00j\\\x03\x00\x00j]\x03\x00\x00j^\x03\x00\x00j_\x03\x00\x00j`\x03\x00\x00ja\x03\x00\x00jb\x03\x00\x00jc\x03\x00\x00jd\x03\x00\x00je\x03\x00\x00jf\x03\x00\x00jg\x03\x00\x00jh\x03\x00\x00ji\x03\x00\x00jj\x03\x00\x00jk\x03\x00\x00jl\x03\x00\x00jm\x03\x00\x00jn\x03\x00\x00jo\x03\x00\x00jp\x03\x00\x00jq\x03\x00\x00jr\x03\x00\x00js\x03\x00\x00jt\x03\x00\x00ju\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjS\x05\x00\x00jz\x05\x00\x00)\x81\x94(jv\x03\x00\x00jw\x03\x00\x00jx\x03\x00\x00jy\x03\x00\x00jz\x03\x00\x00j{\x03\x00\x00j|\x03\x00\x00j}\x03\x00\x00j~\x03\x00\x00j\x7f\x03\x00\x00j\x80\x03\x00\x00j\x81\x03\x00\x00j\x82\x03\x00\x00j\x83\x03\x00\x00j\x84\x03\x00\x00j\x85\x03\x00\x00j\x86\x03\x00\x00j\x87\x03\x00\x00j\x88\x03\x00\x00j\x89\x03\x00\x00j\x8a\x03\x00\x00j\x8b\x03\x00\x00j\x8c\x03\x00\x00j\x8d\x03\x00\x00j\x8e\x03\x00\x00j\x8f\x03\x00\x00j\x90\x03\x00\x00j\x91\x03\x00\x00j\x92\x03\x00\x00j\x93\x03\x00\x00j\x94\x03\x00\x00j\x95\x03\x00\x00j\x96\x03\x00\x00j\x97\x03\x00\x00j\x98\x03\x00\x00j\x99\x03\x00\x00j\x9a\x03\x00\x00j\x9b\x03\x00\x00j\x9c\x03\x00\x00j\x9d\x03\x00\x00j\x9e\x03\x00\x00j\x9f\x03\x00\x00j\xa0\x03\x00\x00j\xa1\x03\x00\x00j\xa2\x03\x00\x00j\xa3\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjU\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xa4\x03\x00\x00j\xa5\x03\x00\x00j\xa6\x03\x00\x00j\xa7\x03\x00\x00j\xa8\x03\x00\x00j\xa9\x03\x00\x00j\xaa\x03\x00\x00j\xab\x03\x00\x00j\xac\x03\x00\x00j\xad\x03\x00\x00j\xae\x03\x00\x00j\xaf\x03\x00\x00j\xb0\x03\x00\x00j\xb1\x03\x00\x00j\xb2\x03\x00\x00j\xb3\x03\x00\x00j\xb4\x03\x00\x00j\xb5\x03\x00\x00j\xb6\x03\x00\x00j\xb7\x03\x00\x00j\xb8\x03\x00\x00j\xb9\x03\x00\x00j\xba\x03\x00\x00j\xbb\x03\x00\x00j\xbc\x03\x00\x00j\xbd\x03\x00\x00j\xbe\x03\x00\x00j\xbf\x03\x00\x00j\xc0\x03\x00\x00j\xc1\x03\x00\x00j\xc2\x03\x00\x00j\xc3\x03\x00\x00j\xc4\x03\x00\x00j\xc5\x03\x00\x00j\xc6\x03\x00\x00j\xc7\x03\x00\x00j\xc8\x03\x00\x00j\xc9\x03\x00\x00j\xca\x03\x00\x00j\xcb\x03\x00\x00j\xcc\x03\x00\x00j\xcd\x03\x00\x00j\xce\x03\x00\x00j\xcf\x03\x00\x00j\xd0\x03\x00\x00j\xd1\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjW\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xd2\x03\x00\x00j\xd3\x03\x00\x00j\xd4\x03\x00\x00j\xd5\x03\x00\x00j\xd6\x03\x00\x00j\xd7\x03\x00\x00j\xd8\x03\x00\x00j\xd9\x03\x00\x00j\xda\x03\x00\x00j\xdb\x03\x00\x00j\xdc\x03\x00\x00j\xdd\x03\x00\x00j\xde\x03\x00\x00j\xdf\x03\x00\x00j\xe0\x03\x00\x00j\xe1\x03\x00\x00j\xe2\x03\x00\x00j\xe3\x03\x00\x00j\xe4\x03\x00\x00j\xe5\x03\x00\x00j\xe6\x03\x00\x00j\xe7\x03\x00\x00j\xe8\x03\x00\x00j\xe9\x03\x00\x00j\xea\x03\x00\x00j\xeb\x03\x00\x00j\xec\x03\x00\x00j\xed\x03\x00\x00j\xee\x03\x00\x00j\xef\x03\x00\x00j\xf0\x03\x00\x00j\xf1\x03\x00\x00j\xf2\x03\x00\x00j\xf3\x03\x00\x00j\xf4\x03\x00\x00j\xf5\x03\x00\x00j\xf6\x03\x00\x00j\xf7\x03\x00\x00j\xf8\x03\x00\x00j\xf9\x03\x00\x00j\xfa\x03\x00\x00j\xfb\x03\x00\x00j\xfc\x03\x00\x00j\xfd\x03\x00\x00j\xfe\x03\x00\x00j\xff\x03\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjY\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\x00\x04\x00\x00j\x01\x04\x00\x00j\x02\x04\x00\x00j\x03\x04\x00\x00j\x04\x04\x00\x00j\x05\x04\x00\x00j\x06\x04\x00\x00j\x07\x04\x00\x00j\x08\x04\x00\x00j\t\x04\x00\x00j\n\x04\x00\x00j\x0b\x04\x00\x00j\x0c\x04\x00\x00j\r\x04\x00\x00j\x0e\x04\x00\x00j\x0f\x04\x00\x00j\x10\x04\x00\x00j\x11\x04\x00\x00j\x12\x04\x00\x00j\x13\x04\x00\x00j\x14\x04\x00\x00j\x15\x04\x00\x00j\x16\x04\x00\x00j\x17\x04\x00\x00j\x18\x04\x00\x00j\x19\x04\x00\x00j\x1a\x04\x00\x00j\x1b\x04\x00\x00j\x1c\x04\x00\x00j\x1d\x04\x00\x00j\x1e\x04\x00\x00j\x1f\x04\x00\x00j \x04\x00\x00j!\x04\x00\x00j"\x04\x00\x00j#\x04\x00\x00j$\x04\x00\x00j%\x04\x00\x00j&\x04\x00\x00j\'\x04\x00\x00j(\x04\x00\x00j)\x04\x00\x00j*\x04\x00\x00j+\x04\x00\x00j,\x04\x00\x00j-\x04\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubj[\x05\x00\x00jz\x05\x00\x00)\x81\x94(j.\x04\x00\x00j/\x04\x00\x00j0\x04\x00\x00j1\x04\x00\x00j2\x04\x00\x00j3\x04\x00\x00j4\x04\x00\x00j5\x04\x00\x00j6\x04\x00\x00j7\x04\x00\x00j8\x04\x00\x00j9\x04\x00\x00j:\x04\x00\x00j;\x04\x00\x00j<\x04\x00\x00j=\x04\x00\x00j>\x04\x00\x00j?\x04\x00\x00j@\x04\x00\x00jA\x04\x00\x00jB\x04\x00\x00jC\x04\x00\x00jD\x04\x00\x00jE\x04\x00\x00jF\x04\x00\x00jG\x04\x00\x00jH\x04\x00\x00jI\x04\x00\x00jJ\x04\x00\x00jK\x04\x00\x00jL\x04\x00\x00jM\x04\x00\x00jN\x04\x00\x00jO\x04\x00\x00jP\x04\x00\x00jQ\x04\x00\x00jR\x04\x00\x00jS\x04\x00\x00jT\x04\x00\x00jU\x04\x00\x00jV\x04\x00\x00jW\x04\x00\x00jX\x04\x00\x00jY\x04\x00\x00jZ\x04\x00\x00j[\x04\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubj]\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\\\x04\x00\x00j]\x04\x00\x00j^\x04\x00\x00j_\x04\x00\x00j`\x04\x00\x00ja\x04\x00\x00jb\x04\x00\x00jc\x04\x00\x00jd\x04\x00\x00je\x04\x00\x00jf\x04\x00\x00jg\x04\x00\x00jh\x04\x00\x00ji\x04\x00\x00jj\x04\x00\x00jk\x04\x00\x00jl\x04\x00\x00jm\x04\x00\x00jn\x04\x00\x00jo\x04\x00\x00jp\x04\x00\x00jq\x04\x00\x00jr\x04\x00\x00js\x04\x00\x00jt\x04\x00\x00ju\x04\x00\x00jv\x04\x00\x00jw\x04\x00\x00jx\x04\x00\x00jy\x04\x00\x00jz\x04\x00\x00j{\x04\x00\x00j|\x04\x00\x00j}\x04\x00\x00j~\x04\x00\x00j\x7f\x04\x00\x00j\x80\x04\x00\x00j\x81\x04\x00\x00j\x82\x04\x00\x00j\x83\x04\x00\x00j\x84\x04\x00\x00j\x85\x04\x00\x00j\x86\x04\x00\x00j\x87\x04\x00\x00j\x88\x04\x00\x00j\x89\x04\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubj_\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\x8a\x04\x00\x00j\x8b\x04\x00\x00j\x8c\x04\x00\x00j\x8d\x04\x00\x00j\x8e\x04\x00\x00j\x8f\x04\x00\x00j\x90\x04\x00\x00j\x91\x04\x00\x00j\x92\x04\x00\x00j\x93\x04\x00\x00j\x94\x04\x00\x00j\x95\x04\x00\x00j\x96\x04\x00\x00j\x97\x04\x00\x00j\x98\x04\x00\x00j\x99\x04\x00\x00j\x9a\x04\x00\x00j\x9b\x04\x00\x00j\x9c\x04\x00\x00j\x9d\x04\x00\x00j\x9e\x04\x00\x00j\x9f\x04\x00\x00j\xa0\x04\x00\x00j\xa1\x04\x00\x00j\xa2\x04\x00\x00j\xa3\x04\x00\x00j\xa4\x04\x00\x00j\xa5\x04\x00\x00j\xa6\x04\x00\x00j\xa7\x04\x00\x00j\xa8\x04\x00\x00j\xa9\x04\x00\x00j\xaa\x04\x00\x00j\xab\x04\x00\x00j\xac\x04\x00\x00j\xad\x04\x00\x00j\xae\x04\x00\x00j\xaf\x04\x00\x00j\xb0\x04\x00\x00j\xb1\x04\x00\x00j\xb2\x04\x00\x00j\xb3\x04\x00\x00j\xb4\x04\x00\x00j\xb5\x04\x00\x00j\xb6\x04\x00\x00j\xb7\x04\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubja\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xb8\x04\x00\x00j\xb9\x04\x00\x00j\xba\x04\x00\x00j\xbb\x04\x00\x00j\xbc\x04\x00\x00j\xbd\x04\x00\x00j\xbe\x04\x00\x00j\xbf\x04\x00\x00j\xc0\x04\x00\x00j\xc1\x04\x00\x00j\xc2\x04\x00\x00j\xc3\x04\x00\x00j\xc4\x04\x00\x00j\xc5\x04\x00\x00j\xc6\x04\x00\x00j\xc7\x04\x00\x00j\xc8\x04\x00\x00j\xc9\x04\x00\x00j\xca\x04\x00\x00j\xcb\x04\x00\x00j\xcc\x04\x00\x00j\xcd\x04\x00\x00j\xce\x04\x00\x00j\xcf\x04\x00\x00j\xd0\x04\x00\x00j\xd1\x04\x00\x00j\xd2\x04\x00\x00j\xd3\x04\x00\x00j\xd4\x04\x00\x00j\xd5\x04\x00\x00j\xd6\x04\x00\x00j\xd7\x04\x00\x00j\xd8\x04\x00\x00j\xd9\x04\x00\x00j\xda\x04\x00\x00j\xdb\x04\x00\x00j\xdc\x04\x00\x00j\xdd\x04\x00\x00j\xde\x04\x00\x00j\xdf\x04\x00\x00j\xe0\x04\x00\x00j\xe1\x04\x00\x00j\xe2\x04\x00\x00j\xe3\x04\x00\x00j\xe4\x04\x00\x00j\xe5\x04\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubjc\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\xe6\x04\x00\x00j\xe7\x04\x00\x00j\xe8\x04\x00\x00j\xe9\x04\x00\x00j\xea\x04\x00\x00j\xeb\x04\x00\x00j\xec\x04\x00\x00j\xed\x04\x00\x00j\xee\x04\x00\x00j\xef\x04\x00\x00j\xf0\x04\x00\x00j\xf1\x04\x00\x00j\xf2\x04\x00\x00j\xf3\x04\x00\x00j\xf4\x04\x00\x00j\xf5\x04\x00\x00j\xf6\x04\x00\x00j\xf7\x04\x00\x00j\xf8\x04\x00\x00j\xf9\x04\x00\x00j\xfa\x04\x00\x00j\xfb\x04\x00\x00j\xfc\x04\x00\x00j\xfd\x04\x00\x00j\xfe\x04\x00\x00j\xff\x04\x00\x00j\x00\x05\x00\x00j\x01\x05\x00\x00j\x02\x05\x00\x00j\x03\x05\x00\x00j\x04\x05\x00\x00j\x05\x05\x00\x00j\x06\x05\x00\x00j\x07\x05\x00\x00j\x08\x05\x00\x00j\t\x05\x00\x00j\n\x05\x00\x00j\x0b\x05\x00\x00j\x0c\x05\x00\x00j\r\x05\x00\x00j\x0e\x05\x00\x00j\x0f\x05\x00\x00j\x10\x05\x00\x00j\x11\x05\x00\x00j\x12\x05\x00\x00j\x13\x05\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubje\x05\x00\x00jz\x05\x00\x00)\x81\x94(j\x14\x05\x00\x00j\x15\x05\x00\x00j\x16\x05\x00\x00j\x17\x05\x00\x00j\x18\x05\x00\x00j\x19\x05\x00\x00j\x1a\x05\x00\x00j\x1b\x05\x00\x00j\x1c\x05\x00\x00j\x1d\x05\x00\x00j\x1e\x05\x00\x00j\x1f\x05\x00\x00j \x05\x00\x00j!\x05\x00\x00j"\x05\x00\x00j#\x05\x00\x00j$\x05\x00\x00j%\x05\x00\x00j&\x05\x00\x00j\'\x05\x00\x00j(\x05\x00\x00j)\x05\x00\x00j*\x05\x00\x00j+\x05\x00\x00j,\x05\x00\x00j-\x05\x00\x00j.\x05\x00\x00j/\x05\x00\x00j0\x05\x00\x00j1\x05\x00\x00j2\x05\x00\x00j3\x05\x00\x00j4\x05\x00\x00j5\x05\x00\x00j6\x05\x00\x00j7\x05\x00\x00j8\x05\x00\x00j9\x05\x00\x00j:\x05\x00\x00j;\x05\x00\x00j<\x05\x00\x00j=\x05\x00\x00j>\x05\x00\x00j?\x05\x00\x00j@\x05\x00\x00jA\x05\x00\x00e}\x94(jC\x05\x00\x00}\x94jg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_rarefraction_plot.tot.png\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_rarefraction_plot.tot.svg\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_rarefraction_plot_fitted.tot.png\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_rarefraction_plot_fitted.tot.svg\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_rarefraction_fitted.tot.html\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_distribution_plot_pre.tot.png\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_distribution_plot_pre.tot.svg\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_distribution_plot_post.tot.png\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_kmer_distribution_plot_post.tot.svg\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_post_qc_read_summary.tot.html\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_percentage_kept_reads.tot.png\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_percentage_kept_reads.tot.svg\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_percentage_kept_Mbp.tot.png\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_percentage_kept_Mbp.tot.svg\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_multistep_qc_report.tot.html\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_bystep_counts.tot.png\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_bystep_counts.tot.svg\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_bystep_percentage.tot.png\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_bystep_percentage.tot.svg\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_read_counts_paired.tot.csv\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.html\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.png\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_superdedupper_PCR.tot.svg\x94e}\x94(jC\x05\x00\x00}\x94(\x8c\x08kmer_png\x94K\x00N\x86\x94\x8c\x08kmer_svg\x94K\x01N\x86\x94\x8c\x0ckmer_fit_png\x94K\x02N\x86\x94\x8c\x0ckmer_fit_svg\x94K\x03N\x86\x94\x8c\rkmer_fit_html\x94K\x04N\x86\x94\x8c\x11kmer_dist_pre_png\x94K\x05N\x86\x94\x8c\x11kmer_dist_pre_svg\x94K\x06N\x86\x94\x8c\x12kmer_dist_post_png\x94K\x07N\x86\x94\x8c\x12kmer_dist_post_svg\x94K\x08N\x86\x94\x8c\x0fqc_summary_html\x94K\tN\x86\x94\x8c\x19percentage_kept_reads_png\x94K\nN\x86\x94\x8c\x19percentage_kept_reads_svg\x94K\x0bN\x86\x94\x8c\x17percentage_kept_Mbp_png\x94K\x0cN\x86\x94\x8c\x17percentage_kept_Mbp_svg\x94K\rN\x86\x94\x8c\x12step_qc_reads_html\x94K\x0eN\x86\x94\x8c\x12steps_qc_reads_png\x94K\x0fN\x86\x94\x8c\x12steps_qc_reads_svg\x94K\x10N\x86\x94\x8c\x17steps_qc_percentage_png\x94K\x11N\x86\x94\x8c\x17steps_qc_percentage_svg\x94K\x12N\x86\x94\x8c\x10df_counts_paired\x94K\x13N\x86\x94\x8c\x13supperdedupper_html\x94K\x14N\x86\x94\x8c\x12supperdedupper_png\x94K\x15N\x86\x94\x8c\x12supperdedupper_svg\x94K\x16N\x86\x94ujg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bjL\x06\x00\x00j3\x06\x00\x00jN\x06\x00\x00j4\x06\x00\x00jP\x06\x00\x00j5\x06\x00\x00jR\x06\x00\x00j6\x06\x00\x00jT\x06\x00\x00j7\x06\x00\x00jV\x06\x00\x00j8\x06\x00\x00jX\x06\x00\x00j9\x06\x00\x00jZ\x06\x00\x00j:\x06\x00\x00j\\\x06\x00\x00j;\x06\x00\x00j^\x06\x00\x00j<\x06\x00\x00j`\x06\x00\x00j=\x06\x00\x00jb\x06\x00\x00j>\x06\x00\x00jd\x06\x00\x00j?\x06\x00\x00jf\x06\x00\x00j@\x06\x00\x00jh\x06\x00\x00jA\x06\x00\x00jj\x06\x00\x00jB\x06\x00\x00jl\x06\x00\x00jC\x06\x00\x00jn\x06\x00\x00jD\x06\x00\x00jp\x06\x00\x00jE\x06\x00\x00jr\x06\x00\x00jF\x06\x00\x00jt\x06\x00\x00jG\x06\x00\x00jv\x06\x00\x00jH\x06\x00\x00jx\x06\x00\x00jI\x06\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(\x8c2/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION\x94\x8c@/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/02_CLEAN_DATA\x94]\x94(\x8c\x04bF1A\x94\x8c\x04bF1B\x94\x8c\x04bF1C\x94\x8c\x04bF2A\x94\x8c\x04bF2B\x94\x8c\x04bF2C\x94\x8c\x04bF3A\x94\x8c\x04bF3B\x94\x8c\x04bF3C\x94\x8c\x03bFL\x94\x8c\x05bFL_T\x94\x8c\x03bN1\x94\x8c\x05bN1_T\x94\x8c\x03bN2\x94\x8c\x05bN2_T\x94\x8c\x03bN3\x94\x8c\x05bN3_T\x94\x8c\x03bNW\x94\x8c\x04bNWd\x94\x8c\x04bO1A\x94\x8c\x04bO1B\x94\x8c\x04bO1C\x94\x8c\x04bO2A\x94\x8c\x04bO2B\x94\x8c\x04bO2C\x94\x8c\x04bO3A\x94\x8c\x04bO3B\x94\x8c\x04bO3C\x94\x8c\x03bOL\x94\x8c\x05bOL_T\x94\x8c\x04bS1B\x94\x8c\x04bS1C\x94\x8c\x04bS2B\x94\x8c\x04bS2C\x94\x8c\x04bS3B\x94\x8c\x04bS3C\x94\x8c\x03bSE\x94\x8c\x04bSEd\x94\x8c\x03bSW\x94\x8c\x04bSWd\x94\x8c\x03bZ1\x94\x8c\x05bZ1_T\x94\x8c\x03bZ2\x94\x8c\x05bZ2_T\x94\x8c\x03bZ3\x94\x8c\x05bZ3_T\x94e\x8c\x02R1\x94\x8c\x02R2\x94\x8c>/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA\x94\x8c8/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/01_QC\x94e}\x94(jC\x05\x00\x00}\x94(\x8c\x0bresults_dir\x94K\x00N\x86\x94\x8c\tclean_dir\x94K\x01N\x86\x94\x8c\x07samples\x94K\x02N\x86\x94\x8c\x0bforward_tag\x94K\x03N\x86\x94\x8c\x0breverse_tag\x94K\x04N\x86\x94\x8c\x07raw_dir\x94K\x05N\x86\x94\x8c\x06qc_dir\x94K\x06N\x86\x94ujg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bj\xbe\x06\x00\x00j\x87\x06\x00\x00j\xc0\x06\x00\x00j\x88\x06\x00\x00j\xc2\x06\x00\x00j\x89\x06\x00\x00j\xc4\x06\x00\x00j\xb8\x06\x00\x00j\xc6\x06\x00\x00j\xb9\x06\x00\x00j\xc8\x06\x00\x00j\xba\x06\x00\x00j\xca\x06\x00\x00j\xbb\x06\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x03tot\x94a}\x94(jC\x05\x00\x00}\x94\x8c\x08sampling\x94K\x00N\x86\x94sjg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94b\x8c\x08sampling\x94j\xd9\x06\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(jC\x05\x00\x00}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94ujg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bj\xf0\x06\x00\x00K\x01j\xf2\x06\x00\x00K\x01j\xf4\x06\x00\x00j\xed\x06\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cL/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/NOTEBOOKS/01_QC.tot.ipynb\x94a}\x94(jC\x05\x00\x00}\x94\x8c\x08notebook\x94K\x00N\x86\x94sjg\x05\x00\x00]\x94(ji\x05\x00\x00jj\x05\x00\x00eji\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00ji\x05\x00\x00sNt\x94bjj\x05\x00\x00jm\x05\x00\x00jo\x05\x00\x00\x85\x94R\x94(jo\x05\x00\x00)}\x94js\x05\x00\x00jj\x05\x00\x00sNt\x94bj\x06\x07\x00\x00j\x03\x07\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94j\xba\x06\x00\x00\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\x1cadditional_reference_contigs\x94\x8cA/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/active_vOTUs.fasta\x94\x8c\x0bsubsampling\x94\x88\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94j\xb8\x06\x00\x00\x8c\x0breverse_tag\x94j\xb9\x06\x00\x00\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\x11nanopore_headcrop\x94K2\x8c\x11nanopore_tailcrop\x94K2\x8c\x0cmedaka_model\x94\x8c\x12r941_min_high_g360\x94\x8c\x12contaminants_taxid\x94M\xc7\n\x8c\x0bsubassembly\x94\x89\x8c\tVirSorter\x94\x89\x8c\x0eassembly_stats\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x0crun_vcontact\x94\x89\x8c\x08run_DRAM\x94\x89\x8c\x0bimgvr_blast\x94\x89\x8c\necc_memory\x94Mp\x17\x8c\x16representative_contigs\x94j\x1c\x07\x00\x00\x8c\x08sra_list\x94j\x1c\x07\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x0fmin_votu_length\x94M\x88\x13\x8c\x11contaminants_list\x94j\x1c\x07\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x11microbial_spacers\x94j\x1c\x07\x00\x00\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2025_08_29.fasta\x94\x8c\x0bpharokka_db\x94\x8c\x15/home/lmf/db/pharokka\x94\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\nQC_parsing\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Quality Control

# %%
# import necessary modules
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.colors import LinearSegmentedColormap
from scipy.optimize import curve_fit
import json
import numpy as np

#------------------------------------------
# Create a list of colors
colors_rarefaction=sns.color_palette("colorblind", n_colors=len(list(snakemake.params.samples))+1)
# Create a LinearSegmentedColormap object
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


sns.set_style("ticks",{'axes.grid' : True})
sns.set_palette("colorblind")

plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["xtick.major.width"] = 1.5
plt.rcParams["ytick.major.width"] = 1.5
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["axes.titlepad"] = 20

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["axes.titlesize"] = 30
plt.rcParams['axes.labelsize'] = 23.5
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['text.usetex'] = False

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["savefig.dpi"]=300

# %%
clean_dir=snakemake.params.clean_dir
raw_dir=snakemake.params.raw_dir
qc_dir=snakemake.params.qc_dir

SAMPLE_PLOT_LIM_LEGEND=100
SAMPLE_PLOT_LIM=200

SAMPLES=list(snakemake.params.samples)
forward_tag="_" + str(snakemake.params.forward_tag)
reverse_tag="_" +str( snakemake.params.reverse_tag)

input_histograms=list(snakemake.input.histograms)
input_histograms_pre=list(snakemake.input.histogram_kmer_pre)
input_histograms_post=list(snakemake.input.histogram_kmer_post)
# input_peak_kmer=list(snakemake.input.peak_kmer)

input_histograms.sort()
input_histograms_pre.sort()
input_histograms_post.sort()


if len(input_histograms)>SAMPLE_PLOT_LIM:
   input_histograms=input_histograms[:SAMPLE_PLOT_LIM]

if len(input_histograms_pre)>SAMPLE_PLOT_LIM:
   input_histograms_pre=input_histograms_pre[:SAMPLE_PLOT_LIM]

if len(input_histograms_post)>SAMPLE_PLOT_LIM:
   input_histograms_post=input_histograms_post[:SAMPLE_PLOT_LIM]

illumina_preqc=snakemake.input.preqc_txt
illumina_postqc=snakemake.input.postqc_txt
#------------------------------------------
output_kmer_png=snakemake.output.kmer_png
output_kmer_svg=snakemake.output.kmer_svg
output_kmer_png_fitted=snakemake.output.kmer_fit_png
output_kmer_svg_fitted=snakemake.output.kmer_fit_svg
output_kmer_fit_html=snakemake.output.kmer_fit_html
output_kmer_dist_pre_png=snakemake.output.kmer_dist_pre_png
output_kmer_dist_pre_svg=snakemake.output.kmer_dist_pre_svg
output_kmer_dist_post_png=snakemake.output.kmer_dist_post_png
output_kmer_dist_post_svg=snakemake.output.kmer_dist_post_svg

output_qc_summary_html=snakemake.output.qc_summary_html
output_percentage_kept_reads_png=snakemake.output.percentage_kept_reads_png
output_percentage_kept_reads_svg=snakemake.output.percentage_kept_reads_svg
output_percentage_kept_Mbp_png=snakemake.output.percentage_kept_Mbp_png
output_percentage_kept_Mbp_svg=snakemake.output.percentage_kept_Mbp_svg
output_step_qc_reads_html=snakemake.output.step_qc_reads_html
output_steps_qc_reads_png=snakemake.output.steps_qc_reads_png
output_steps_qc_reads_svg=snakemake.output.steps_qc_reads_svg
output_steps_qc_percentage_png=snakemake.output.steps_qc_percentage_png
output_steps_qc_percentage_svg=snakemake.output.steps_qc_percentage_svg
output_df_counts_paired=snakemake.output.df_counts_paired
output_supperdedupper_html=snakemake.output.supperdedupper_html
output_supperdedupper_png=snakemake.output.supperdedupper_png
output_supperdedupper_svg=snakemake.output.supperdedupper_svg

# %% [markdown]
# ## KMER rarefraction

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Sort input_histograms and SAMPLES
input_histograms.sort()
SAMPLES.sort()

# Initialize variables
n = 1
read_max = 0

# Create a single plot
fig, ax = plt.subplots()

# Loop through each histogram in input_histograms
for h in input_histograms:
    # Read the histogram file as a pandas dataframe
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Convert percent to percentage of missing kmers and counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000

    # Plot the data as a line plot
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, ax=ax)

    # Add a vertical line at the x-value corresponding to the maximum count
    max_count = df["counts"].max()
    plt.axvline(max_count, 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.3)
    read_max = max(read_max, max_count)

    # Increment n
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.2))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 2.17 %
# 4.35 %
# 6.52 %
# 8.70 %
# 10.87 %
# 13.04 %
# 15.22 %
# 17.39 %
# 19.57 %
# 21.74 %
# 23.91 %
# 26.09 %
# 28.26 %
# 30.43 %
# 32.61 %
# 34.78 %
# 36.96 %
# 39.13 %
# 41.30 %
# 43.48 %
# 45.65 %
# 47.83 %
# 50.00 %
# 52.17 %
# 54.35 %
# 56.52 %
# 58.70 %
# 60.87 %
# 63.04 %
# 65.22 %
# 67.39 %
# 69.57 %
# 71.74 %
# 73.91 %
# 76.09 %
# 78.26 %
# 80.43 %
# 82.61 %
# 84.78 %
# 86.96 %
# 89.13 %
# 91.30 %
# 93.48 %
# 95.65 %
# 97.83 %
# 100.00 %

# %% [markdown]
# # KMER rarefraction log fit

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define the number of million reads to trim
cut_million_reads = 5
trim_reads = int(cut_million_reads * 40)
max_read_fitting = 80

# Initialize variables
read_max = 0
n = 1
samples = []
a_list = []
b_list = []
max_reads = []
slope_list = []

# Define the logarithmic function used for fitting
def logFunc(x, a, b):
    return a + b * np.log(x)

# Create a single plot
fig, ax = plt.subplots()

# Loop through input histograms
for h in input_histograms:
    # Load the data from the current input histogram
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Calculate the percentage of known k-mers and convert the counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000

    # Plot the original data
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, alpha=0.8, ax=ax)

    # Keep track of the maximum read count
    read_max = max(read_max, df["counts"].max())

    # If there are enough data points, fit a logarithmic function to the tail of the data
    if len(df["counts"]) > trim_reads + 1:
        # Subsample pandas dataframe every half million reads
        subsample_rate_mreads = 0.1
        subsample_size = int(subsample_rate_mreads * 40)
        df_subsampled = df[trim_reads:].iloc[::subsample_size, :]
        if len(df_subsampled) > 10:
            # Fit the function to the tail of the data
            popt, _ = curve_fit(logFunc, df_subsampled["counts"], df_subsampled["percent"])

            # Plot the fitted function
            sns.lineplot(x=np.arange(cut_million_reads, max_read_fitting, 0.25), 
                         y=logFunc(np.arange(cut_million_reads, max_read_fitting, 0.25), *popt), 
                         color=colors_rarefaction[n], err_style='band', linewidth=2, alpha=0.2, 
                         label='_nolegend_', ax=ax)

            # Store the fitting parameters and other statistics
            samples.append(h.split("/")[-1].split("_kmer")[0])
            a_list.append(popt[0])
            b_list.append(popt[1])
            max_reads.append(df["counts"].max())
            reads_to_1 = (popt[0] / popt[1])
            slope_list.append(popt[1] / df["counts"].max())

    # Add a vertical line to indicate the maximum read count
    plt.axvline(df["counts"].max(), 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.4)

    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.5))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png_fitted, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg_fitted, format="svg", bbox_inches="tight", transparent=True)

# Display the plot
plt.show()
# Out:
# 2.17 %
# 4.35 %
# 6.52 %
# 8.70 %
# 10.87 %
# 13.04 %
# 15.22 %
# 17.39 %
# 19.57 %
# 21.74 %
# 23.91 %
# 26.09 %
# 28.26 %
# 30.43 %
# 32.61 %
# 34.78 %
# 36.96 %
# 39.13 %
# 41.30 %
# 43.48 %
# 45.65 %
# 47.83 %
# 50.00 %
# 52.17 %
# 54.35 %
# 56.52 %
# 58.70 %
# 60.87 %
# 63.04 %
# 65.22 %
# 67.39 %
# 69.57 %
# 71.74 %
# 73.91 %
# 76.09 %
# 78.26 %
# 80.43 %
# 82.61 %
# 84.78 %
# 86.96 %
# 89.13 %
# 91.30 %
# 93.48 %
# 95.65 %
# 97.83 %
# 100.00 %

# %%
# create a new empty pandas DataFrame
stats_df=pd.DataFrame()

# add columns to the DataFrame using lists
stats_df["Sample"]=samples
stats_df["a"]=a_list
stats_df["b"]=b_list
stats_df["slope"]=slope_list
stats_df["M_reads"]=max_reads
stats_df["b_-_Mreads"]=stats_df["b"]-stats_df["M_reads"]

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
stats_df_out = stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn").to_html()
# write the HTML table to a file
with open(output_kmer_fit_html,"w") as fp:
    fp.write(stats_df_out)

# sort the DataFrame by "Sample" column and apply background color gradient to it
stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_4f8ca_row0_col1, #T_4f8ca_row14_col4 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_4f8ca_row0_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_4f8ca_row0_col3, #T_4f8ca_row15_col3 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_4f8ca_row0_col4 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_4f8ca_row0_col5 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_4f8ca_row1_col1, #T_4f8ca_row8_col4 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_4f8ca_row1_col2, #T_4f8ca_row7_col2, #T_4f8ca_row19_col5, #T_4f8ca_row24_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_4f8ca_row1_col3, #T_4f8ca_row4_col3, #T_4f8ca_row14_col1 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_4f8ca_row1_col4, #T_4f8ca_row25_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_4f8ca_row1_col5, #T_4f8ca_row19_col3 {
#   background-color: #fa9656;
# ...

# %% [markdown]
# # Kmer count histogram (kmer size=31)

# %% [markdown]
# ## Pre normalization

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_pre.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_pre:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_pre_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_pre_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()
# Out:
# 2.17 %
# 4.35 %
# 6.52 %
# 8.70 %
# 10.87 %
# 13.04 %
# 15.22 %
# 17.39 %
# 19.57 %
# 21.74 %
# 23.91 %
# 26.09 %
# 28.26 %
# 30.43 %
# 32.61 %
# 34.78 %
# 36.96 %
# 39.13 %
# 41.30 %
# 43.48 %
# 45.65 %
# 47.83 %
# 50.00 %
# 52.17 %
# 54.35 %
# 56.52 %
# 58.70 %
# 60.87 %
# 63.04 %
# 65.22 %
# 67.39 %
# 69.57 %
# 71.74 %
# 73.91 %
# 76.09 %
# 78.26 %
# 80.43 %
# 82.61 %
# 84.78 %
# 86.96 %
# 89.13 %
# 91.30 %
# 93.48 %
# 95.65 %
# 97.83 %
# 100.00 %

# %% [markdown]
# ## Post normalization (target=100x)

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_post.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_post:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_post_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_post_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ## PreQC and PostQC FASTQC statistics

# %%
# load the pre- and post-illumina sequencing quality control data into pandas dataframes
preqc = pd.read_csv(illumina_preqc, sep="\t")
postqc = pd.read_csv(illumina_postqc, sep="\t")

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the preqc dataframe
read_stats_df1 = preqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df1
read_stats_df1["Mbp"] = read_stats_df1["avg_sequence_length"] * read_stats_df1["Total Sequences"] / 1000000

# remove the ".fastq" extension from the Filename column
read_stats_df1["Filename"] = read_stats_df1["Filename"].str.split(".fastq").str[0]

# rename the columns of read_stats_df1
read_stats_df1.columns = ["file_pre","length_pre", "number_pre", "Mbp_pre"]

# set the Filename column as the index of read_stats_df1
read_stats_df1 = read_stats_df1.set_index('file_pre')

# remove any whitespace from the index values of read_stats_df1
read_stats_df1.index = read_stats_df1.index.map("".join)

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the postqc dataframe
read_stats_df2 = postqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df2
read_stats_df2["Mbp"] = read_stats_df2["avg_sequence_length"] * read_stats_df2["Total Sequences"] / 1000000

# replace certain portions of the Filename column with standard suffixes (e.g. _forward -> _R1)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_forward", forward_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_reverse", reverse_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_unpaired", "_U")
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_paired").str[0]
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_clean").str[0]

# create a new column in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
# # create a new column in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
# List of suffixes to remove
suffixes = [str(snakemake.params.forward_tag), str(snakemake.params.reverse_tag), "U"]
pattern = "_(" + "|".join(suffixes) + ")$"
# Replace the suffixes
read_stats_df2['Sample'] = read_stats_df2['Filename'].str.replace(pattern, "", regex=True)
read_stats_df2

# set the Filename column as the index of read_stats_df2
read_stats_df2 = read_stats_df2.set_index('Filename')

# rename the columns of read_stats_df2
read_stats_df2.columns=["length_post", "number_post", "Mbp_post", "sample"]

# merge read_stats_df1 and read_stats_df2 on their indices (i.e. Filename), keeping all rows from both dataframes
read_stats_df3 = read_stats_df1.merge(read_stats_df2, left_index=True, right_index=True, how="outer")

# replace any NaN (missing) values in read_stats_df3 with 0
read_stats_df3 = read_stats_df3.fillna(0)

# return the final merged dataframe
read_stats_df3
# Out:
# /tmp/ipykernel_2356787/1195267115.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df1["Mbp"] = read_stats_df1["avg_sequence_length"] * read_stats_df1["Total Sequences"] / 1000000
# /tmp/ipykernel_2356787/1195267115.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df1["Filename"] = read_stats_df1["Filename"].str.split(".fastq").str[0]
# /tmp/ipykernel_2356787/1195267115.py:27: SettingWithCopyWarning:
# ...

# %%
# Pre quality control fastQC statistics
preqc
# Out:
#       Sample           Filename                File type  \
# 0    bF1A_R1   bF1A_R1.fastq.gz  Conventional base calls
# 1    bF1A_R2   bF1A_R2.fastq.gz  Conventional base calls
# 2    bF1B_R1   bF1B_R1.fastq.gz  Conventional base calls
# 3    bF1B_R2   bF1B_R2.fastq.gz  Conventional base calls
# 4    bF1C_R1   bF1C_R1.fastq.gz  Conventional base calls
# ..       ...                ...                      ...
# 87  bZ2_T_R2  bZ2_T_R2.fastq.gz  Conventional base calls
# 88    bZ3_R1    bZ3_R1.fastq.gz  Conventional base calls
# 89    bZ3_R2    bZ3_R2.fastq.gz  Conventional base calls
# 90  bZ3_T_R1  bZ3_T_R1.fastq.gz  Conventional base calls
# 91  bZ3_T_R2  bZ3_T_R2.fastq.gz  Conventional base calls
#
#                  Encoding  Total Sequences  Sequences flagged as poor quality  \
# 0   Sanger / Illumina 1.9       17879627.0                                0.0
# 1   Sanger / Illumina 1.9       17879627.0                                0.0
# ...

# %%
# Post quality control fastQC statistics
postqc
# Out:
#                              Sample                                 Filename  \
# 0     bF1A_forward_paired_clean.tot   bF1A_forward_paired_clean.tot.fastq.gz
# 1     bF1A_reverse_paired_clean.tot   bF1A_reverse_paired_clean.tot.fastq.gz
# 2           bF1A_unpaired_clean.tot         bF1A_unpaired_clean.tot.fastq.gz
# 3     bF1B_forward_paired_clean.tot   bF1B_forward_paired_clean.tot.fastq.gz
# 4     bF1B_reverse_paired_clean.tot   bF1B_reverse_paired_clean.tot.fastq.gz
# ..                              ...                                      ...
# 133  bZ3_T_reverse_paired_clean.tot  bZ3_T_reverse_paired_clean.tot.fastq.gz
# 134        bZ3_T_unpaired_clean.tot        bZ3_T_unpaired_clean.tot.fastq.gz
# 135    bZ3_forward_paired_clean.tot    bZ3_forward_paired_clean.tot.fastq.gz
# 136    bZ3_reverse_paired_clean.tot    bZ3_reverse_paired_clean.tot.fastq.gz
# 137          bZ3_unpaired_clean.tot          bZ3_unpaired_clean.tot.fastq.gz
#
# ...

# %%
# Group read statistics by sample
read_stats_df = read_stats_df3.groupby(["sample"]).sum()

# Calculate percentage of reads and Mbp kept
read_stats_df["%number_kept"] = (read_stats_df["number_post"] / read_stats_df["number_pre"] * 100).round(2)
read_stats_df["%Mbp_kept"] = (read_stats_df["Mbp_post"] / read_stats_df["Mbp_pre"] * 100).round(2)

# Calculate percentage of reads and Mbp removed
read_stats_df["%Mbp_removed"] = 100 - read_stats_df["%Mbp_kept"]
read_stats_df["%number_removed"] = 100 - read_stats_df["%number_kept"]

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
read_stats_out=read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn").to_html()

# write the HTML table to a file
with open(output_qc_summary_html,"w") as fp:
    fp.write(read_stats_out)
    
# Drop unnecessary columns and apply a gradient color scheme to the resulting DataFrame
read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_93c4d_row0_col1, #T_93c4d_row0_col2, #T_93c4d_row44_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_93c4d_row0_col3 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_93c4d_row0_col4 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_93c4d_row0_col5, #T_93c4d_row37_col5, #T_93c4d_row40_col8 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_93c4d_row0_col6, #T_93c4d_row14_col7, #T_93c4d_row14_col8 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_93c4d_row0_col7, #T_93c4d_row14_col5, #T_93c4d_row14_col6, #T_93c4d_row45_col3, #T_93c4d_row45_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_93c4d_row0_col8, #T_93c4d_row16_col1, #T_93c4d_row16_col2, #T_93c4d_row37_col8, #T_93c4d_row40_col5 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_93c4d_row1_col1, #T_93c4d_row1_col2 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_93c4d_row1_col3 {
# ...

# %% [markdown]
# ### Percentage of kept/removed reads

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define maximum number of samples per subplot
max_samples_per_subplot = 200

# Initialize n
n=1

# Calculate the number of rows of subplots needed
num_subplots = int(np.ceil(len(SAMPLES) / max_samples_per_subplot))

# Calculate the approximate number of samples per subplot
samples_per_subplot = int(np.ceil(len(SAMPLES) / num_subplots))

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of reads kept and removed for each sample
    ax = subset_df[["%number_kept", "%number_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of reads')
    ax.set_title(f'Percentage of kept reads (Samples {start_idx + 1} to {end_idx})')

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
    
    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)

    n=n+1
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_reads_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ### Percentage of kept/removed Mbp

# %%
# Initialize n
n=1

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of Mbp kept and removed for each sample
    ax = subset_df[["%Mbp_kept", "%Mbp_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of Mbp')
    ax.set_title(f'Percentage of kept Mbp (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1


# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_Mbp_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_Mbp_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ## Removed reads per QC step

# %%
# Initialize empty lists and variables
sample_l=[]
read_types=[]
raw=[]
trimmed=[]
duk=[]
euk=[]
norm=[]
reads=[]

# Initialize n
n=1

# Loop through each sample in read_stats_df and populate the lists with relevant information
for sample in (read_stats_df.index.to_list()):  
    # Add sample name and read type to lists
    sample_l.extend([sample]*3)
    read_types.extend(["R1", "R2", "U"])
    # Read in raw read counts for each read type and add to raw list
    raw.append(int(open(raw_dir + "/" + sample + forward_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(open(raw_dir + "/" +  sample + reverse_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(0))
    # Read in trimmed read counts for each read type and add to trimmed list
    trimmed.append(int(open(clean_dir + "/" + sample + "_forward_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_reverse_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_merged_unpaired.tot_read_count.txt" , 'r').readline().strip()))
    # Read in non-eukaryotic read counts for each read type and add to euk list
    euk.append(int(open(clean_dir + "/" + sample + "_forward_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_unpaired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    # Read in BBDuk-cleaned read counts for each read type and add to duk list
    duk.append(int(open(clean_dir + "/" + sample + "_forward_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_unpaired_clean.tot_read_count.txt" , 'r').readline().strip()))
    # Read in normalized read counts for each read type and add to norm list
    norm.append(int(open(clean_dir + "/" + sample + "_forward_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_reverse_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_unpaired_norm.tot_read_count.txt" , 'r').readline().strip()))


    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Create an empty pandas DataFrame
df_counts = pd.DataFrame()

# Add columns to the DataFrame
df_counts["sample"] = sample_l
df_counts["type"] = read_types
df_counts["raw"] = raw
df_counts["trimmomatic"] = trimmed
df_counts["kraken"] = euk
df_counts["bbduk"] = duk
df_counts["norm"] = norm

# Calculate values for new columns and add them to the DataFrame
df_counts["raw_s"] = df_counts["raw"] / 1000000
df_counts["low_QC_reads_s"] = (df_counts["raw"] - df_counts["trimmomatic"]) / 1000000
df_counts["eukaryotic_reads_s"] = (df_counts["trimmomatic"] - df_counts["kraken"]) / 1000000
df_counts["bbduk_phix174_reads_s"] = (df_counts["kraken"] - df_counts["bbduk"]) / 1000000
df_counts["duplicate_reads_s"] = (df_counts["bbduk"] - df_counts["norm"]) / 1000000
df_counts["assembly_reads_s"] = df_counts["norm"] / 1000000

df_counts["low_QC_reads_p"] = df_counts["low_QC_reads_s"] / df_counts["raw_s"]
df_counts["eukaryotic_reads_p"] = df_counts["eukaryotic_reads_s"] / df_counts["raw_s"]
df_counts["bbduk_phix174_reads_p"] = df_counts["bbduk_phix174_reads_s"] / df_counts["raw_s"]
df_counts["duplicate_reads_p"] = df_counts["duplicate_reads_s"] / df_counts["raw_s"]
df_counts["assembly_reads_p"] = df_counts["assembly_reads_s"] / df_counts["raw_s"]

# Create a new column by concatenating two existing columns
df_counts["sample_long"] = df_counts["sample"] + "_" + df_counts["type"]

# Convert the DataFrame to an HTML table and write it to a file
df_counts.to_html(output_step_qc_reads_html)

# Display the final DataFrame
df_counts
# Out:
# 2.17 %
# 4.35 %
# 6.52 %
# 8.70 %
# 10.87 %
# 13.04 %
# 15.22 %
# 17.39 %
# 19.57 %
# 21.74 %
# 23.91 %
# 26.09 %
# 28.26 %
# 30.43 %
# 32.61 %
# 34.78 %
# 36.96 %
# 39.13 %
# 41.30 %
# 43.48 %
# 45.65 %
# 47.83 %
# 50.00 %
# 52.17 %
# 54.35 %
# 56.52 %
# 58.70 %
# 60.87 %
# 63.04 %
# 65.22 %
# 67.39 %
# 69.57 %
# 71.74 %
# 73.91 %
# 76.09 %
# 78.26 %
# 80.43 %
# 82.61 %
# 84.78 %
# 86.96 %
# 89.13 %
# 91.30 %
# 93.48 %
# 95.65 %
# 97.83 %
# 100.00 %
#     sample type       raw  trimmomatic    kraken     bbduk      norm  \
# 0     bF1A   R1  17879627     15905433  15624772  15624772  14267472
# 1     bF1A   R2  17879627     15905433  15624772  15624772  14267472
# 2     bF1A    U         0      1621017   1600010   1600010   1598605
# 3     bF1B   R1  35119093     31209863  29281941  29281941  28447243
# 4     bF1B   R2  35119093     31209863  29281941  29281941  28447243
# ..     ...  ...       ...          ...       ...       ...       ...
# ...

# %% [markdown]
# ### Number of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4


# Define legend text and create colormap
legend_text = ["Used for assembly", "Duplicate (removed)", "phiX174 (user contaminants)", "Eukaryotic contamination", "Low quality"]

# Filter the dataframe to only include R1 reads
df_counts_paired = df_counts[df_counts["type"] == "R1"]

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    # print(i)
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(x="sample", y=["assembly_reads_s", "duplicate_reads_s", "bbduk_phix174_reads_s", "eukaryotic_reads_s", "low_QC_reads_s"],
                        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none')

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Million reads')
    ax.set_title(f'Sample Read Counts (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1
    
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_reads_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %% [markdown]
# ### Percentage of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(
        x="sample",
        y=["assembly_reads_p", "duplicate_reads_p", "bbduk_phix174_reads_p", "eukaryotic_reads_p", "low_QC_reads_p"],
        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none'
    )

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Proportion of raw reads')
    ax.set_title(f'Sample Proportion of Raw Reads (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_percentage_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_percentage_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()
# Out:
# 100.00 %

# %%
df_counts_paired.to_csv(output_df_counts_paired)
df_counts_paired
# Out:
#     sample type       raw  trimmomatic    kraken     bbduk      norm  \
# 0     bF1A   R1  17879627     15905433  15624772  15624772  14267472
# 3     bF1B   R1  35119093     31209863  29281941  29281941  28447243
# 6     bF1C   R1  24019860     20791303  18598176  18598176  18462394
# 9     bF2A   R1   9016569      7207097   7102101   7102101   7033776
# 12    bF2B   R1  35448248     32092896  28925956  28925956  28379670
# 15    bF2C   R1  14141146     11961284   9588357   9588357   9553380
# 18    bF3A   R1  17468900     15581593  14904494  14904494  14754867
# 21    bF3B   R1  30701310     26499668  24054438  24054438  23874331
# 24    bF3C   R1  10863179      8428680   7949703   7949703   7883721
# 27     bFL   R1  20302819     16180650  16010372  16010371  15491615
# 30   bFL_T   R1   3644892      2703456   2670339   2670338   2656730
# 33     bN1   R1  10905109      6043719   4171549   4171549   2485270
# 36   bN1_T   R1    373002       232243     70946     70946     69025
# ...

# %% [markdown]
# ## Super Deduper PCR duplication statistics

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Initialize variables
maxim = 0
percentages = []

# Create a single plot
fig, ax = plt.subplots()
n=1
# Loop through each sample
for sample in SAMPLES:
    # Load the JSON data from the file
    with open(qc_dir + "/" + sample + "_stats_pcr_duplicates.log") as f:
        data = json.load(f)
    
    # Extract the relevant data and calculate percentage of duplicates
    df = pd.DataFrame(data[0]["Fragment"]["duplicate_saturation"], columns=["reads", "dup"]) / 1000000
    percentages.append(df.iloc[-1]["dup"] * 100 / df.iloc[-1]["reads"])
    
    # Find the maximum value of "reads"
    max_temp = df["reads"].max()
    if max_temp > maxim:
        maxim = max_temp

    n=n+1
    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)

    # Plot the data as a line plot using seaborn
    sns.lineplot(x="reads", y="dup", data=df, err_style='band', color=colors_rarefaction[len(percentages) - 1], 
                 label=sample, linewidth=1, alpha=0.8, ax=ax)

# Set the x and y limits of the plot
ax.set(ylim=(0, maxim))
ax.set(xlim=(0, maxim))

# Set the x and y labels of the plot
ax.set_xlabel("Million reads")
ax.set_ylabel("PCR duplicates (Million reads)")

# Add a legend to the plot
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)

plt.tight_layout()

# Save the plot as png and svg files
fig.savefig(output_supperdedupper_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_supperdedupper_svg, format="svg", bbox_inches="tight", transparent=True)

# Create a dataframe to store the percentage of duplicates for each sample
pcr_dup_df = pd.DataFrame({
    "sample": SAMPLES,
    "pcr_percent_duplicates": percentages
})

# Generate a styled HTML table of the dataframe and save it to a file
pcr_dup_df_out = pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100).to_html()
with open(output_supperdedupper_html, "w") as fp:
    fp.write(pcr_dup_df_out)
# Out:
# 4.35 %
# 6.52 %
# 8.70 %
# 10.87 %
# 13.04 %
# 15.22 %
# 17.39 %
# 19.57 %
# 21.74 %
# 23.91 %
# 26.09 %
# 28.26 %
# 30.43 %
# 32.61 %
# 34.78 %
# 36.96 %
# 39.13 %
# 41.30 %
# 43.48 %
# 45.65 %
# 47.83 %
# 50.00 %
# 52.17 %
# 54.35 %
# 56.52 %
# 58.70 %
# 60.87 %
# 63.04 %
# 65.22 %
# 67.39 %
# 69.57 %
# 71.74 %
# 73.91 %
# 76.09 %
# 78.26 %
# 80.43 %
# 82.61 %
# 84.78 %
# 86.96 %
# 89.13 %
# 91.30 %
# 93.48 %
# 95.65 %
# 97.83 %
# 100.00 %
# 102.17 %
# /tmp/ipykernel_2356787/3414207298.py:47: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# display the styled dataframe in the notebook
pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100)
# Out:
# <style type="text/css">
# #T_4e020_row0_col1 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_4e020_row1_col1, #T_4e020_row4_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_4e020_row2_col1 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_4e020_row3_col1 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_4e020_row5_col1, #T_4e020_row6_col1, #T_4e020_row25_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_4e020_row7_col1, #T_4e020_row17_col1, #T_4e020_row20_col1, #T_4e020_row23_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_4e020_row8_col1 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_4e020_row9_col1, #T_4e020_row41_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_4e020_row10_col1, #T_4e020_row29_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_4e020_row11_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_4e020_row12_col1 {
# ...
