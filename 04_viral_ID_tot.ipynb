# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpn2i44r2f/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95w<\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF1A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF1B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF1C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF2A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF2B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF2C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF3A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF3B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bF3C_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bFL_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bFL_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN1_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN1_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN2_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN2_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN3_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bN3_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bNW_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bNWd_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO1A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO1B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO1C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO2A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO2B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO2C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO3A_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO3B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bO3C_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bOL_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bOL_T_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS1B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS1C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS2B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS2C_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS3B_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bS3C_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bSE_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bSEd_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bSW_positive_viral_contigs.tot.fasta\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bSWd_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ1_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ1_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ2_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ2_T_positive_viral_contigs.tot.fasta\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ3_positive_viral_contigs.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID/bZ3_T_positive_viral_contigs.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF1A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF1B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF1C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF2A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF2B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF2C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF3A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF3B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bF3C_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bFL_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bFL_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN1_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN1_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN2_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN2_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN3_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bN3_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bNW_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bNWd_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO1A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO1B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO1C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO2A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO2B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO2C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO3A_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO3B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bO3C_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bOL_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bOL_T_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS1B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS1C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS2B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS2C_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS3B_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bS3C_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bSE_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bSEd_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bSW_spades_filtered_scaffolds.tot.fasta\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bSWd_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ1_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ1_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ2_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ2_T_spades_filtered_scaffolds.tot.fasta\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ3_spades_filtered_scaffolds.tot.fasta\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS/bZ3_T_spades_filtered_scaffolds.tot.fasta\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x0fviral_sequences\x94K\x00K.\x86\x94\x8c\x13assembled_sequences\x94K.K\\\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eho\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(hu)}\x94\x8c\x05_name\x94hosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bhih\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7e}\x94(hg}\x94hm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bubhkh\x80)\x81\x94(h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhchdhee}\x94(hg}\x94hm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_count_tot.png\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_count_tot.svg\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_count_tot.html\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_length_tot.png\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_length_tot.svg\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/04_viral_sequences_length_tot.html\x94e}\x94(hg}\x94(\x8c\x1eviral_sequences_count_plot_png\x94K\x00N\x86\x94\x8c\x1eviral_sequences_count_plot_svg\x94K\x01N\x86\x94\x8c viral_sequences_count_table_html\x94K\x02N\x86\x94\x8c\x1fviral_sequences_length_plot_png\x94K\x03N\x86\x94\x8c\x1fviral_sequences_length_plot_svg\x94K\x04N\x86\x94\x8c!viral_sequences_length_table_html\x94K\x05N\x86\x94uhm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bh\xa5h\x9dh\xa7h\x9eh\xa9h\x9fh\xabh\xa0h\xadh\xa1h\xafh\xa2ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(\x8c\x04bF1A\x94\x8c\x04bF1B\x94\x8c\x04bF1C\x94\x8c\x04bF2A\x94\x8c\x04bF2B\x94\x8c\x04bF2C\x94\x8c\x04bF3A\x94\x8c\x04bF3B\x94\x8c\x04bF3C\x94\x8c\x03bFL\x94\x8c\x05bFL_T\x94\x8c\x03bN1\x94\x8c\x05bN1_T\x94\x8c\x03bN2\x94\x8c\x05bN2_T\x94\x8c\x03bN3\x94\x8c\x05bN3_T\x94\x8c\x03bNW\x94\x8c\x04bNWd\x94\x8c\x04bO1A\x94\x8c\x04bO1B\x94\x8c\x04bO1C\x94\x8c\x04bO2A\x94\x8c\x04bO2B\x94\x8c\x04bO2C\x94\x8c\x04bO3A\x94\x8c\x04bO3B\x94\x8c\x04bO3C\x94\x8c\x03bOL\x94\x8c\x05bOL_T\x94\x8c\x04bS1B\x94\x8c\x04bS1C\x94\x8c\x04bS2B\x94\x8c\x04bS2C\x94\x8c\x04bS3B\x94\x8c\x04bS3C\x94\x8c\x03bSE\x94\x8c\x04bSEd\x94\x8c\x03bSW\x94\x8c\x04bSWd\x94\x8c\x03bZ1\x94\x8c\x05bZ1_T\x94\x8c\x03bZ2\x94\x8c\x05bZ2_T\x94\x8c\x03bZ3\x94\x8c\x05bZ3_T\x94e\x8c=/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/03_CONTIGS\x94\x8c>/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/04_VIRAL_ID\x94\x89\x89\x8c\x04canu\x94e}\x94(hg}\x94(\x8c\x07samples\x94K\x00N\x86\x94\x8c\ncontig_dir\x94K\x01N\x86\x94\x8c\tviral_dir\x94K\x02N\x86\x94\x8c\x0bsubassembly\x94K\x03N\x86\x94\x8c\x0ecross_assembly\x94K\x04N\x86\x94\x8c\x0elong_assembler\x94K\x05N\x86\x94uhm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bh\xf2h\xbeh\xf4h\xedh\xf6h\xeeh\xf8\x89h\xfa\x89h\xfch\xefub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x03tot\x94a}\x94(hg}\x94\x8c\x08sampling\x94K\x00N\x86\x94shm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94b\x8c\x08sampling\x94j\x0b\x01\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(hg}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uhm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bj"\x01\x00\x00K\x01j$\x01\x00\x00K\x01j&\x01\x00\x00j\x1f\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/NOTEBOOKS/04_viral_ID_tot.ipynb\x94a}\x94(hg}\x94\x8c\x08notebook\x94K\x00N\x86\x94shm]\x94(hohpehohshu\x85\x94R\x94(hu)}\x94hyhosNt\x94bhphshu\x85\x94R\x94(hu)}\x94hyhpsNt\x94bj8\x01\x00\x00j5\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c>/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x10\'\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94h\xef\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\x11nanopore_headcrop\x94K2\x8c\x11nanopore_tailcrop\x94K2\x8c\x0cmedaka_model\x94\x8c\x12r941_min_high_g360\x94\x8c\x12contaminants_taxid\x94M\xc7\n\x8c\x0bsubassembly\x94\x89\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x0crun_vcontact\x94\x89\x8c\x08run_DRAM\x94\x89\x8c\x0bimgvr_blast\x94\x89\x8c\x16representative_contigs\x94jP\x01\x00\x00\x8c\x08sra_list\x94jP\x01\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94jP\x01\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x1cadditional_reference_contigs\x94jP\x01\x00\x00\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x11microbial_spacers\x94jP\x01\x00\x00\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2025_08_29.fasta\x94\x8c\x0bpharokka_db\x94\x8c\x15/home/lmf/db/pharokka\x94\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x0fviralID_parsing\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Viral Identification

# %%
import glob, os
# import necessary modules
import pandas as pd
from Bio import SeqIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Create a list of colors
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


sns.set_style("ticks",{'axes.grid' : True})
sns.set_palette("colorblind")


plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["xtick.major.width"] = 1.5
plt.rcParams["ytick.major.width"] = 1.5
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["axes.titlepad"] = 20

plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["axes.titlesize"] = 30
plt.rcParams['axes.labelsize'] = 23.5
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['text.usetex'] = False
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["savefig.dpi"]=300

# %%
input_viral_sequences=snakemake.input.viral_sequences
input_assembled_sequences=snakemake.input.assembled_sequences

SAMPLES=list(snakemake.params.samples)
contig_dir=snakemake.params.contig_dir
viral_dir=snakemake.params.viral_dir
SUBASSEMBLY=snakemake.params.subassembly
CROSS_ASSEMBLY=snakemake.params.cross_assembly
LONG_ASSEMBLER=snakemake.params.long_assembler
#-------------------------------------------------------------------------------------------
output_viral_sequences_count_plot_png=snakemake.output.viral_sequences_count_plot_png
output_viral_sequences_count_plot_svg=snakemake.output.viral_sequences_count_plot_svg
output_viral_sequences_count_table_html=snakemake.output.viral_sequences_count_table_html
output_viral_sequences_length_plot_png=snakemake.output.viral_sequences_length_plot_png
output_viral_sequences_length_plot_svg=snakemake.output.viral_sequences_length_plot_svg
output_viral_sequences_length_table_html=snakemake.output.viral_sequences_length_table_html

# %% [markdown]
# ## Number of viral contigs

# %%
# Create an empty DataFrame to store the samples data
df_samples = pd.DataFrame()

# Initialize empty lists for storing sample names, file names, and lengths
names = []
files = []
lengths = []

# Initialize empty lists for storing positive viral contig names and their corresponding labels
names_p = []
names_p_prophage = []
positive = []
positive_lengths = []

# Iterate over files in the working directory
n=0
len_pass=0
while n<len(input_assembled_sequences):
    file_assembly=input_assembled_sequences[n]
    file_viral=input_viral_sequences[n]    

    if "spades_" in file_assembly:
        # Iterate over records in the fasta file
        for record in SeqIO.parse(file_assembly, "fasta"):
            # Append the modified record ID, sample name, file name, and contig length to their respective lists
            names.append(record.id.replace("=", "_"))
            sample = file_assembly.split("/")[-1].replace("_metaspades", "_spades").split("_spades")[0]
            files.append(file_assembly.split("/")[-1].split("_filtered")[0])
            lengths.append(len(record.seq))
            len_pass=len_pass+1
    elif LONG_ASSEMBLER in file_assembly:
        # Process files long assembly
        for record in SeqIO.parse(file_assembly, "fasta"):
            # Append the modified record ID, sample name, file name, and contig length to their respective lists
            names.append(record.id.replace("=", "_"))
            sample = file_assembly.split("/")[-1].split("_corrected")[0]
            files.append(file_assembly.split("/")[-1].split("_corrected")[0])
            len_pass=len_pass+1
    # Iterate over records in the positive viral contig file
    for record in SeqIO.parse(file_viral, "fasta"):
        # Append the modified record ID (without "_provirus" suffix) and label "positive" to their respective lists
        names_p.append(record.id.replace("=", "_").split("_provirus")[0])
        if "_provirus" in record.id:
            names_p_prophage.append(record.id.replace("=", "_"))
        else:
            names_p_prophage.append("")
        positive_lengths.append(len(record.seq))
        positive.append("positive")
    n=n+1
    
# Assign the lists to the corresponding columns in the df_samples DataFrame
df_samples["names"] = names
df_samples["files"] = files
df_samples["length"] = lengths

# Create a new DataFrame for positive viral contigs data
df_positive = pd.DataFrame()
df_positive["names"] = names_p
df_positive["names_p_prophage"] = names_p_prophage
df_positive["positive"] = positive
df_positive["positive_length"] = positive_lengths

# df_positive=df_positive.groupby("names").first().reset_index()
# Merge the df_samples and df_positive DataFrames on the "names" column
df_samples = df_samples.merge(df_positive, left_on="names", right_on="names", how="left")

# Fill missing values in the "positive" column with the label "negative"
df_samples['positive'] = df_samples['positive'].fillna("negative")
df_samples['positive_length'] = df_samples['positive_length'].fillna(0)
df_samples['names_p_prophage'] = df_samples['names_p_prophage'].fillna("")

# Return the updated df_samples DataFrame
df_samples
# Out:
#                                             names         files  length  \
# 0         bF1A_NODE_1_length_385935_cov_94.309511   bF1A_spades  385935
# 1         bF1A_NODE_2_length_372279_cov_85.460516   bF1A_spades  372279
# 2         bF1A_NODE_3_length_369201_cov_74.404620   bF1A_spades  369201
# 3         bF1A_NODE_4_length_365898_cov_94.144781   bF1A_spades  365898
# 4         bF1A_NODE_5_length_318206_cov_92.051843   bF1A_spades  318206
# ...                                           ...           ...     ...
# 1407803  bZ3_T_NODE_3537_length_1001_cov_2.844609  bZ3_T_spades    1001
# 1407804  bZ3_T_NODE_3538_length_1001_cov_2.226216  bZ3_T_spades    1001
# 1407805  bZ3_T_NODE_3539_length_1001_cov_2.146934  bZ3_T_spades    1001
# 1407806  bZ3_T_NODE_3541_length_1000_cov_2.913228  bZ3_T_spades    1000
# 1407807  bZ3_T_NODE_3542_length_1000_cov_2.696296  bZ3_T_spades    1000
#
#         names_p_prophage  positive  positive_length
# ...

# %%
df_samples_grouped=df_samples.groupby("names").first()
print(len(df_samples))
print(len(df_samples_grouped))
df_samples_grouped[["positive"]].value_counts().to_frame()
# Out:
# 1407808
# 1407806
#             count
# positive
# negative  1128807
# positive   278999

# %%
# df_samples[df_samples["names"]=="bF1C_NODE_1_length_746427_cov_33.465433"]
prophage_positive_length=df_samples.groupby("names").sum()[["positive_length"]].reset_index()
df_samples_grouped=df_samples_grouped.drop("positive_length", axis=1).merge(prophage_positive_length,left_on="names", right_on="names")
df_samples_grouped["negative_length"]=df_samples_grouped["length"]-df_samples_grouped["positive_length"]
df_samples_grouped
# Out:
#                                             names         files  length  \
# 0        bF1A_NODE_10000_length_2385_cov_4.058798   bF1A_spades    2385
# 1        bF1A_NODE_10001_length_2385_cov_3.521030   bF1A_spades    2385
# 2        bF1A_NODE_10002_length_2385_cov_3.466094   bF1A_spades    2385
# 3        bF1A_NODE_10003_length_2385_cov_2.848498   bF1A_spades    2385
# 4        bF1A_NODE_10004_length_2384_cov_4.680550   bF1A_spades    2384
# ...                                           ...           ...     ...
# 1407801   bZ3_T_NODE_997_length_3100_cov_2.626929  bZ3_T_spades    3100
# 1407802   bZ3_T_NODE_998_length_3096_cov_4.848405  bZ3_T_spades    3096
# 1407803   bZ3_T_NODE_999_length_3096_cov_3.872739  bZ3_T_spades    3096
# 1407804   bZ3_T_NODE_99_length_13543_cov_3.968713  bZ3_T_spades   13543
# 1407805    bZ3_T_NODE_9_length_77496_cov_6.716145  bZ3_T_spades   77496
#
#         names_p_prophage  positive  positive_length  negative_length
# ...

# %%
# Group the df_samples DataFrame by "names" and "positive" columns,
# keep the first record for each group, and reset the index
df = df_samples.groupby(["names", "positive"]).first().reset_index()

# Group the resulting DataFrame by "files" and "positive" columns,
# calculate the size of each group, and reset the index with a new column "Count"
df = df.groupby(["files", "positive"]).size().reset_index(name='Count')

# Create a pivot table using the "Count" column as values,
# "positive" column as columns, and "files" column as index.
# The missing values are filled with 0.
df_pivot = pd.pivot_table(df, values='Count', columns=['positive'], index="files",
                     aggfunc=np.sum, fill_value=0)

# Calculate the desired figure width based on the number of columns in df_pivot
fig_width = 0.5 * len(df_pivot)

# Create a bar plot with stacked bars for the "positive" and "negative" columns in df_pivot,
# set the figure size using the calculated width, and customize the appearance
ax = df_pivot[["positive", "negative"]].plot(kind='bar', stacked=True, figsize=(fig_width, 12), edgecolor='none', colormap=cmap1)

# Set the x-axis label and y-axis label
ax.set_xlabel("Sample")
ax.set_ylabel("# of Contigs")

# Add a legend to the plot
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels),loc='center left', bbox_to_anchor=(1, 0.5))

# Save the figure as png and svg
ax.figure.savefig(output_viral_sequences_count_plot_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_viral_sequences_count_plot_svg, format="svg", bbox_inches = "tight",transparent=True)
# Out:
# /tmp/ipykernel_2365316/3089897619.py:12: FutureWarning: The provided callable <function sum at 0x7f7d98080ea0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_pivot = pd.pivot_table(df, values='Count', columns=['positive'], index="files",

# %% [markdown]
# ## Number of viral bases

# %%
# Dataframe with number contigs per viral category
df_pivot["total"]=df_pivot["positive"]+df_pivot["negative"]
df_pivot["f_positive"]=round((df_pivot["positive"]/df_pivot["total"])*100,1)
df_pivot["f_negative"]=round((df_pivot["negative"]/df_pivot["total"])*100,1)

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
df_pivot_out=df_pivot.style.background_gradient(cmap="RdYlGn", vmin=0).to_html()

# write the HTML table to a file
with open(output_viral_sequences_count_table_html,"w") as fp:
    fp.write(df_pivot_out)
    
# show the dataframe wand apply background color gradient
df_pivot.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style type="text/css">
# #T_20aa1_row0_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_20aa1_row0_col1, #T_20aa1_row9_col0, #T_20aa1_row31_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_20aa1_row0_col2, #T_20aa1_row5_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_20aa1_row0_col3, #T_20aa1_row19_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_20aa1_row0_col4, #T_20aa1_row19_col4 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_20aa1_row1_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_20aa1_row1_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_20aa1_row1_col2, #T_20aa1_row14_col4 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_20aa1_row1_col3, #T_20aa1_row3_col2, #T_20aa1_row21_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_20aa1_row1_col4, #T_20aa1_row21_col4 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# ...

# %%
df_Mbp=df_samples_grouped[["files", "positive_length", "negative_length"]].groupby(["files"]).sum()
df_Mbp.columns=["positive", "negative"]
# Calculate the figure width based on the number of columns in df_Mbp
fig_width = 0.5 * len(df_Mbp)

# Create a bar plot with stacked bars using df_Mbp, set the colormap, figure size, edgecolor, and transparency
ax = df_Mbp[["positive", "negative"]].plot(kind='bar', stacked=True, colormap=cmap1, figsize=(fig_width, 12), edgecolor='none')

# Set the x-label and y-label of the plot
ax.set_xlabel("Sample")
ax.set_ylabel("Million basepairs")

# Add a legend to the plot
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels),loc='center left', bbox_to_anchor=(1, 0.5))

# Save the figure as PNG and SVG files with specified output paths, and adjust the bounding box and transparency
ax.figure.savefig(output_viral_sequences_length_plot_png, format="png", bbox_inches="tight", transparent=True)
ax.figure.savefig(output_viral_sequences_length_plot_svg, format="svg", bbox_inches="tight", transparent=True)

# %%
# Add a new column "total" to df_Mbp, which is the sum of "positive" and "negative" columns
df_Mbp["total"] = df_Mbp["positive"] + df_Mbp["negative"]

# Calculate the percentage of positive contigs and add a new column "f_positive" to df_Mbp
df_Mbp["f_positive"] = round((df_Mbp["positive"] / df_Mbp["total"]) * 100, 1)

# Calculate the percentage of negative contigs and add a new column "f_negative" to df_Mbp
df_Mbp["f_negative"] = round((df_Mbp["negative"] / df_Mbp["total"]) * 100, 1)

# Render the styled DataFrame to an HTML representation
df_Mbp_out = df_Mbp.style.background_gradient(cmap="RdYlGn", vmin=0).to_html()

# Write the HTML representation of the styled DataFrame to a file
with open(output_viral_sequences_length_table_html, "w") as fp:
    fp.write(df_Mbp_out)

# Apply a background gradient to the DataFrame using the "RdYlGn" colormap and set the minimum value to 0
df_Mbp.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style type="text/css">
# #T_1aa03_row0_col0, #T_1aa03_row35_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_1aa03_row0_col1, #T_1aa03_row0_col2, #T_1aa03_row5_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_1aa03_row0_col3, #T_1aa03_row1_col3, #T_1aa03_row4_col3, #T_1aa03_row19_col3, #T_1aa03_row26_col3, #T_1aa03_row45_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_1aa03_row0_col4, #T_1aa03_row1_col4, #T_1aa03_row4_col4, #T_1aa03_row19_col4, #T_1aa03_row26_col4 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_1aa03_row1_col0, #T_1aa03_row20_col4 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_1aa03_row1_col1, #T_1aa03_row1_col2, #T_1aa03_row42_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_1aa03_row2_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_1aa03_row2_col1, #T_1aa03_row30_col4 {
#   background-color: #7ac665;
#   color: #000000;
# }
# ...

# %%
df_pivot.merge(df_Mbp, left_index=True, right_index=True, suffixes=["_number", "_bp"]).to_csv("/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/FIGURES_AND_TABLES/full_sumary_viralID.csv")
df_pivot.merge(df_Mbp, left_index=True, right_index=True, suffixes=["_number", "_bp"])
# Out:
#               negative_number  positive_number  total_number  \
# files
# bF1A_spades             30592             8258         38850
# bF1B_spades             57747            16817         74564
# bF1C_spades             47494            10986         58480
# bF2A_spades             18445             1409         19854
# bF2B_spades             61712            17371         79083
# bF2C_spades             30360             7664         38024
# bF3A_spades             39278            15825         55103
# bF3B_spades             58051            19029         77080
# bF3C_spades             23462             7118         30580
# bFL_T_spades            26953             2036         28989
# bFL_spades              46235             3660         49895
# bN1_T_spades              448               36           484
# bN1_spades               1056              179          1235
# bN2_T_spades                5                2             7
# ...

# %%
df_pivot[["negative", "positive", "total"]].merge(df_Mbp[["negative", "positive", "total"]], left_index=True, right_index=True, suffixes=["_number", "_bp"]).sum().to_frame().astype(int)
# Out:
#                           0
# negative_number     1128807
# positive_number      278999
# total_number        1407806
# negative_bp      3337836517
# positive_bp       490642423
# total_bp         3828478940

# %%
49064242300/3828478940
# Out:
# 12.815596760210989

# %%
91+39
# Out:
# 130
