# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpn2i44r2f/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xb55\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/FIGURES_AND_TABLES/01_qc_read_counts_paired.tot.csv\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/95-85_positive_viral_contigs.tot.fasta\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/checkV_merged_quality_summary.tot.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_circular.tot.csv\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_list.tot.csv\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_quality.tot.csv\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_summary_results.tot.csv\x94\x8c}/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/final-viral-score.tsv\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/positive_VS_list_tot.txt\x94\x8c\xc0/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_virus_summary.tsv\x94\x8c\xc2/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_plasmid_summary.tsv\x94\x8c\xc4/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs.tot.fasta\x94\x8c\xd1/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs_conservative.tot.fasta\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF1A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF1B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF1C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF2A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF2B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF2C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF3A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF3B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bF3C_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bFL_unfiltered_contigs.tot.txt\x94\x8c\x85/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bFL_T_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN1_unfiltered_contigs.tot.txt\x94\x8c\x85/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN1_T_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN2_unfiltered_contigs.tot.txt\x94\x8c\x85/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN2_T_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN3_unfiltered_contigs.tot.txt\x94\x8c\x85/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bN3_T_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bNW_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bNWd_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO1A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO1B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO1C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO2A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO2B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO2C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO3A_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO3B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bO3C_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bOL_unfiltered_contigs.tot.txt\x94\x8c\x85/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bOL_T_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS1B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS1C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS2B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS2C_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS3B_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bS3C_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bSE_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bSEd_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_bSW_unfiltered_contigs.tot.txt\x94\x8c\x84/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_
\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x17get_list_filtered_vOTUs\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # FILTER

# %%
import pandas as pd
from Bio import SeqIO   
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import numpy as np 
import seaborn as sns

# %%
input_df_counts_paired=snakemake.input.df_counts_paired
input_merged_summary=snakemake.input.merged_summary
input_vOTUs_prefiltered=snakemake.input.vOTUs_prefiltered
input_vibrant_circular=snakemake.input.vibrant_circular
input_vibrant_positive=snakemake.input.vibrant_positive
input_vibrant_quality=snakemake.input.vibrant_quality
input_vibrant_summary=snakemake.input.vibrant_summary
input_virsorter_table=snakemake.input.virsorter_table
input_virsorter_positive_list=snakemake.input.virsorter_positive_list
input_genomad_virus_summary=snakemake.input.genomad_virus_summary
input_genomad_plasmid_summary=snakemake.input.genomad_plasmid_summary
input_genomad_viral_fasta=snakemake.input.genomad_viral_fasta
input_genomad_viral_fasta_conservative=snakemake.input.genomad_viral_fasta_conservative
#________
output_summary=snakemake.output.summary
output_filtered_list=snakemake.output.filtered_list

SAMPLES=snakemake.params.samples
min_votu_len=snakemake.params.min_votu_len
SAMPLES_key=snakemake.params.key_samples
input_mapping_dir=snakemake.params.mapping_dir

# %%
# Initialize an empty list to hold individual DataFrames
df_list = []

# Loop over each sample and process data
for sample in SAMPLES_key:
    # Load unfiltered coverage stats
    print(sample)
    covstats_unf = pd.read_csv(f"{input_mapping_dir}/STATS_FILES/bowtie2_{sample}_unfiltered_contigs.tot_covstats.txt", sep="\t", index_col=0)
    covstats_unf = covstats_unf[[f"bowtie2_{sample}_unfiltered_contigs_tot_filtered Read Count"]]
    
    covstats_unf.columns = [sample]
    df_list.append(covstats_unf)

# Concatenate all DataFrames at once along the columns axis
combined_reads_u = pd.concat(df_list, axis=1)

# Display or use the combined DataFrame
combined_reads_u.head()

# Calculate count DataFrame as before
count_df = (combined_reads_u > 1).sum(axis=1).to_frame()
mapped_contigs = list(count_df[count_df[0] > 0].index)
# Out:
# bF1A
# bF1B
# bF1C
# bF2A
# bF2B
# bF2C
# bF3A
# bF3B
# bF3C
# bFL
# bFL_T
# bN1
# bN1_T
# bN2
# bN2_T
# bN3
# bN3_T
# bNW
# bNWd
# bO1A
# bO1B
# bO1C
# bO2A
# bO2B
# bO2C
# bO3A
# bO3B
# bO3C
# bOL
# bOL_T
# bS1B
# bS1C
# bS2B
# bS2C
# bS3B
# bS3C
# bSE
# bSEd
# bSW
# bSWd
# bZ1
# bZ1_T
# bZ2
# bZ2_T
# bZ3
# bZ3_T

# %%
# Create an empty list to store vOTU names
vOTU_list = []

# Iterate over records in input_vOTUs_prefiltered file and append record IDs to the list
for record in SeqIO.parse(input_vOTUs_prefiltered, "fasta"):
    vOTU_list.append(record.id)

# Create a DataFrame with vOTU names
vOTU_prefiltered = pd.DataFrame(vOTU_list, columns=["vOTU_name"])

# Read data from input_merged_summary file into checkv_df DataFrame with specified column names
checkv_df = pd.read_csv(input_merged_summary, sep="\t", names=["checkV_contig_id", "checkV_contig_length", "checkV_provirus",
                                                                "checkV_proviral_length", "checkV_gene_count", "checkV_viral_genes",
                                                                "checkV_host_genes", "checkv_quality", "checkV_miuvig_quality",
                                                                "checkV_completeness", "checkV_completeness_method", "checkV_contamination",
                                                                "checkV_kmer_freq", "checkV_warnings"])
checkv_df=checkv_df.groupby(["checkV_contig_id"]).first().reset_index()

# Read data from input_vibrant_circular file into vibrant_circular_df DataFrame with a single column name
vibrant_circular_df = pd.read_csv(input_vibrant_circular, names=["VIBRANT_circular_name"])
vibrant_circular_df["VIBRANT_circular"] = "Y"

# Read data from input_vibrant_positive file into vibrant_positive_df DataFrame with a single column name
vibrant_positive_df = pd.read_csv(input_vibrant_positive, names=["VIBRANT_positive_name"])
vibrant_positive_df["VIBRANT_positive"] = "Y"

# Read data from input_vibrant_quality file into vibrant_quality_df DataFrame with specific column names
vibrant_quality_df = pd.read_csv(input_vibrant_quality, sep="\t")
vibrant_quality_df.columns = ["VIBRANT_scaffold", "VIBRANT_lifecycle", "VIBRANT_quality"]
vibrant_quality_df = vibrant_quality_df.groupby("VIBRANT_scaffold").first()

# Read data from input_vibrant_summary file into vibrant_summary_df DataFrame with modified column names
vibrant_summary_df = pd.read_csv(input_vibrant_summary, sep="\t")
vibrant_summary_df.columns = ['VIBRANT_' + str(col).replace(" ", "_") for col in vibrant_summary_df.columns]

# Read data from input_virsorter_table file into virsorter_summary_df DataFrame with modified column names
virsorter_summary_df = pd.read_csv(input_virsorter_table, sep="\t")
virsorter_summary_df.columns = ['VirSorter2_' + str(col).replace(" ", "_") for col in virsorter_summary_df.columns]
virsorter_summary_df["VirSorter2_positive"] = "Y"

# Read data from input_genomad_virus_summary file into genomad_summary_df DataFrame with modified column names
genomad_summary_df = pd.read_csv(input_genomad_virus_summary, sep="\t")
genomad_summary_df.columns = ['geNomad_' + str(col).replace(" ", "_") for col in genomad_summary_df.columns]

# Create an empty list to store viral names
viral_list = []

# Iterate over records in input_genomad_viral_fasta file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta, "fasta"):
    viral_list.append(record.id)

# Create a DataFrame with viral names
geNomad_viral = pd.DataFrame(viral_list, columns=["geNomad_viral_name"])
geNomad_viral["geNomad_viral"] = "Y"

# Create an empty list to store conservative viral names
viral_list_conservative = []

# Iterate over records in input_genomad_viral_fasta_conservative file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta_conservative, "fasta"):
    viral_list_conservative.append(record.id)

# Create a DataFrame with conservative viral names
geNomad_viral_conservative = pd.DataFrame(viral_list_conservative, columns=["geNomad_viral_conservative_name"])
geNomad_viral_conservative["geNomad_viral_conservative"] = "Y"

# %%
# Merge vOTU_prefiltered with vibrant_circular_df based on vOTU_name and VIBRANT_circular_name columns
df_temp1 = vOTU_prefiltered.merge(vibrant_circular_df, left_on="vOTU_name", right_on="VIBRANT_circular_name", how="left")

# Merge df_temp1 with vibrant_positive_df based on vOTU_name and VIBRANT_positive_name columns
df_temp2 = df_temp1.merge(vibrant_positive_df, left_on="vOTU_name", right_on="VIBRANT_positive_name", how="left")

# Merge df_temp2 with vibrant_quality_df based on vOTU_name and VIBRANT_scaffold columns
df_temp3 = df_temp2.merge(vibrant_quality_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp3 with vibrant_summary_df based on vOTU_name and VIBRANT_scaffold columns
df_temp4 = df_temp3.merge(vibrant_summary_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp4 with virsorter_summary_df based on vOTU_name and VirSorter2_seqname columns
df_temp5 = df_temp4.merge(virsorter_summary_df, left_on="vOTU_name", right_on="VirSorter2_seqname", how="left")

# Merge df_temp5 with genomad_summary_df based on vOTU_name and geNomad_seq_name columns
df_temp6 = df_temp5.merge(genomad_summary_df, left_on="vOTU_name", right_on="geNomad_seq_name", how="left")

# Merge df_temp6 with geNomad_viral based on vOTU_name and geNomad_viral_name columns
df_temp7 = df_temp6.merge(geNomad_viral, left_on="vOTU_name", right_on="geNomad_viral_name", how="left")

# Merge df_temp7 with geNomad_viral_conservative based on vOTU_name and geNomad_viral_conservative_name columns
df_temp8 = df_temp7.merge(geNomad_viral_conservative, left_on="vOTU_name", right_on="geNomad_viral_conservative_name", how="left")

# Merge df_temp8 with checkv_df based on vOTU_name and checkV_contig_id columns
df_merged = df_temp8.merge(checkv_df, left_on="vOTU_name", right_on="checkV_contig_id", how="left")

# Drop unnecessary columns from df_merged
df_merged = df_merged.drop(["VIBRANT_circular_name", "VIBRANT_positive_name", "VIBRANT_scaffold", "checkV_contig_id"], axis=1)

# Return the merged DataFrame
df_merged
# Out:
#                                        vOTU_name VIBRANT_circular  \
# 0       bF1A_NODE_156_length_40302_cov_16.958233              NaN
# 1        bF1A_NODE_209_length_28979_cov_8.781773              NaN
# 2       bF1A_NODE_389_length_15816_cov_16.222257              NaN
# 3        bF1A_NODE_391_length_15769_cov_4.542701              NaN
# 4        bF1A_NODE_406_length_14977_cov_4.898472              NaN
# ...                                          ...              ...
# 141818  bZ3_T_NODE_3369_length_1060_cov_2.697512              NaN
# 141819  bZ3_T_NODE_3406_length_1042_cov_2.896657              NaN
# 141820  bZ3_T_NODE_3450_length_1028_cov_2.214800              NaN
# 141821  bZ3_T_NODE_3463_length_1025_cov_3.190722              NaN
# 141822  bZ3_T_NODE_3531_length_1002_cov_3.922914              NaN
#
#        VIBRANT_positive VIBRANT_lifecycle     VIBRANT_quality  \
# 0                     Y         lysogenic  high quality draft
# 1                     Y         lysogenic  high quality draft
# 2                     Y             lytic   low quality draft
# 3                     Y             lytic   low quality draft
# 4                     Y             lytic   low quality draft
# ...                 ...               ...                 ...
# 141818              NaN               NaN                 NaN
# 141819              NaN               NaN                 NaN
# 141820              NaN               NaN                 NaN
# 141821              NaN               NaN                 NaN
# 141822              NaN               NaN                 NaN
#
#         VIBRANT_total_genes  VIBRANT_all_KEGG  VIBRANT_KEGG_v-score  \
# 0                      78.0              11.0                 26.19
# 1                      40.0              10.0                 25.96
# 2                      16.0               2.0                  1.18
# 3                      18.0               3.0                  3.36
# 4                      23.0               2.0                  5.49
# ...                     ...               ...                   ...
# 141818                  NaN               NaN                   NaN
# 141819                  NaN               NaN                   NaN
# 141820                  NaN               NaN                   NaN
# 141821                  NaN               NaN                   NaN
# 141822                  NaN               NaN                   NaN
#
#         VIBRANT_all_Pfam  VIBRANT_Pfam_v-score  ...  checkV_gene_count  \
# 0                   21.0                 22.23  ...                 78
# 1                   19.0                 31.96  ...                 39
# 2                    9.0                  9.40  ...                 16
# 3                    4.0                  4.34  ...                 18
# 4                   11.0                 12.64  ...                 23
# ...                  ...                   ...  ...                ...
# 141818               NaN                   NaN  ...                  2
# 141819               NaN                   NaN  ...                  1
# 141820               NaN                   NaN  ...                  1
# 141821               NaN                   NaN  ...                  1
# 141822               NaN                   NaN  ...                  1
#
#         checkV_viral_genes  checkV_host_genes  checkv_quality  \
# 0                       38                  0  Medium-quality
# 1                       19                  0  Medium-quality
# 2                        8                  0     Low-quality
# 3                        2                  0     Low-quality
# 4                       12                  1     Low-quality
# ...                    ...                ...             ...
# 141818                   0                  2  Not-determined
# 141819                   0                  0  Not-determined
# 141820                   0                  0  Not-determined
# 141821                   0                  1  Not-determined
# 141822                   0                  0  Not-determined
#
#         checkV_miuvig_quality  checkV_completeness  \
# 0             Genome-fragment                85.66
# 1             Genome-fragment                69.30
# 2             Genome-fragment                40.94
# 3             Genome-fragment                20.98
# 4             Genome-fragment                47.31
# ...                       ...                  ...
# 141818        Genome-fragment                  NaN
# 141819        Genome-fragment                  NaN
# 141820        Genome-fragment                  NaN
# 141821        Genome-fragment                  NaN
# 141822        Genome-fragment                  NaN
#
#            checkV_completeness_method  checkV_contamination  checkV_kmer_freq  \
# 0         AAI-based (high-confidence)                   0.0               1.0
# 1         AAI-based (high-confidence)                   0.0               1.0
# 2       AAI-based (medium-confidence)                   0.0               1.0
# 3             HMM-based (lower-bound)                   0.0               1.0
# 4         AAI-based (high-confidence)                   0.0               1.0
# ...                               ...                   ...               ...
# 141818                           None                   0.0               1.0
# 141819                           None                   0.0               1.0
# 141820                           None                   0.0               1.0
# 141821                           None                   0.0               1.0
# 141822                           None                   0.0               1.0
#
#                 checkV_warnings
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# ...                         ...
# 141818  no viral genes detected
# 141819  no viral genes detected
# 141820  no viral genes detected
# 141821  no viral genes detected
# 141822  no viral genes detected
#
# [141823 rows x 73 columns]

# %%
df=df_merged[["VirSorter2_positive","VIBRANT_positive","geNomad_viral","geNomad_viral_conservative"]]

# Get the counts for each category
a_count = df['VirSorter2_positive'].value_counts()['Y']
b_count = df['VIBRANT_positive'].value_counts()['Y']
c_count = df['geNomad_viral'].value_counts()['Y']
ab_count = df[df['VirSorter2_positive'] == 'Y']['VIBRANT_positive'].value_counts()['Y']
ac_count = df[df['VirSorter2_positive'] == 'Y']['geNomad_viral'].value_counts()['Y']
bc_count = df[(df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']
abc_count = df[(df['VirSorter2_positive'] == 'Y') & (df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']

# Create the Venn diagram
venn_labels = {'100': a_count - ab_count - ac_count + abc_count,
               '010': b_count - ab_count - bc_count + abc_count,
               '001': c_count - ac_count - bc_count + abc_count,
               '110': ab_count - abc_count,
               '101': ac_count - abc_count,
               '011': bc_count - abc_count,
               '111': abc_count}

plt.figure(figsize=(8, 6))
venn_diagram = venn3(subsets=venn_labels, set_labels=('VirSorter2', 'VIBRANT', 'geNomad'))

# Add the counts to the Venn diagram
for text in venn_diagram.set_labels:
    text.set_fontsize(14)
for text in venn_diagram.subset_labels:
    if text:
        text.set_fontsize(12)

# Show the Venn diagram
# plt.title("Venn Diagram of Categories 'VirSorter2_positive', 'VIBRANT_positive', and 'geNomad_viral'")
plt.show()

# %%
# Define columns to count
columns_to_count = ["VirSorter2_positive", "VIBRANT_positive", "geNomad_viral"]

# Count the number of 'Y' occurrences in columns specified in columns_to_count and store the result in a new column 'count_Y'
df_merged['count_Y'] = df_merged[columns_to_count].eq('Y').sum(axis=1)

# Define the desired column order in the DataFrame
move_cols = ["vOTU_name", "count_Y", "checkV_contig_length", "VirSorter2_positive", "VIBRANT_positive", "geNomad_viral", "geNomad_viral_conservative"]

# Reorder the columns in df_merged according to move_cols and keep the remaining columns in their original order
df_merged = df_merged[move_cols + [col for col in df_merged.columns if col not in move_cols]]

# Create a filtered DataFrame by applying conditions on count_Y and checkV_contig_length columns
df_merged_filtered =df_merged[
    ((df_merged["count_Y"] == 3) | (df_merged["geNomad_viral_conservative"] == "Y")) & 
    ((df_merged["checkV_contig_length"] >= min_votu_len) | (df_merged["checkV_miuvig_quality"] == "High-quality")) ]

df_merged_filtered_abundance=df_merged_filtered[(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=df_merged[
    ((df_merged["count_Y"] != 3) & (df_merged["geNomad_viral_conservative"] != "Y")) |
    ((df_merged["checkV_contig_length"] < min_votu_len) & (df_merged["checkV_miuvig_quality"] != "High-quality"))]

df_merged_removed_abundance=df_merged_filtered[~(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=pd.concat([df_merged_removed,df_merged_removed_abundance])

# Write the values in the 'vOTU_name' column to output_filtered_list file without the index and header
df_merged_filtered_abundance["vOTU_name"].to_csv(output_filtered_list, index=False, header=False)

# Write df_merged_filtered_abundance to output_summary file
df_merged_filtered_abundance.to_csv(output_summary)

# df_merged_removed
print("all\t\t", len(df_merged))
print("selected\t",len(df_merged_filtered_abundance))
print("removed\t\t",len(df_merged_removed))

print("sum\t\t",len(df_merged_filtered_abundance)+len(df_merged_removed) )
# Out:
# all		 141823
# selected	 501
# removed		 141322
# sum		 141823

# %%
category_colors = ["red", "blue", "green", "orange", "purple"]

df_merged_removed["checkV_contig_length_log"]=np.log10(df_merged_removed["checkV_contig_length"])


# Plot the data as a distribution plot
ax = sns.jointplot(data=df_merged_removed,x="checkV_contig_length_log",y="checkV_completeness", hue="checkv_quality", alpha=1,height=6,palette=category_colors, marker="+")
try:
    ax.plot_joint(sns.kdeplot)
except IndexError:
    print("Not enough data for KDE in one or more hue groups.")
    
# Set x- and y-axis labels  
ax.ax_joint.set_xlabel('Contig length')
ax.ax_joint.set_ylabel('CheckV completness')
ax.ax_joint.set_ylim(0,100)
ax.ax_joint.set_xlim(3,5)

# Set the x-ticks and y-ticks to powers of 10
# x-ticks
xticks = ax.ax_joint.get_xticks()
xticklabels = [int(10**x) for x in xticks]
ax.ax_joint.set_xticklabels(xticklabels)

# Set legend
sns.move_legend(ax.ax_joint, title='Checkv quality',  markerscale=1, loc="lower right",fontsize=10,title_fontsize=12)

# # Save the figure as png and svg files
# ax.figure.savefig(output_filtered_vOTUs_png, format="png", bbox_inches = "tight",transparent=True)
# ax.figure.savefig(output_filtered_vOTUs_svg, format="svg", bbox_inches = "tight",transparent=True)
# plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
# plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title
# Show the plot
plt.show()
# Out:
# /home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages/seaborn/axisgrid.py:1832: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   func(x=self.x, y=self.y, **kwargs)
# /home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages/seaborn/axisgrid.py:1883: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
# /home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages/seaborn/axisgrid.py:1889: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   func(y=self.y, ax=self.ax_marg_y, **kwargs)
# /home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages/seaborn/axisgrid.py:1832: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   func(x=self.x, y=self.y, **kwargs)
# /tmp/ipykernel_503599/3320886259.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.ax_joint.set_xticklabels(xticklabels)

# %%
df_merged_filtered_abundance.groupby("checkv_quality").size().to_frame()
# Out:
#                   0
# checkv_quality
# Complete         20
# High-quality     54
# Low-quality     328
# Medium-quality   95
# Not-determined    4

# %%
fig, ax = plt.subplots(figsize=(8,8))

df_quality_counts=df_merged_filtered_abundance.groupby('checkv_quality').size()
df_quality_counts=df_quality_counts.reindex(['Complete','High-quality', 'Medium-quality','Low-quality','Not-determined']).fillna(0)

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


explode = (0.3, 0.2, 0.1, 0, 0)


mycolors=["#d4dbba","#ebeddd","#372f69","#efeff7","#e0cf94"]

plt.pie(df_quality_counts, labels=df_quality_counts.index, autopct=make_autopct(df_quality_counts), explode=explode, textprops={'fontsize': 12}, colors=mycolors)

plt.show()
