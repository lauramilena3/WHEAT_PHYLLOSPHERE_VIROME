# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpqa7r3v42/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95}M\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/FIGURES_AND_TABLES/01_qc_read_counts_paired.tot.csv\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/95-85_positive_viral_contigs.tot.fasta\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/checkV_merged_quality_summary.tot.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_circular.tot.csv\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_list.tot.csv\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_positive_quality.tot.csv\x94\x8ct/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VIBRANT_95-85_positive_viral_contigs_summary_results.tot.csv\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/final-viral-score.tsv\x94\x8c|/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/VirSorter2_95-85_positive_viral_contigs_tot/positive_VS_list_tot.txt\x94\x8c\xbc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_virus_summary.tsv\x94\x8c\xbe/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/95-85_positive_viral_contigs.tot_plasmid_summary.tsv\x94\x8c\xc0/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs.tot.fasta\x94\x8c\xcd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/geNomad_95-85_positive_viral_contigs_tot/95-85_positive_viral_contigs.tot_summary/formatted_viral_95-85_positive_viral_contigs_conservative.tot.fasta\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vBRB_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vBRB_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1C_T_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1aB_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF1aB_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF23_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2C_T_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2aA_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF2aA_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vF3C_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vFL_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vFL_amp_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN1_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN1_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN2_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN2_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN3_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vN3_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vNW_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vNW_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vNWd_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vNWd_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1C_T_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1aB_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO1aB_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2C_T_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2aA_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO2aA_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3A_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3A_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vO3C_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vOL_unfiltered_contigs.tot.txt\x94\x8c\x83/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vOL_amp_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS1B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS1B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS1C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS1C_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS2B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS2B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS2C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS2C_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS3B_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS3B_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS3C_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vS3C_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSE_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSE_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSEd_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSEd_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSW_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSW_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSWd_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vSWd_T_unfiltered_contigs.tot.txt\x94\x8c\x80/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vWRB_unfiltered_contigs.tot.txt\x94\x8c\x82/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vWRB_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ1_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ1_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ2_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ2_T_unfiltered_contigs.tot.txt\x94\x8c\x7f/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ3_unfiltered_contigs.tot.txt\x94\x8c\x81/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_flagstats_filtered_vZ3_T_unfiltered_contigs.tot.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x10df_counts_paired\x94K\x00N\x86\x94\x8c\x11vOTUs_prefiltered\x94K\x01N\x86\x94\x8c\x0emerged_summary\x94K\x02N\x86\x94\x8c\x10vibrant_circular\x94K\x03N\x86\x94\x8c\x10vibrant_positive\x94K\x04N\x86\x94\x8c\x0fvibrant_quality\x94K\x05N\x86\x94\x8c\x0fvibrant_summary\x94K\x06N\x86\x94\x8c\x0fvirsorter_table\x94K\x07N\x86\x94\x8c\x17virsorter_positive_list\x94K\x08N\x86\x94\x8c\x15genomad_virus_summary\x94K\tN\x86\x94\x8c\x17genomad_plasmid_summary\x94K\nN\x86\x94\x8c\x13genomad_viral_fasta\x94K\x0bN\x86\x94\x8c genomad_viral_fasta_conservative\x94K\x0cN\x86\x94\x8c\x0emap_unfiltered\x94K\rKf\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x91\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x97)}\x94\x8c\x05_name\x94h\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bhsh\nhuh\x0bhwh\x0chyh\rh{h\x0eh}h\x0fh\x7fh\x10h\x81h\x11h\x83h\x12h\x85h\x13h\x87h\x14h\x89h\x15h\x8bh\x16h\x8dh\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhchdhehfhghhhihjhkhlhmhnhoe}\x94(hq}\x94h\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/vOTU_clustering_summary.tot.csv\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/05_vOTUs/filtered_95-85_positive_viral_contigs_list.tot.txt\x94e}\x94(hq}\x94(\x8c\x07summary\x94K\x00N\x86\x94\x8c\rfiltered_list\x94K\x01N\x86\x94uh\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bh\xb7h\xb3h\xb9h\xb4ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(\x8c\x04vBRB\x94\x8c\x06vBRB_T\x94\x8c\x04vF1A\x94\x8c\x06vF1A_T\x94\x8c\x04vF1B\x94\x8c\x06vF1B_T\x94\x8c\x04vF1C\x94\x8c\x06vF1C_T\x94\x8c\x05vF1aB\x94\x8c\x07vF1aB_T\x94\x8c\x04vF23\x94\x8c\x04vF2A\x94\x8c\x06vF2A_T\x94\x8c\x04vF2B\x94\x8c\x06vF2B_T\x94\x8c\x04vF2C\x94\x8c\x06vF2C_T\x94\x8c\x05vF2aA\x94\x8c\x07vF2aA_T\x94\x8c\x04vF3A\x94\x8c\x06vF3A_T\x94\x8c\x04vF3B\x94\x8c\x06vF3B_T\x94\x8c\x04vF3C\x94\x8c\x06vF3C_T\x94\x8c\x03vFL\x94\x8c\x07vFL_amp\x94\x8c\x03vN1\x94\x8c\x05vN1_T\x94\x8c\x03vN2\x94\x8c\x05vN2_T\x94\x8c\x03vN3\x94\x8c\x05vN3_T\x94\x8c\x03vNW\x94\x8c\x05vNW_T\x94\x8c\x04vNWd\x94\x8c\x06vNWd_T\x94\x8c\x04vO1A\x94\x8c\x06vO1A_T\x94\x8c\x04vO1B\x94\x8c\x06vO1B_T\x94\x8c\x04vO1C\x94\x8c\x06vO1C_T\x94\x8c\x05vO1aB\x94\x8c\x07vO1aB_T\x94\x8c\x04vO2A\x94\x8c\x06vO2A_T\x94\x8c\x04vO2B\x94\x8c\x06vO2B_T\x94\x8c\x04vO2C\x94\x8c\x06vO2C_T\x94\x8c\x05vO2aA\x94\x8c\x07vO2aA_T\x94\x8c\x04vO3A\x94\x8c\x06vO3A_T\x94\x8c\x04vO3B\x94\x8c\x06vO3B_T\x94\x8c\x04vO3C\x94\x8c\x06vO3C_T\x94\x8c\x03vOL\x94\x8c\x07vOL_amp\x94\x8c\x04vS1B\x94\x8c\x06vS1B_T\x94\x8c\x04vS1C\x94\x8c\x06vS1C_T\x94\x8c\x04vS2B\x94\x8c\x06vS2B_T\x94\x8c\x04vS2C\x94\x8c\x06vS2C_T\x94\x8c\x04vS3B\x94\x8c\x06vS3B_T\x94\x8c\x04vS3C\x94\x8c\x06vS3C_T\x94\x8c\x03vSE\x94\x8c\x05vSE_T\x94\x8c\x04vSEd\x94\x8c\x06vSEd_T\x94\x8c\x03vSW\x94\x8c\x05vSW_T\x94\x8c\x04vSWd\x94\x8c\x06vSWd_T\x94\x8c\x04vWRB\x94\x8c\x06vWRB_T\x94\x8c\x03vZ1\x94\x8c\x05vZ1_T\x94\x8c\x03vZ2\x94\x8c\x05vZ2_T\x94\x8c\x03vZ3\x94\x8c\x05vZ3_T\x94e\x8c9/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/03_CONTIGS\x94\x8c:/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/04_VIRAL_ID\x94\x8c9/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING\x94\x88\x89M\x88\x13]\x94(\x8c\x03vFL\x94\x8c\x03vOL\x94\x8c\x04vF23\x94\x8c\x03vN1\x94\x8c\x03vN2\x94\x8c\x03vN3\x94\x8c\x03vZ1\x94\x8c\x03vZ2\x94\x8c\x03vZ3\x94\x8c\x04vF1A\x94\x8c\x04vF2A\x94\x8c\x04vF3A\x94\x8c\x04vF1B\x94\x8c\x04vF2B\x94\x8c\x04vF3B\x94\x8c\x04vF1C\x94\x8c\x04vF2C\x94\x8c\x04vF3C\x94\x8c\x04vO1A\x94\x8c\x04vO2A\x94\x8c\x04vO3A\x94\x8c\x04vO1B\x94\x8c\x04vO2B\x94\x8c\x04vO3B\x94\x8c\x04vO1C\x94\x8c\x04vO2C\x94\x8c\x04vO3C\x94\x8c\x04vS1B\x94\x8c\x04vS2B\x94\x8c\x04vS3B\x94\x8c\x04vS1C\x94\x8c\x04vS2C\x94\x8c\x04vS3C\x94\x8c\x04vNWd\x94\x8c\x04vSWd\x94\x8c\x04vSEd\x94ee}\x94(hq}\x94(\x8c\x07samples\x94K\x00N\x86\x94\x8c\ncontig_dir\x94K\x01N\x86\x94\x8c\tviral_dir\x94K\x02N\x86\x94\x8c\x0bmapping_dir\x94K\x03N\x86\x94\x8c\x0bsubassembly\x94K\x04N\x86\x94\x8c\x0ecross_assembly\x94K\x05N\x86\x94\x8c\x0cmin_votu_len\x94K\x06N\x86\x94\x8c\x0bkey_samples\x94K\x07N\x86\x94uh\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bjL\x01\x00\x00h\xc8jN\x01\x00\x00j"\x01\x00\x00jP\x01\x00\x00j#\x01\x00\x00jR\x01\x00\x00j$\x01\x00\x00jT\x01\x00\x00\x88jV\x01\x00\x00\x89jX\x01\x00\x00M\x88\x13jZ\x01\x00\x00j%\x01\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x03tot\x94a}\x94(hq}\x94\x8c\x08sampling\x94K\x00N\x86\x94sh\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94b\x8c\x08sampling\x94ji\x01\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(hq}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bj\x80\x01\x00\x00K\x01j\x82\x01\x00\x00K\x01j\x84\x01\x00\x00j}\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/NOTEBOOKS/05_vOTU_filtering.tot.ipynb\x94a}\x94(hq}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x8f]\x94(h\x91h\x92eh\x91h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x91sNt\x94bh\x92h\x95h\x97\x85\x94R\x94(h\x97)}\x94h\x9bh\x92sNt\x94bj\x96\x01\x00\x00j\x93\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c:/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\necc_memory\x94M\x80>\x8c\x0bsubassembly\x94\x88\x8c\x1cadditional_reference_contigs\x94\x8cE/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/reference_phages.fasta\x94\x8c\x0eassembly_stats\x94\x88\x8c\x0bsubsampling\x94\x88\x8c\x0fmin_votu_length\x94M\x88\x13\x8c\x11microbial_spacers\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/BACTERIAL_FRACTION/07_ANNOTATION/minced_predicted_spacers_spacers.fa\x94\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\tVirSorter\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\x16representative_contigs\x94j\xb3\x01\x00\x00\x8c\x08sra_list\x94j\xb3\x01\x00\x00\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x11contaminants_list\x94j\xb3\x01\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x0bimgvr_blast\x94\x89\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x0crun_vcontact\x94\x89\x8c\x08run_DRAM\x94\x89\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x17get_list_filtered_vOTUs\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # FILTER

# %%
import pandas as pd
from Bio import SeqIO   
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import numpy as np 
import seaborn as sns

palette_quality = {
    "Complete": "#66CC99",
    "High-quality": "#66CC99",
    "Medium-quality": "#666699",
    "Low-quality": "#996699",
    "Not-determined": "#996699",
}

# Plotting preferences
sns.set_style(
    "ticks",
    {
        "axes.grid": True,
        "grid.color": "#BFBFBF",
        "grid.linestyle": "-",
        "grid.linewidth": 0.35,
        "axes.facecolor": "white",
        "figure.facecolor": "white",
    },
)
sns.set_palette("colorblind")

plt.rcParams.update({
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "savefig.facecolor": "white",
    "savefig.transparent": False,
    "savefig.bbox": "tight",
    "axes.linewidth": 0.7,
    "axes.edgecolor": "#222222",
    "xtick.major.width": 0.7,
    "ytick.major.width": 0.7,
    "xtick.minor.width": 0.5,
    "ytick.minor.width": 0.5,
    "xtick.major.size": 4.5,
    "ytick.major.size": 4.5,
    "xtick.minor.size": 2.5,
    "ytick.minor.size": 2.5,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "grid.linewidth": 0.35,
    "grid.alpha": 0.8,
    "patch.linewidth": 0.7,
    "lines.linewidth": 1.0,
    "lines.markersize": 4,
    "font.family": "sans-serif",
    "font.sans-serif": ["Liberation Sans"],
    "text.usetex": False,
    "font.size": 5,
    "axes.titlepad": 5,
    "axes.titlesize": 7,
    "axes.labelsize": 7,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.labelweight": "bold",
    "axes.titleweight": "bold",
    "legend.frameon": True,
    "legend.fancybox": False,
    "legend.framealpha": 1.0,
    "legend.edgecolor": "#444444",
    "legend.facecolor": "white",
    "legend.fontsize": 5,
    "legend.title_fontsize": 6,
    "savefig.dpi": 300,
    "figure.dpi": 150,
    "svg.fonttype": "none",
})

# %%
input_df_counts_paired=snakemake.input.df_counts_paired
input_merged_summary=snakemake.input.merged_summary
input_vOTUs_prefiltered=snakemake.input.vOTUs_prefiltered
input_vibrant_circular=snakemake.input.vibrant_circular
input_vibrant_positive=snakemake.input.vibrant_positive
input_vibrant_quality=snakemake.input.vibrant_quality
input_vibrant_summary=snakemake.input.vibrant_summary
input_virsorter_table=snakemake.input.virsorter_table
input_virsorter_positive_list=snakemake.input.virsorter_positive_list
input_genomad_virus_summary=snakemake.input.genomad_virus_summary
input_genomad_plasmid_summary=snakemake.input.genomad_plasmid_summary
input_genomad_viral_fasta=snakemake.input.genomad_viral_fasta
input_genomad_viral_fasta_conservative=snakemake.input.genomad_viral_fasta_conservative
#________
output_summary=snakemake.output.summary
output_filtered_list=snakemake.output.filtered_list

SAMPLES=snakemake.params.samples
min_votu_len=10000
SAMPLES_key=snakemake.params.key_samples

# %%
# Initialize an empty list to hold individual DataFrames
df_list = []

# Loop over each sample and process data
for sample in SAMPLES_key:
    # Load unfiltered coverage stats
    print(sample)
    covstats_unf = pd.read_csv(f"/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/STATS_FILES/bowtie2_{sample}_unfiltered_contigs.tot_covstats.txt", sep="\t", index_col=0)
    covstats_unf = covstats_unf[[f"bowtie2_{sample}_unfiltered_contigs_tot_filtered Read Count"]]
    
    covstats_unf.columns = [sample]
    df_list.append(covstats_unf)

# Concatenate all DataFrames at once along the columns axis
combined_reads_u = pd.concat(df_list, axis=1)

# Display or use the combined DataFrame
combined_reads_u.head()

# Calculate count DataFrame as before
count_df = (combined_reads_u > 1).sum(axis=1).to_frame()
mapped_contigs = list(count_df[count_df[0] > 0].index)

# %%
# Create an empty list to store vOTU names
vOTU_list = []

# Iterate over records in input_vOTUs_prefiltered file and append record IDs to the list
for record in SeqIO.parse(input_vOTUs_prefiltered, "fasta"):
    vOTU_list.append(record.id)

# Create a DataFrame with vOTU names
vOTU_prefiltered = pd.DataFrame(vOTU_list, columns=["vOTU_name"])

# Read data from input_merged_summary file into checkv_df DataFrame with specified column names
checkv_df = pd.read_csv(input_merged_summary, sep="\t", names=["checkV_contig_id", "checkV_contig_length", "checkV_provirus",
                                                                "checkV_proviral_length", "checkV_gene_count", "checkV_viral_genes",
                                                                "checkV_host_genes", "checkv_quality", "checkV_miuvig_quality",
                                                                "checkV_completeness", "checkV_completeness_method", "checkV_contamination",
                                                                "checkV_kmer_freq", "checkV_warnings"])
checkv_df=checkv_df.groupby(["checkV_contig_id"]).first().reset_index()

# Read data from input_vibrant_circular file into vibrant_circular_df DataFrame with a single column name
vibrant_circular_df = pd.read_csv(input_vibrant_circular, names=["VIBRANT_circular_name"])
vibrant_circular_df["VIBRANT_circular"] = "Y"

# Read data from input_vibrant_positive file into vibrant_positive_df DataFrame with a single column name
vibrant_positive_df = pd.read_csv(input_vibrant_positive, names=["VIBRANT_positive_name"])
vibrant_positive_df["VIBRANT_positive"] = "Y"

# Read data from input_vibrant_quality file into vibrant_quality_df DataFrame with specific column names
vibrant_quality_df = pd.read_csv(input_vibrant_quality, sep="\t")
vibrant_quality_df.columns = ["VIBRANT_scaffold", "VIBRANT_lifecycle", "VIBRANT_quality"]
vibrant_quality_df = vibrant_quality_df.groupby("VIBRANT_scaffold").first()

# Read data from input_vibrant_summary file into vibrant_summary_df DataFrame with modified column names
vibrant_summary_df = pd.read_csv(input_vibrant_summary, sep="\t")
vibrant_summary_df.columns = ['VIBRANT_' + str(col).replace(" ", "_") for col in vibrant_summary_df.columns]

# Read data from input_virsorter_table file into virsorter_summary_df DataFrame with modified column names
virsorter_summary_df = pd.read_csv(input_virsorter_table, sep="\t")
virsorter_summary_df.columns = ['VirSorter2_' + str(col).replace(" ", "_") for col in virsorter_summary_df.columns]
virsorter_summary_df["VirSorter2_positive"] = "Y"

# Read data from input_genomad_virus_summary file into genomad_summary_df DataFrame with modified column names
genomad_summary_df = pd.read_csv(input_genomad_virus_summary, sep="\t")
genomad_summary_df.columns = ['geNomad_' + str(col).replace(" ", "_") for col in genomad_summary_df.columns]

# Create an empty list to store viral names
viral_list = []

# Iterate over records in input_genomad_viral_fasta file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta, "fasta"):
    viral_list.append(record.id)

# Create a DataFrame with viral names
geNomad_viral = pd.DataFrame(viral_list, columns=["geNomad_viral_name"])
geNomad_viral["geNomad_viral"] = "Y"

# Create an empty list to store conservative viral names
viral_list_conservative = []

# Iterate over records in input_genomad_viral_fasta_conservative file and append record IDs to the list
for record in SeqIO.parse(input_genomad_viral_fasta_conservative, "fasta"):
    viral_list_conservative.append(record.id)

# Create a DataFrame with conservative viral names
geNomad_viral_conservative = pd.DataFrame(viral_list_conservative, columns=["geNomad_viral_conservative_name"])
geNomad_viral_conservative["geNomad_viral_conservative"] = "Y"

# %%
# Merge vOTU_prefiltered with vibrant_circular_df based on vOTU_name and VIBRANT_circular_name columns
df_temp1 = vOTU_prefiltered.merge(vibrant_circular_df, left_on="vOTU_name", right_on="VIBRANT_circular_name", how="left")

# Merge df_temp1 with vibrant_positive_df based on vOTU_name and VIBRANT_positive_name columns
df_temp2 = df_temp1.merge(vibrant_positive_df, left_on="vOTU_name", right_on="VIBRANT_positive_name", how="left")

# Merge df_temp2 with vibrant_quality_df based on vOTU_name and VIBRANT_scaffold columns
df_temp3 = df_temp2.merge(vibrant_quality_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp3 with vibrant_summary_df based on vOTU_name and VIBRANT_scaffold columns
df_temp4 = df_temp3.merge(vibrant_summary_df, left_on="vOTU_name", right_on="VIBRANT_scaffold", how="left")

# Merge df_temp4 with virsorter_summary_df based on vOTU_name and VirSorter2_seqname columns
df_temp5 = df_temp4.merge(virsorter_summary_df, left_on="vOTU_name", right_on="VirSorter2_seqname", how="left")

# Merge df_temp5 with genomad_summary_df based on vOTU_name and geNomad_seq_name columns
df_temp6 = df_temp5.merge(genomad_summary_df, left_on="vOTU_name", right_on="geNomad_seq_name", how="left")

# Merge df_temp6 with geNomad_viral based on vOTU_name and geNomad_viral_name columns
df_temp7 = df_temp6.merge(geNomad_viral, left_on="vOTU_name", right_on="geNomad_viral_name", how="left")

# Merge df_temp7 with geNomad_viral_conservative based on vOTU_name and geNomad_viral_conservative_name columns
df_temp8 = df_temp7.merge(geNomad_viral_conservative, left_on="vOTU_name", right_on="geNomad_viral_conservative_name", how="left")

# Merge df_temp8 with checkv_df based on vOTU_name and checkV_contig_id columns
df_merged = df_temp8.merge(checkv_df, left_on="vOTU_name", right_on="checkV_contig_id", how="left")

# Drop unnecessary columns from df_merged
df_merged = df_merged.drop(["VIBRANT_circular_name", "VIBRANT_positive_name", "VIBRANT_scaffold", "checkV_contig_id"], axis=1)

# Return the merged DataFrame
df_merged

# %%
df=df_merged[["VirSorter2_positive","VIBRANT_positive","geNomad_viral","geNomad_viral_conservative"]]

# Get the counts for each category
a_count = df['VirSorter2_positive'].value_counts()['Y']
b_count = df['VIBRANT_positive'].value_counts()['Y']
c_count = df['geNomad_viral'].value_counts()['Y']
ab_count = df[df['VirSorter2_positive'] == 'Y']['VIBRANT_positive'].value_counts()['Y']
ac_count = df[df['VirSorter2_positive'] == 'Y']['geNomad_viral'].value_counts()['Y']
bc_count = df[(df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']
abc_count = df[(df['VirSorter2_positive'] == 'Y') & (df['VIBRANT_positive'] == 'Y') & (df['geNomad_viral'] == 'Y')]['VIBRANT_positive'].value_counts()['Y']

# Create the Venn diagram
venn_labels = {'100': a_count - ab_count - ac_count + abc_count,
               '010': b_count - ab_count - bc_count + abc_count,
               '001': c_count - ac_count - bc_count + abc_count,
               '110': ab_count - abc_count,
               '101': ac_count - abc_count,
               '011': bc_count - abc_count,
               '111': abc_count}

plt.figure(figsize=(8, 6))
venn_diagram = venn3(subsets=venn_labels, set_labels=('VirSorter2', 'VIBRANT', 'geNomad'))

# Add the counts to the Venn diagram
for text in venn_diagram.set_labels:
    text.set_fontsize(14)
for text in venn_diagram.subset_labels:
    if text:
        text.set_fontsize(12)

# Show the Venn diagram
# plt.title("Venn Diagram of Categories 'VirSorter2_positive', 'VIBRANT_positive', and 'geNomad_viral'")
plt.show()

# %%
# Define columns to count
columns_to_count = ["VirSorter2_positive", "VIBRANT_positive", "geNomad_viral"]

# Count the number of 'Y' occurrences in columns specified in columns_to_count and store the result in a new column 'count_Y'
df_merged['count_Y'] = df_merged[columns_to_count].eq('Y').sum(axis=1)

# Define the desired column order in the DataFrame
move_cols = ["vOTU_name", "count_Y", "checkV_contig_length", "VirSorter2_positive", "VIBRANT_positive", "geNomad_viral", "geNomad_viral_conservative"]

# Reorder the columns in df_merged according to move_cols and keep the remaining columns in their original order
df_merged = df_merged[move_cols + [col for col in df_merged.columns if col not in move_cols]]

# Create a filtered DataFrame by applying conditions on count_Y and checkV_contig_length columns
df_merged_filtered =df_merged[
    ((df_merged["count_Y"] == 3) | (df_merged["geNomad_viral_conservative"] == "Y")) & 
    ((df_merged["checkV_contig_length"] >= min_votu_len) | (df_merged["checkV_miuvig_quality"] == "High-quality")) ]

df_merged_filtered_abundance=df_merged_filtered[(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=df_merged[
    ((df_merged["count_Y"] != 3) & (df_merged["geNomad_viral_conservative"] != "Y")) |
    ((df_merged["checkV_contig_length"] < min_votu_len) & (df_merged["checkV_miuvig_quality"] != "High-quality"))]

df_merged_removed_abundance=df_merged_filtered[~(df_merged_filtered.vOTU_name.isin(mapped_contigs))]

df_merged_removed=pd.concat([df_merged_removed,df_merged_removed_abundance])

# Write the values in the 'vOTU_name' column to output_filtered_list file without the index and header
df_merged_filtered_abundance["vOTU_name"].to_csv(output_filtered_list, index=False, header=False)

# Write df_merged_filtered_abundance to output_summary file
df_merged_filtered_abundance.to_csv(output_summary)

# df_merged_removed
print("all\t\t", len(df_merged))
print("selected\t",len(df_merged_filtered_abundance))
print("removed\t\t",len(df_merged_removed))

print("sum\t\t",len(df_merged_filtered_abundance)+len(df_merged_removed) )

# %%
df_merged_removed["checkV_contig_length_log"]=np.log10(df_merged_removed["checkV_contig_length"])


# Plot the data as a distribution plot
ax = sns.jointplot(data=df_merged_removed,x="checkV_contig_length_log",y="checkV_completeness", hue="checkv_quality", alpha=1,height=3.2,palette=palette_quality, marker="+")
ax.plot_joint(sns.kdeplot)

# Set x- and y-axis labels  
ax.ax_joint.set_xlabel('Contig length')
ax.ax_joint.set_ylabel('CheckV completness')
ax.ax_joint.set_ylim(0,100)
ax.ax_joint.set_xlim(3,5)

# Set the x-ticks and y-ticks to powers of 10
# x-ticks
xticks = ax.ax_joint.get_xticks()
xticklabels = [int(10**x) for x in xticks]
ax.ax_joint.set_xticklabels(xticklabels)

# Set legend
sns.move_legend(ax.ax_joint, title='Checkv quality',  markerscale=1, loc="lower right",fontsize=7,title_fontsize=7)

# # Save the figure as png and svg files
# ax.figure.savefig(output_filtered_vOTUs_png, format="png", bbox_inches = "tight",transparent=True)
# ax.figure.savefig(output_filtered_vOTUs_svg, format="svg", bbox_inches = "tight",transparent=True)
# Show the plot
plt.show()

# %%
df_merged_filtered_abundance.groupby("checkv_quality").size().to_frame()

# %%
fig, ax = plt.subplots(figsize=(3, 3))

df_quality_counts=df_merged_filtered_abundance.groupby('checkv_quality').size()
df_quality_counts=df_quality_counts.reindex(['Complete','High-quality', 'Medium-quality','Low-quality','Not-determined'])

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


explode = (0.3, 0.2, 0.1, 0, 0)


mycolors=[palette_quality[label] for label in df_quality_counts.index]

plt.pie(df_quality_counts, labels=df_quality_counts.index, autopct=make_autopct(df_quality_counts), explode=explode, textprops={'fontsize': 6}, colors=mycolors)

plt.show()
# plt.savefig("/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/07_ANNOTATION/quality_pie_vOTUs.svg")
