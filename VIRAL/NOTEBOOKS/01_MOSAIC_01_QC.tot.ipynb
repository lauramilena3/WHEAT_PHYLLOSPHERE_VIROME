# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/anaconda3/envs/Mosaic_workflow/lib/python3.9/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpbjs_r_gg/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95`\x00\x01\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF23_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_amp_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_amp_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF23_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_amp_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_amp_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_T_R2_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_merged_unpaired.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_merged_unpaired.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_merged_unpaired.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_merged_unpaired.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_merged_unpaired.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_merged_unpaired.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_unpaired_noEuk.tot_read_count.txt\x94\x95C\x00\x01\x00\x00\x00\x00\x00\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_unpaired_noEuk.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_unpaired_noEuk.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_unpaired_noEuk.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_unpaired_noEuk.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_unpaired_noEuk.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_unpaired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_unpaired_clean.tot_read_count.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_unpaired_clean.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_unpaired_clean.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_unpaired_clean.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_unpaired_clean.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_unpaired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_norm.tot_read_count.txt\x94e(\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_unpaired_norm.tot_read_count.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_unpaired_norm.tot_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_unpaired_norm.tot_read_count.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_unpaired_norm.tot_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_unpaired_norm.tot_read_count.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_unpaired_norm.tot_read_count.txt\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_kmer_histogram.tot.csv\x94\x95\x06\x00\x01\x00\x00\x00\x00\x00\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_kmer_histogram.tot.csv\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_kmer_histogram.tot.csv\x94\x8cX/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_kmer_histogram.tot.csv\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_kmer_histogram.tot.csv\x94\x8cW/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_kmer_histogram.tot.csv\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_kmer_histogram.tot.csv\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/preQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/postQC_illumina_report_data/multiqc_fastqc.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF23_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_amp_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_T_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_R1_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_amp_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_R1_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_T_R1_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_R1_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_T_R1_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vBRB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF1aB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF23_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF2aA_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vF3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vFL_amp_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN1_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN2_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vN3_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNW_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vNWd_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO1aB_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2C_T_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO2aA_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3A_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vO3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_R2_read_count.txt\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vOL_amp_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS1C_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS2C_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3B_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vS3C_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSE_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSEd_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSW_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vSWd_T_R2_read_count.txt\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_R2_read_count.txt\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vWRB_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ1_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ2_T_R2_read_count.txt\x94\x8cP/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_R2_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA/vZ3_T_R2_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_read_count.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_read_count.txt\x94\x8c_/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_read_count.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_read_count.txt\x94\x8c^/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_read_count.txt\x94\x8c`/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_noEuk.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_noEuk.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_noEuk.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_noEuk.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_clean.tot_read_count.txt\x94\x95\x01\x00\x01\x00\x00\x00\x00\x00\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_clean.tot_read_count.txt\x94e(\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_clean.tot_read_count.txt\x94\x8cl/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_clean.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_clean.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_clean.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_clean.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_forward_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_forward_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_forward_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_forward_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_forward_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_reverse_paired_norm.tot_read_count.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_reverse_paired_norm.tot_read_count.txt\x94\x8ch/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_reverse_paired_norm.tot_read_count.txt\x94\x8cj/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_reverse_paired_norm.tot_read_count.txt\x94\x8cg/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_reverse_paired_norm.tot_read_count.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_reverse_paired_norm.tot_read_count.txt\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vBRB_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vBRB_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1C_T_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1aB_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF1aB_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF23_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2C_T_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2aA_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF2aA_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vF3C_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vFL_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vFL_amp_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN1_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN1_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN2_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN2_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN3_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vN3_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vNW_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vNW_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vNWd_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vNWd_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1C_T_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1aB_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO1aB_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2C_T_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2aA_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO2aA_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3A_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3A_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vO3C_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vOL_stats_pcr_duplicates.log\x94\x8cU/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vOL_amp_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS1B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS1B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS1C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS1C_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS2B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS2B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS2C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS2C_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS3B_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS3B_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS3C_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vS3C_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSE_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSE_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSEd_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSEd_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSW_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSW_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSWd_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vSWd_T_stats_pcr_duplicates.log\x94\x8cR/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vWRB_stats_pcr_duplicates.log\x94\x8cT/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vWRB_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ1_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ1_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ2_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ2_T_stats_pcr_duplicates.log\x94\x8cQ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ3_stats_pcr_duplicates.log\x94\x8cS/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/vZ3_T_stats_pcr_duplicates.log\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_kmer_count_histogram_pre.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_kmer_count_histogram_pre.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_kmer_count_histogram_pre.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_kmer_count_histogram_pre.tot.txt\x94\x8ca/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_kmer_count_histogram_pre.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_kmer_count_histogram_post.tot.txt\x94\x8cf/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_kmer_count_histogram_post.tot.txt\x94\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_kmer_count_histogram_post.tot.txt\x94\x8ce/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_kmer_count_histogram_post.tot.txt\x94\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_kmer_count_histogram_post.tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_kmer_count_histogram_post.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vBRB_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1C_T_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF1aB_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF23_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2C_T_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF2aA_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vF3C_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vFL_amp_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN1_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN2_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vN3_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNW_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vNWd_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1C_T_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO1aB_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2C_T_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO2aA_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3A_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vO3C_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_kmer_count_peaks.tot.txt\x94\x8c]/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vOL_amp_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS1C_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS2C_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3B_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vS3C_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSE_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSEd_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSW_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vSWd_T_kmer_count_peaks.tot.txt\x94\x8cZ/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_kmer_count_peaks.tot.txt\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vWRB_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ1_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ2_T_kmer_count_peaks.tot.txt\x94\x8cY/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_kmer_count_peaks.tot.txt\x94\x8c[/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA/vZ3_T_kmer_count_peaks.tot.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\nhistograms\x94M\xde\x04M7\x05\x86\x94\x8c\tpreqc_txt\x94M7\x05N\x86\x94\x8c\npostqc_txt\x94M8\x05N\x86\x94\x8c\x16read_count_raw_forward\x94M9\x05M\x92\x05\x86\x94\x8c\x16read_count_raw_reverse\x94M\x92\x05M\xeb\x05\x86\x94\x8c\x1aread_count_trimmed_forward\x94M\xeb\x05MD\x06\x86\x94\x8c\x1aread_count_trimmed_reverse\x94MD\x06M\x9d\x06\x86\x94\x8c\x16read_count_euk_forward\x94M\x9d\x06M\xf6\x06\x86\x94\x8c\x16read_count_euk_reverse\x94M\xf6\x06MO\x07\x86\x94\x8c\x16read_count_duk_forward\x94MO\x07M\xa8\x07\x86\x94\x8c\x16read_count_duk_reverse\x94M\xa8\x07M\x01\x08\x86\x94\x8c\x17read_count_norm_forward\x94M\x01\x08MZ\x08\x86\x94\x8c\x17read_count_norm_reverse\x94MZ\x08M\xb3\x08\x86\x94\x8c\x0csupper_dedup\x94M\xb3\x08M\x0c\t\x86\x94\x8c\x12histogram_kmer_pre\x94M\x0c\tMe\t\x86\x94\x8c\x13histogram_kmer_post\x94Me\tM\xbe\t\x86\x94\x8c\tpeak_kmer\x94M\xbe\tM\x17\n\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ejH\n\x00\x00\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(jN\n\x00\x00)}\x94\x8c\x05_name\x94jH\n\x00\x00sNt\x94bjI\n\x00\x00jL\n\x00\x00jN\n\x00\x00\x85\x94R\x94(jN\n\x00\x00)}\x94jR\n\x00\x00jI\n\x00\x00sNt\x94bj$\n\x00\x00h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94
x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x0crun_vcontact\x94\x89\x8c\x08run_DRAM\x94\x89\x8c\x0bimgvr_blast\x94\x89\x8c\necc_memory\x94Mp\x17\x8c\x16representative_contigs\x94j%\x0c\x00\x00\x8c\x08sra_list\x94j%\x0c\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x0fmin_votu_length\x94M\x88\x13\x8c\x11contaminants_list\x94j%\x0c\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x11microbial_spacers\x94j%\x0c\x00\x00\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94N\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\nQC_parsing\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Quality Control

# %%
# import necessary modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.colors import LinearSegmentedColormap
import json
import numpy as np

#------------------------------------------
# Create a list of colors
colors_rarefaction=sns.color_palette("colorblind", n_colors=len(list(snakemake.params.samples))+1)
# Create a LinearSegmentedColormap object
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


# Plotting preferences
sns.set_style(
    "ticks",
    {
        "axes.grid": True,
        "grid.color": "#BFBFBF",
        "grid.linestyle": "-",
        "grid.linewidth": 0.35,
        "axes.facecolor": "white",
        "figure.facecolor": "white",
    },
)
sns.set_palette("colorblind")

plt.rcParams.update({
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "savefig.facecolor": "white",
    "savefig.transparent": False,
    "savefig.bbox": "tight",
    "axes.linewidth": 0.7,
    "axes.edgecolor": "#222222",
    "xtick.major.width": 0.7,
    "ytick.major.width": 0.7,
    "xtick.minor.width": 0.5,
    "ytick.minor.width": 0.5,
    "xtick.major.size": 4.5,
    "ytick.major.size": 4.5,
    "xtick.minor.size": 2.5,
    "ytick.minor.size": 2.5,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "grid.linewidth": 0.35,
    "grid.alpha": 0.8,
    "patch.linewidth": 0.7,
    "lines.linewidth": 1.0,
    "lines.markersize": 4,
    "font.family": "sans-serif",
    "font.sans-serif": ["Liberation Sans"],
    "text.usetex": False,
    "font.size": 5,
    "axes.titlepad": 5,
    "axes.titlesize": 7,
    "axes.labelsize": 7,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.labelweight": "bold",
    "axes.titleweight": "bold",
    "legend.frameon": True,
    "legend.fancybox": False,
    "legend.framealpha": 1.0,
    "legend.edgecolor": "#444444",
    "legend.facecolor": "white",
    "legend.fontsize": 5,
    "legend.title_fontsize": 6,
    "savefig.dpi": 300,
    "figure.dpi": 150,
    "svg.fonttype": "none",
})

# %%
clean_dir=snakemake.params.clean_dir
raw_dir=snakemake.params.raw_dir
qc_dir=snakemake.params.qc_dir

SAMPLE_PLOT_LIM_LEGEND=100
SAMPLE_PLOT_LIM=200

SAMPLES=list(snakemake.params.samples)
forward_tag="_" + str(snakemake.params.forward_tag)
reverse_tag="_" +str( snakemake.params.reverse_tag)

input_histograms=list(snakemake.input.histograms)
input_histograms_pre=list(snakemake.input.histogram_kmer_pre)
input_histograms_post=list(snakemake.input.histogram_kmer_post)
# input_peak_kmer=list(snakemake.input.peak_kmer)

input_histograms.sort()
input_histograms_pre.sort()
input_histograms_post.sort()


if len(input_histograms)>SAMPLE_PLOT_LIM:
   input_histograms=input_histograms[:SAMPLE_PLOT_LIM]

if len(input_histograms_pre)>SAMPLE_PLOT_LIM:
   input_histograms_pre=input_histograms_pre[:SAMPLE_PLOT_LIM]

if len(input_histograms_post)>SAMPLE_PLOT_LIM:
   input_histograms_post=input_histograms_post[:SAMPLE_PLOT_LIM]

illumina_preqc=snakemake.input.preqc_txt
illumina_postqc=snakemake.input.postqc_txt
#------------------------------------------
output_kmer_png=snakemake.output.kmer_png
output_kmer_svg=snakemake.output.kmer_svg
output_kmer_png_fitted=snakemake.output.kmer_fit_png
output_kmer_svg_fitted=snakemake.output.kmer_fit_svg
output_kmer_fit_html=snakemake.output.kmer_fit_html
output_kmer_dist_pre_png=snakemake.output.kmer_dist_pre_png
output_kmer_dist_pre_svg=snakemake.output.kmer_dist_pre_svg
output_kmer_dist_post_png=snakemake.output.kmer_dist_post_png
output_kmer_dist_post_svg=snakemake.output.kmer_dist_post_svg

output_qc_summary_html=snakemake.output.qc_summary_html
output_percentage_kept_reads_png=snakemake.output.percentage_kept_reads_png
output_percentage_kept_reads_svg=snakemake.output.percentage_kept_reads_svg
output_percentage_kept_Mbp_png=snakemake.output.percentage_kept_Mbp_png
output_percentage_kept_Mbp_svg=snakemake.output.percentage_kept_Mbp_svg
output_step_qc_reads_html=snakemake.output.step_qc_reads_html
output_steps_qc_reads_png=snakemake.output.steps_qc_reads_png
output_steps_qc_reads_svg=snakemake.output.steps_qc_reads_svg
output_steps_qc_percentage_png=snakemake.output.steps_qc_percentage_png
output_steps_qc_percentage_svg=snakemake.output.steps_qc_percentage_svg
output_df_counts_paired=snakemake.output.df_counts_paired
output_supperdedupper_html=snakemake.output.supperdedupper_html
output_supperdedupper_png=snakemake.output.supperdedupper_png
output_supperdedupper_svg=snakemake.output.supperdedupper_svg

# %% [markdown]
# ## KMER rarefraction

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Sort input_histograms and SAMPLES
input_histograms.sort()
SAMPLES.sort()

# Initialize variables
n = 1
read_max = 0

# Create a single plot
fig, ax = plt.subplots()

# Loop through each histogram in input_histograms
for h in input_histograms:
    # Read the histogram file as a pandas dataframe
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Convert percent to percentage of missing kmers and counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000

    # Plot the data as a line plot
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, ax=ax)

    # Add a vertical line at the x-value corresponding to the maximum count
    max_count = df["counts"].max()
    plt.axvline(max_count, 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.3)
    read_max = max(read_max, max_count)

    # Increment n
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.2))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# # KMER rarefraction log fit

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define the number of million reads to trim
cut_million_reads = 5
trim_reads = int(cut_million_reads * 40)
max_read_fitting = 80

# Initialize variables
read_max = 0
n = 1
samples = []
a_list = []
b_list = []
max_reads = []
slope_list = []

# Define the logarithmic function used for fitting
def logFunc(x, a, b):
    return a + b * np.log(x)

# Create a single plot
fig, ax = plt.subplots()

# Loop through input histograms
for h in input_histograms:
    # Load the data from the current input histogram
    df = pd.read_csv(h, sep="\t", usecols=["#count", "first"])
    df.columns=["counts", "percent"]
    
    # Calculate the percentage of known k-mers and convert the counts to millions of reads
    df["percent"] = 100 - df["percent"]
    df["counts"] = df["counts"] / 1000000

    # Plot the original data
    sns.lineplot(x="counts", y="percent", data=df, err_style='band', color=colors_rarefaction[n], 
                 label=h.split("/")[-1].split("_kmer")[0], linewidth=0.5, alpha=0.8, ax=ax)

    # Keep track of the maximum read count
    read_max = max(read_max, df["counts"].max())

    # If there are enough data points, fit a logarithmic function to the tail of the data
    if len(df["counts"]) > trim_reads + 1:
        # Subsample pandas dataframe every half million reads
        subsample_rate_mreads = 0.1
        subsample_size = int(subsample_rate_mreads * 40)
        df_subsampled = df[trim_reads:].iloc[::subsample_size, :]
        if len(df_subsampled) > 10:
            # Fit the function to the tail of the data
            popt, _ = curve_fit(logFunc, df_subsampled["counts"], df_subsampled["percent"])

            # Plot the fitted function
            sns.lineplot(x=np.arange(cut_million_reads, max_read_fitting, 0.25), 
                         y=logFunc(np.arange(cut_million_reads, max_read_fitting, 0.25), *popt), 
                         color=colors_rarefaction[n], err_style='band', linewidth=2, alpha=0.2, 
                         label='_nolegend_', ax=ax)

            # Store the fitting parameters and other statistics
            samples.append(h.split("/")[-1].split("_kmer")[0])
            a_list.append(popt[0])
            b_list.append(popt[1])
            max_reads.append(df["counts"].max())
            reads_to_1 = (popt[0] / popt[1])
            slope_list.append(popt[1] / df["counts"].max())

    # Add a vertical line to indicate the maximum read count
    plt.axvline(df["counts"].max(), 0, 1, linestyle="--", color=colors_rarefaction[n], alpha=0.4)

    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n += 1

# Set y- and x-axis limits, labels, and legend outside the loop
ax.set(ylim=(0, 110))
ax.set(xlim=(0, read_max * 1.5))
ax.set_xlabel("Read count (Million reads)")
ax.set_ylabel("Known k-mers (%)")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
fig.savefig(output_kmer_png_fitted, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_kmer_svg_fitted, format="svg", bbox_inches="tight", transparent=True)

# Display the plot
plt.show()

# %%
# create a new empty pandas DataFrame
stats_df=pd.DataFrame()

# add columns to the DataFrame using lists
stats_df["Sample"]=samples
stats_df["a"]=a_list
stats_df["b"]=b_list
stats_df["slope"]=slope_list
stats_df["M_reads"]=max_reads
stats_df["b_-_Mreads"]=stats_df["b"]-stats_df["M_reads"]

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
stats_df_out=stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn").render()

# write the HTML table to a file
with open(output_kmer_fit_html,"w") as fp:
    fp.write(stats_df_out)

# sort the DataFrame by "Sample" column and apply background color gradient to it
stats_df.sort_values(by="Sample").style.background_gradient(cmap="RdYlGn")

# %% [markdown]
# # Kmer count histogram (kmer size=31)

# %% [markdown]
# ## Pre normalization

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_pre.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_pre:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    print(f"{100*n/len(input_histograms):.2f}" + " %", end='\r', flush=True)
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_pre_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_pre_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ## Post normalization (target=100x)

# %%
# set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Sort input_histograms and print the sorted list
input_histograms_post.sort()

# Sort SAMPLES
SAMPLES.sort()

# Initialize n and read_max as 0
n=1

# Loop through each histogram in input_histograms
for h in input_histograms_post:
    # Read the histogram file as a pandas dataframe
    df=pd.read_csv(h, sep="\t")
    
    # Rename columns 
    df.columns=["Depth", "Raw count", "Unique kmers"]

     # Plot the data as a line plot
    ax = sns.lineplot(x="Depth", y="Raw count", data=df[:],err_style='band',color=colors_rarefaction[n], label=h.split("/")[-1].split("_kmer")[0], linewidth=1)

    # Set y- and x-axis scale
    ax.set_xscale('log')
    ax.set_yscale('log')
    
    # Increment the sample counter
    n = n+1

# Set x- and y-axis labels and legend
ax.set_xlabel("Depth (31mer)")
ax.set_ylabel("Raw Count")
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)
    
# Save the figure as png and svg files
ax.figure.savefig(output_kmer_dist_post_png, format="png", bbox_inches = "tight",transparent=True)
ax.figure.savefig(output_kmer_dist_post_svg, format="svg", bbox_inches = "tight",transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ## PreQC and PostQC FASTQC statistics

# %%
# load the pre- and post-illumina sequencing quality control data into pandas dataframes
preqc = pd.read_csv(illumina_preqc, sep="\t")
postqc = pd.read_csv(illumina_postqc, sep="\t")

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the preqc dataframe
read_stats_df1 = preqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df1
read_stats_df1["Mbp"] = read_stats_df1["avg_sequence_length"] * read_stats_df1["Total Sequences"] / 1000000

# remove the ".fastq" extension from the Filename column
read_stats_df1["Filename"] = read_stats_df1["Filename"].str.split(".fastq").str[0]

# rename the columns of read_stats_df1
read_stats_df1.columns = ["file_pre","length_pre", "number_pre", "Mbp_pre"]

# set the Filename column as the index of read_stats_df1
read_stats_df1 = read_stats_df1.set_index('file_pre')

# remove any whitespace from the index values of read_stats_df1
read_stats_df1.index = read_stats_df1.index.map("".join)

# create a new dataframe with columns for Filename, average sequence length, and total sequences from the postqc dataframe
read_stats_df2 = postqc[["Filename","avg_sequence_length", "Total Sequences"]]

# calculate the total number of megabases for each file and add this as a new column to read_stats_df2
read_stats_df2["Mbp"] = read_stats_df2["avg_sequence_length"] * read_stats_df2["Total Sequences"] / 1000000

# replace certain portions of the Filename column with standard suffixes (e.g. _forward -> _R1)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_forward", forward_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_reverse", reverse_tag)
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.replace("_unpaired", "_U")
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_paired").str[0]
read_stats_df2["Filename"] = read_stats_df2["Filename"].str.split("_clean").str[0]

# create a new column in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
read_stats_df2["Sample"] = read_stats_df2["Filename"].str.rsplit("_",1).str[0]

# set the Filename column as the index of read_stats_df2
read_stats_df2 = read_stats_df2.set_index('Filename')

# rename the columns of read_stats_df2
read_stats_df2.columns=["length_post", "number_post", "Mbp_post", "sample"]

# merge read_stats_df1 and read_stats_df2 on their indices (i.e. Filename), keeping all rows from both dataframes
read_stats_df3 = read_stats_df1.merge(read_stats_df2, left_index=True, right_index=True, how="outer")

# replace any NaN (missing) values in read_stats_df3 with 0
read_stats_df3 = read_stats_df3.fillna(0)

# return the final merged dataframe
read_stats_df3

# %%
# Pre quality control fastQC statistics
preqc

# %%
# Post quality control fastQC statistics
postqc

# %%
# Group read statistics by sample
read_stats_df = read_stats_df3.groupby(["sample"]).sum()

# Calculate percentage of reads and Mbp kept
read_stats_df["%number_kept"] = (read_stats_df["number_post"] / read_stats_df["number_pre"] * 100).round(2)
read_stats_df["%Mbp_kept"] = (read_stats_df["Mbp_post"] / read_stats_df["Mbp_pre"] * 100).round(2)

# Calculate percentage of reads and Mbp removed
read_stats_df["%Mbp_removed"] = 100 - read_stats_df["%Mbp_kept"]
read_stats_df["%number_removed"] = 100 - read_stats_df["%number_kept"]

# sort the DataFrame by "Sample" column, apply background color gradient to it, and render it as an HTML table
read_stats_out=read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn").render()

# write the HTML table to a file
with open(output_qc_summary_html,"w") as fp:
    fp.write(read_stats_out)
    
# Drop unnecessary columns and apply a gradient color scheme to the resulting DataFrame
read_stats_df.drop(["length_pre", "length_post"], axis=1).reset_index().style.background_gradient(cmap="RdYlGn")

# %% [markdown]
# ### Percentage of kept/removed reads

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Define maximum number of samples per subplot
max_samples_per_subplot = 200

# Initialize n
n=1

# Calculate the number of rows of subplots needed
num_subplots = int(np.ceil(len(SAMPLES) / max_samples_per_subplot))

# Calculate the approximate number of samples per subplot
samples_per_subplot = int(np.ceil(len(SAMPLES) / num_subplots))

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of reads kept and removed for each sample
    ax = subset_df[["%number_kept", "%number_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of reads')
    ax.set_title(f'Percentage of kept reads (Samples {start_idx + 1} to {end_idx})')

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
    
    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)

    n=n+1
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_reads_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ### Percentage of kept/removed Mbp

# %%
# Initialize n
n=1

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(SAMPLES))
    subset_df = read_stats_df.iloc[start_idx:end_idx]

    # Create a bar plot of the percentage of Mbp kept and removed for each sample
    ax = subset_df[["%Mbp_kept", "%Mbp_removed"]].plot(
        kind='bar', stacked=True, colormap=cmap1, width=0.8, edgecolor='none', ax=axs[i, 0]
    )

    # Add axis labels and a title to the plot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Percentage of Mbp')
    ax.set_title(f'Percentage of kept Mbp (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Set the limits of the y-axis
    ax.set_ylim(0, 100)

    # Add a legend to the plot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1


# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
fig.savefig(output_percentage_kept_Mbp_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_percentage_kept_Mbp_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ## Removed reads per QC step

# %%
# Initialize empty lists and variables
sample_l=[]
read_types=[]
raw=[]
trimmed=[]
duk=[]
euk=[]
norm=[]
reads=[]

# Initialize n
n=1

# Loop through each sample in read_stats_df and populate the lists with relevant information
for sample in (read_stats_df.index.to_list()):  
    # Add sample name and read type to lists
    sample_l.extend([sample]*3)
    read_types.extend(["R1", "R2", "U"])
    # Read in raw read counts for each read type and add to raw list
    raw.append(int(open(raw_dir + "/" + sample + forward_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(open(raw_dir + "/" +  sample + reverse_tag + "_read_count.txt" , 'r').readline().strip()))
    raw.append(int(0))
    # Read in trimmed read counts for each read type and add to trimmed list
    trimmed.append(int(open(clean_dir + "/" + sample + "_forward_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_reverse_paired_read_count.txt" , 'r').readline().strip()))
    trimmed.append(int(open(clean_dir + "/" + sample + "_merged_unpaired.tot_read_count.txt" , 'r').readline().strip()))
    # Read in non-eukaryotic read counts for each read type and add to euk list
    euk.append(int(open(clean_dir + "/" + sample + "_forward_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    euk.append(int(open(clean_dir + "/" + sample + "_unpaired_noEuk.tot_read_count.txt" , 'r').readline().strip()))
    # Read in BBDuk-cleaned read counts for each read type and add to duk list
    duk.append(int(open(clean_dir + "/" + sample + "_forward_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_reverse_paired_clean.tot_read_count.txt" , 'r').readline().strip()))
    duk.append(int(open(clean_dir + "/" + sample + "_unpaired_clean.tot_read_count.txt" , 'r').readline().strip()))
    # Read in normalized read counts for each read type and add to norm list
    norm.append(int(open(clean_dir + "/" + sample + "_forward_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_reverse_paired_norm.tot_read_count.txt" , 'r').readline().strip()))
    norm.append(int(open(clean_dir + "/" + sample + "_unpaired_norm.tot_read_count.txt" , 'r').readline().strip()))


    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Create an empty pandas DataFrame
df_counts = pd.DataFrame()

# Add columns to the DataFrame
df_counts["sample"] = sample_l
df_counts["type"] = read_types
df_counts["raw"] = raw
df_counts["trimmomatic"] = trimmed
df_counts["kraken"] = euk
df_counts["bbduk"] = duk
df_counts["norm"] = norm

# Calculate values for new columns and add them to the DataFrame
df_counts["raw_s"] = df_counts["raw"] / 1000000
df_counts["low_QC_reads_s"] = (df_counts["raw"] - df_counts["trimmomatic"]) / 1000000
df_counts["eukaryotic_reads_s"] = (df_counts["trimmomatic"] - df_counts["kraken"]) / 1000000
df_counts["bbduk_phix174_reads_s"] = (df_counts["kraken"] - df_counts["bbduk"]) / 1000000
df_counts["duplicate_reads_s"] = (df_counts["bbduk"] - df_counts["norm"]) / 1000000
df_counts["assembly_reads_s"] = df_counts["norm"] / 1000000

df_counts["low_QC_reads_p"] = df_counts["low_QC_reads_s"] / df_counts["raw_s"]
df_counts["eukaryotic_reads_p"] = df_counts["eukaryotic_reads_s"] / df_counts["raw_s"]
df_counts["bbduk_phix174_reads_p"] = df_counts["bbduk_phix174_reads_s"] / df_counts["raw_s"]
df_counts["duplicate_reads_p"] = df_counts["duplicate_reads_s"] / df_counts["raw_s"]
df_counts["assembly_reads_p"] = df_counts["assembly_reads_s"] / df_counts["raw_s"]

# Create a new column by concatenating two existing columns
df_counts["sample_long"] = df_counts["sample"] + "_" + df_counts["type"]

# Convert the DataFrame to an HTML table and write it to a file
df_counts.to_html(output_step_qc_reads_html)

# Display the final DataFrame
df_counts

# %% [markdown]
# ### Number of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4


# Define legend text and create colormap
legend_text = ["Used for assembly", "Duplicate (removed)", "phiX174 (user contaminants)", "Eukaryotic contamination", "Low quality"]

# Filter the dataframe to only include R1 reads
df_counts_paired = df_counts[df_counts["type"] == "R1"]

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    # print(i)
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(x="sample", y=["assembly_reads_s", "duplicate_reads_s", "bbduk_phix174_reads_s", "eukaryotic_reads_s", "low_QC_reads_s"],
                        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none')

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Million reads')
    ax.set_title(f'Sample Read Counts (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1
    
# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_reads_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_reads_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()

# %% [markdown]
# ### Percentage of kept/removed reads per QC step

# %%
# Initialize n
n=1

# Set figure size and font scale for seaborn
plt.figure(figsize=(12,12))

# Set figure width based on number of samples
fig_width = len(SAMPLES) * 0.4

# Create subplots with fixed width for each subplot
fig, axs = plt.subplots(num_subplots, 1, figsize=(samples_per_subplot * 0.4, 12 * num_subplots), squeeze=False)

# Plot each subset of samples in separate subplots
for i in range(num_subplots):
    start_idx = i * samples_per_subplot
    end_idx = min((i + 1) * samples_per_subplot, len(df_counts_paired))
    subset_df = df_counts_paired.iloc[start_idx:end_idx]

    # Plot the data
    ax = subset_df.plot(
        x="sample",
        y=["assembly_reads_p", "duplicate_reads_p", "bbduk_phix174_reads_p", "eukaryotic_reads_p", "low_QC_reads_p"],
        kind="bar", stacked=True, colormap=cmap1, ax=axs[i, 0], width=0.8, edgecolor='none'
    )

    # Add legend, axis labels and title to each subplot
    ax.set_xlabel('Sample')
    ax.set_ylabel('Proportion of raw reads')
    ax.set_title(f'Sample Proportion of Raw Reads (Samples {start_idx + 1} to {end_idx})', pad=20)

    # Add legend to the subplot
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(legend_text), loc='center left', bbox_to_anchor=(1, 0.5))

    print(f"{100*n/(num_subplots):.2f}" + " %", end='\r', flush=True)
    n=n+1

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the plot as PNG and SVG files
plt.savefig(output_steps_qc_percentage_png, format="png", bbox_inches="tight", transparent=True)
plt.savefig(output_steps_qc_percentage_svg, format="svg", bbox_inches="tight", transparent=True)

# Show the plot
plt.show()

# %%
df_counts_paired.to_csv(output_df_counts_paired)
df_counts_paired

# %% [markdown]
# ## Super Deduper PCR duplication statistics

# %%
# Set figure size and font scale for seaborn
plt.figure(figsize=(12, 12))

# Initialize variables
maxim = 0
percentages = []

# Create a single plot
fig, ax = plt.subplots()
n=1
# Loop through each sample
for sample in SAMPLES:
    # Load the JSON data from the file
    with open(qc_dir + "/" + sample + "_stats_pcr_duplicates.log") as f:
        data = json.load(f)
    
    # Extract the relevant data and calculate percentage of duplicates
    df = pd.DataFrame(data[0]["Fragment"]["duplicate_saturation"], columns=["reads", "dup"]) / 1000000
    percentages.append(df.iloc[-1]["dup"] * 100 / df.iloc[-1]["reads"])
    
    # Find the maximum value of "reads"
    max_temp = df["reads"].max()
    if max_temp > maxim:
        maxim = max_temp

    n=n+1
    print(f"{100*n/len(SAMPLES):.2f}" + " %", end='\r', flush=True)

    # Plot the data as a line plot using seaborn
    sns.lineplot(x="reads", y="dup", data=df, err_style='band', color=colors_rarefaction[len(percentages) - 1], 
                 label=sample, linewidth=1, alpha=0.8, ax=ax)

# Set the x and y limits of the plot
ax.set(ylim=(0, maxim))
ax.set(xlim=(0, maxim))

# Set the x and y labels of the plot
ax.set_xlabel("Million reads")
ax.set_ylabel("PCR duplicates (Million reads)")

# Add a legend to the plot
if len(SAMPLES) <= SAMPLE_PLOT_LIM_LEGEND:
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=int(np.ceil(len(SAMPLES) / 25)))
else:
    ax.get_legend().set_visible(False)

plt.tight_layout()

# Save the plot as png and svg files
fig.savefig(output_supperdedupper_png, format="png", bbox_inches="tight", transparent=True)
fig.savefig(output_supperdedupper_svg, format="svg", bbox_inches="tight", transparent=True)

# Create a dataframe to store the percentage of duplicates for each sample
pcr_dup_df = pd.DataFrame({
    "sample": SAMPLES,
    "pcr_percent_duplicates": percentages
})

# Generate a styled HTML table of the dataframe and save it to a file
pcr_dup_df_out = pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100).render()
with open(output_supperdedupper_html, "w") as fp:
    fp.write(pcr_dup_df_out)

# %%
# display the styled dataframe in the notebook
pcr_dup_df.style.background_gradient(cmap="RdYlGn_r", vmin=0, vmax=100)
