# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/lmf/miniforge3/envs/Mosaic_workflow/lib/python3.11/site-packages', '/home/lmf/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpueb9jzhf/file/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks', '/home/lmf/apps/MOSAIC/mosaic/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x14p\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cc/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/01_QC/postQC_illumina_report_data/multiqc_fastqc.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vBRB_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vBRB_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1C_T_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1aB_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1aB_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF23_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2C_T_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2aA_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2aA_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3C_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vFL_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vFL_amp_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN1_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN1_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN2_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN2_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN3_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN3_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNW_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNW_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNWd_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNWd_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1C_T_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1aB_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1aB_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2C_T_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2aA_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2aA_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3A_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3A_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3C_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vOL_tot_covstats.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vOL_amp_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1C_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2C_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3B_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3B_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3C_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3C_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSE_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSE_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSEd_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSEd_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSW_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSW_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSWd_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSWd_T_tot_covstats.txt\x94\x8co/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vWRB_tot_covstats.txt\x94\x8cq/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vWRB_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ1_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ1_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ2_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ2_T_tot_covstats.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ3_tot_covstats.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ3_T_tot_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vBRB_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vBRB_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1C_T_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1aB_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF1aB_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF23_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2C_T_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2aA_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF2aA_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vF3C_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vFL_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vFL_amp_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN1_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN1_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN2_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN2_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN3_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vN3_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNW_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNW_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNWd_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vNWd_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1C_T_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1aB_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO1aB_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2C_T_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2aA_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO2aA_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3A_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3A_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vO3C_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vOL_tot_unique_covstats.txt\x94\x8cy/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vOL_amp_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS1C_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS2C_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3B_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3B_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3C_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vS3C_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSE_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSE_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSEd_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSEd_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSW_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSW_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSWd_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vSWd_T_tot_unique_covstats.txt\x94\x8cv/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vWRB_tot_unique_covstats.txt\x94\x8cx/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vWRB_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ1_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ1_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ2_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ2_T_tot_unique_covstats.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ3_tot_unique_covstats.txt\x94\x8cw/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/bowtie2_active_vOTUs_vZ3_T_tot_unique_covstats.txt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\npostqc_txt\x94K\x00N\x86\x94\x8c\x08covstats\x94K\x01KZ\x86\x94\x8c\x0fcovstats_unique\x94KZK\xb3\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\xc8\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\xce)}\x94\x8c\x05_name\x94h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bh\xc0h\nh\xc2h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0bh\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhce}\x94(h\xbe}\x94h\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bubh\xc4h\xd9)\x81\x94(hdhehfhghhhihjhkhlhmhnhohphqhrhshthuhvhwhxhyhzh{h|h}h~h\x7fh\x80h\x81h\x82h\x83h\x84h\x85h\x86h\x87h\x88h\x89h\x8ah\x8bh\x8ch\x8dh\x8eh\x8fh\x90h\x91h\x92h\x93h\x94h\x95h\x96h\x97h\x98h\x99h\x9ah\x9bh\x9ch\x9dh\x9eh\x9fh\xa0h\xa1h\xa2h\xa3h\xa4h\xa5h\xa6h\xa7h\xa8h\xa9h\xaah\xabh\xach\xadh\xaeh\xafh\xb0h\xb1h\xb2h\xb3h\xb4h\xb5h\xb6h\xb7h\xb8h\xb9h\xbah\xbbh\xbce}\x94(h\xbe}\x94h\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cb/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_RPKM_raw_tot.txt\x94\x8ci/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_RPKM_normalised_tot.txt\x94\x8cd/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_counts_raw_tot.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_counts_normalised_tot.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_breadth_coverage_percent_tot.txt\x94\x8cp/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/active_vOTUs_breadth_coverage_bases_tot.txt\x94\x8ck/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_active_vOTUs_RPKM_raw_tot.txt\x94\x8cr/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_active_vOTUs_RPKM_normalised_tot.txt\x94\x8cm/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_active_vOTUs_counts_raw_tot.txt\x94\x8ct/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_active_vOTUs_counts_normalised_tot.txt\x94\x8cn/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_75_active_vOTUs_RPKM_raw_tot.txt\x94\x8cu/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING/REFERENCES/filtered_75_active_vOTUs_RPKM_normalised_tot.txt\x94e}\x94(h\xbe}\x94(\x8c\rraw_RPKM_file\x94K\x00N\x86\x94\x8c\x0enorm_RPKM_file\x94K\x01N\x86\x94\x8c\x0eraw_count_file\x94K\x02N\x86\x94\x8c\x0fnorm_count_file\x94K\x03N\x86\x94\x8c\x12coverage_RPKM_file\x94K\x04N\x86\x94\x8c\x18coverage_bases_RPKM_file\x94K\x05N\x86\x94\x8c\x16filtered_raw_RPKM_file\x94K\x06N\x86\x94\x8c\x17filtered_norm_RPKM_file\x94K\x07N\x86\x94\x8c\x17filtered_raw_count_file\x94K\x08N\x86\x94\x8c\x18filtered_norm_count_file\x94K\tN\x86\x94\x8c\x19filtered_75_raw_RPKM_file\x94K\nN\x86\x94\x8c\x1afiltered_75_norm_RPKM_file\x94K\x0bN\x86\x94uh\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bj\x04\x01\x00\x00h\xf6j\x06\x01\x00\x00h\xf7j\x08\x01\x00\x00h\xf8j\n\x01\x00\x00h\xf9j\x0c\x01\x00\x00h\xfaj\x0e\x01\x00\x00h\xfbj\x10\x01\x00\x00h\xfcj\x12\x01\x00\x00h\xfdj\x14\x01\x00\x00h\xfej\x16\x01\x00\x00h\xffj\x18\x01\x00\x00j\x00\x01\x00\x00j\x1a\x01\x00\x00j\x01\x01\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(\x8c\x04vBRB\x94\x8c\x06vBRB_T\x94\x8c\x04vF1A\x94\x8c\x06vF1A_T\x94\x8c\x04vF1B\x94\x8c\x06vF1B_T\x94\x8c\x04vF1C\x94\x8c\x06vF1C_T\x94\x8c\x05vF1aB\x94\x8c\x07vF1aB_T\x94\x8c\x04vF23\x94\x8c\x04vF2A\x94\x8c\x06vF2A_T\x94\x8c\x04vF2B\x94\x8c\x06vF2B_T\x94\x8c\x04vF2C\x94\x8c\x06vF2C_T\x94\x8c\x05vF2aA\x94\x8c\x07vF2aA_T\x94\x8c\x04vF3A\x94\x8c\x06vF3A_T\x94\x8c\x04vF3B\x94\x8c\x06vF3B_T\x94\x8c\x04vF3C\x94\x8c\x06vF3C_T\x94\x8c\x03vFL\x94\x8c\x07vFL_amp\x94\x8c\x03vN1\x94\x8c\x05vN1_T\x94\x8c\x03vN2\x94\x8c\x05vN2_T\x94\x8c\x03vN3\x94\x8c\x05vN3_T\x94\x8c\x03vNW\x94\x8c\x05vNW_T\x94\x8c\x04vNWd\x94\x8c\x06vNWd_T\x94\x8c\x04vO1A\x94\x8c\x06vO1A_T\x94\x8c\x04vO1B\x94\x8c\x06vO1B_T\x94\x8c\x04vO1C\x94\x8c\x06vO1C_T\x94\x8c\x05vO1aB\x94\x8c\x07vO1aB_T\x94\x8c\x04vO2A\x94\x8c\x06vO2A_T\x94\x8c\x04vO2B\x94\x8c\x06vO2B_T\x94\x8c\x04vO2C\x94\x8c\x06vO2C_T\x94\x8c\x05vO2aA\x94\x8c\x07vO2aA_T\x94\x8c\x04vO3A\x94\x8c\x06vO3A_T\x94\x8c\x04vO3B\x94\x8c\x06vO3B_T\x94\x8c\x04vO3C\x94\x8c\x06vO3C_T\x94\x8c\x03vOL\x94\x8c\x07vOL_amp\x94\x8c\x04vS1B\x94\x8c\x06vS1B_T\x94\x8c\x04vS1C\x94\x8c\x06vS1C_T\x94\x8c\x04vS2B\x94\x8c\x06vS2B_T\x94\x8c\x04vS2C\x94\x8c\x06vS2C_T\x94\x8c\x04vS3B\x94\x8c\x06vS3B_T\x94\x8c\x04vS3C\x94\x8c\x06vS3C_T\x94\x8c\x03vSE\x94\x8c\x05vSE_T\x94\x8c\x04vSEd\x94\x8c\x06vSEd_T\x94\x8c\x03vSW\x94\x8c\x05vSW_T\x94\x8c\x04vSWd\x94\x8c\x06vSWd_T\x94\x8c\x04vWRB\x94\x8c\x06vWRB_T\x94\x8c\x03vZ1\x94\x8c\x05vZ1_T\x94\x8c\x03vZ2\x94\x8c\x05vZ2_T\x94\x8c\x03vZ3\x94\x8c\x05vZ3_T\x94e\x8c9/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/06_MAPPING\x94\x8c</home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/02_CLEAN_DATA\x94\x8c\x03tot\x94K\xc8G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x0cactive_vOTUs\x94e}\x94(h\xbe}\x94(\x8c\x07samples\x94K\x00N\x86\x94\x8c\x0bmapping_dir\x94K\x01N\x86\x94\x8c\tclean_dir\x94K\x02N\x86\x94\x8c\x08sampling\x94K\x03N\x86\x94\x8c\x0fthreshold_bases\x94K\x04N\x86\x94\x8c\x0ethreshold_RPKM\x94K\x05N\x86\x94\x8c\treference\x94K\x06N\x86\x94uh\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bj\x89\x01\x00\x00j)\x01\x00\x00j\x8b\x01\x00\x00j\x83\x01\x00\x00j\x8d\x01\x00\x00j\x84\x01\x00\x00j\x8f\x01\x00\x00j\x85\x01\x00\x00j\x91\x01\x00\x00K\xc8j\x93\x01\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aj\x95\x01\x00\x00j\x86\x01\x00\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94j\x85\x01\x00\x00a}\x94(h\xbe}\x94\x8c\x08sampling\x94K\x00N\x86\x94sh\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bj\x8f\x01\x00\x00j\x85\x01\x00\x00ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\xbe}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bj\xb9\x01\x00\x00K\x01j\xbb\x01\x00\x00K\x01j\xbd\x01\x00\x00j\xb6\x01\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\\/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/NOTEBOOKS/07_Normalise_active_vOTUs.tot.ipynb\x94a}\x94(h\xbe}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\xc6]\x94(h\xc8h\xc9eh\xc8h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc8sNt\x94bh\xc9h\xcch\xce\x85\x94R\x94(h\xce)}\x94h\xd2h\xc9sNt\x94bj\xcf\x01\x00\x00j\xcc\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\tinput_dir\x94\x8c:/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/00_RAW_DATA\x94\x8c\tkraken_db\x94\x8c\x1b/home/lmf/db/KRAKEN/kraken/\x94\x8c\rkrakenUniq_db\x94\x8c\x1e/home/lmf/db/KRAKEN/KrakenUniq\x94\x8c\x1cadditional_reference_contigs\x94\x8cA/home/lmf/PhylloVir/VIRAL_WORLD/VIRAL_FRACTION/active_vOTUs.fasta\x94\x8c\x0bsubsampling\x94\x88\x8c\x0bresults_dir\x94\x8c\x00\x94\x8c\nmetagenome\x94\x88\x8c\tmicrobial\x94\x89\x8c\x08sourmash\x94\x89\x8c\x0bkey_samples\x94\x8c\x14key_samples_list.csv\x94\x8c\x10operating_system\x94\x8c\x05linux\x94\x8c\x0bforward_tag\x94\x8c\x02R1\x94\x8c\x0breverse_tag\x94\x8c\x02R2\x94\x8c\x0cnanopore_tag\x94\x8c\x08nanopore\x94\x8c\x0fnanopore_pooled\x94\x89\x8c\x14nanopore_pooled_name\x94\x8c\x03raw\x94\x8c\x0elong_assembler\x94\x8c\x04canu\x94\x8c\x0bgenome_size\x94\x8c\x0320m\x94\x8c\x13trimmomatic_leading\x94\x8c\x0220\x94\x8c\x14trimmomatic_trailing\x94\x8c\x0220\x94\x8c\x17trimmomatic_window_size\x94\x8c\x014\x94\x8c\x1atrimmomatic_window_quality\x94\x8c\x0220\x94\x8c\x12trimmomatic_minlen\x94\x8c\x0250\x94\x8c\x10nanopore_quality\x94\x8c\x0210\x94\x8c\x0fnanopore_minlen\x94M\xe8\x03\x8c\x0fnanopore_maxlen\x94J\x80\x96\x98\x00\x8c\x11nanopore_headcrop\x94K2\x8c\x11nanopore_tailcrop\x94K2\x8c\x0cmedaka_model\x94\x8c\x12r941_min_high_g360\x94\x8c\x12contaminants_taxid\x94M\xc7\n\x8c\x0bsubassembly\x94\x89\x8c\tVirSorter\x94\x89\x8c\x0eassembly_stats\x94\x89\x8c\x0ecross_assembly\x94\x89\x8c\nlong_index\x94\x89\x8c\x0crun_vcontact\x94\x89\x8c\x08run_DRAM\x94\x89\x8c\x0bimgvr_blast\x94\x89\x8c\necc_memory\x94Mp\x17\x8c\x16representative_contigs\x94j\xe6\x01\x00\x00\x8c\x08sra_list\x94j\xe6\x01\x00\x00\x8c\x0eextract_mapped\x94\x89\x8c\x07p_ident\x94\x8c\x0295\x94\x8c\x0bkmer_window\x94\x8c\x0525000\x94\x8c\x08min_norm\x94\x8c\x010\x94\x8c\x08max_norm\x94\x8c\x03100\x94\x8c\rmax_subsample\x94\x8c\x0850000000\x94\x8c\x07min_len\x94\x8c\x041000\x94\x8c\x07min_cov\x94\x8c\x012\x94\x8c\x0fmin_votu_length\x94M\x88\x13\x8c\x11contaminants_list\x94j\xe6\x01\x00\x00\x8c\radapters_file\x94\x8c\x0badapters.fa\x94\x8c\x11ambiguous_mapping\x94\x8c\x03all\x94\x8c\x0ebasecalled_dir\x94\x8c\x10data/basecalled/\x94\x8c\x11microbial_spacers\x94j\xe6\x01\x00\x00\x8c\x13reference_databases\x94\x8c\x1eIMGVR GenBankViral RefSeqViral\x94\x8c\x08IMGVR_db\x94\x8c!/home/lmf/db/IMG_VR_2022-12-19_7/\x94\x8c\x0eRefSeqViral_db\x94\x8c6/home/lmf/db/RefSeqViral/RefSeq_viral_2024_09_03.fasta\x94\x8c\x0bpharokka_db\x94\x8c\x15/home/lmf/db/pharokka\x94\x8c\x08blast_db\x94\x8c\x1fdb/ncbi/NCBI_viral_proteins.faa\x94\x8c\x0cvirSorter_db\x94\x8c\x1bdb/VirSorter/virsorter-data\x94\x8c\x0ckraken_db_nt\x94\x8c\x17/home/lmf/db/KRAKEN/nt/\x94\x8c\x0fkraken_db_human\x94\x8c\x13db/kraken2_human_db\x94\x8c\x0ckraken_tools\x94\x8c\x11tools/KrakenTools\x94\x8c\x0bbracken_dir\x94\x8c\rtools/Bracken\x94\x8c\nweesam_dir\x94\x8c\x0ctools/weeSAM\x94\x8c\tcheckv_db\x94\x8c\x11db/checkv-db-v1.5\x94\x8c\tcheckm_db\x94\x8c\x0cdb/checkm-db\x94\x8c\x08iphop_db\x94\x8c\x0bdb/iphop_db\x94\x8c\rtaxmyphage_db\x94\x8c\x10db/taxmyphage_db\x94\x8c\x0csourmash_sig\x94\x8c7/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.zip\x94\x8c\x10sourmash_rocksdb\x94\x8c;/home/lmf/db/SOURMASH/matrix_09_42_sourmash_k31.sig.rocksdb\x94\x8c\x0csourmash_tax\x94\x8c9/home/lmf/db/SOURMASH/taxonomy/taxonomy_matrix_strain.csv\x94\x8c\x08canu_dir\x94\x8c\x1etools/canu-2.0/Linux-amd64/bin\x94\x8c\x12PhaGCN_newICTV_dir\x94\x8c\x14tools/PhaGCN_newICTV\x94\x8c\tquast_dir\x94\x8c\x11tools/quast-5.0.2\x94\x8c\rvirSorter_dir\x94\x8c\x0ftools/VirSorter\x94\x8c\x07WTP_dir\x94\x8c\ttools/WTP\x94\x8c\rvirFinder_dir\x94\x8c\x0ftools/VirFinder\x94\x8c\x0eclusterONE_dir\x94\x8c\x10tools/clusterONE\x94\x8c\x0cvcontact_dir\x94\x8c\x0ftools/vcontact2\x94\x8c\x1areference_genomes_vcontact\x94\x8c\x04None\x94\x8c\rtaxonomy_file\x94\x8c1db/vcontact2/formatting_taxonomy_affiliations.csv\x94\x8c\ngenomad_db\x94\x8c\rdb/genomad_db\x94\x8c\x07DRAM_db\x94\x8c\ndb/DRAM_db\x94\x8c\tgtdbtk_db\x94\x8c\ndb/GTDB-Tk\x94\x8c\nmmseqs_dir\x94\x8c\rtools/MMseqs2\x94\x8c\x08viga_dir\x94\x8c\ntools/viga\x94\x8c\tpiler_dir\x94\x8c\x11tools/pilercr1.06\x94\x8c\x07trf_dir\x94\x8c\ttools/TRF\x94\x8c\x0bvibrant_dir\x94\x8c\rtools/VIBRANT\x94\x8c\x0eviridic_folder\x94\x8c\x17tools/viridic_v1.0_r3.6\x94\x8c\x0fsra_toolkit_dir\x94\x8c tools/sratoolkit.2.10.0-ubuntu64\x94\x8c\x07ALE_dir\x94\x8c\ttools/ALE\x94\x8c\x08wish_dir\x94\x8c\ntools/WIsH\x94\x8c\nminced_dir\x94\x8c\x0ctools/minced\x94\x8c\x07dion_db\x94\x8c\x0cdb/dionSetDB\x94u\x8c\x04rule\x94\x8c\x19normalise_reads_reference\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c//home/lmf/apps/MOSAIC/mosaic/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/lmf/apps/MOSAIC/mosaic');
######## snakemake preamble end #########

# %% [markdown]
# # Active vOTU Normalisation

# %% [markdown]
# ## Notebook Setup

# %%
# Load core libraries
# import necessary modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
import math
from matplotlib import colors

#------------------------------------------
cmap1=LinearSegmentedColormap.from_list("my_colormap", sns.color_palette("colorblind", n_colors=5))


# Plotting preferences
sns.set_style(
    "ticks",
    {
        "axes.grid": True,
        "grid.color": "#BFBFBF",
        "grid.linestyle": "-",
        "grid.linewidth": 0.35,
        "axes.facecolor": "white",
        "figure.facecolor": "white",
    },
)
sns.set_palette("colorblind")

plt.rcParams.update({
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "savefig.facecolor": "white",
    "savefig.transparent": False,
    "savefig.bbox": "tight",
    "axes.linewidth": 0.7,
    "axes.edgecolor": "#222222",
    "xtick.major.width": 0.7,
    "ytick.major.width": 0.7,
    "xtick.minor.width": 0.5,
    "ytick.minor.width": 0.5,
    "xtick.major.size": 4.5,
    "ytick.major.size": 4.5,
    "xtick.minor.size": 2.5,
    "ytick.minor.size": 2.5,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "grid.linewidth": 0.35,
    "grid.alpha": 0.8,
    "patch.linewidth": 0.7,
    "lines.linewidth": 1.0,
    "lines.markersize": 4,
    "font.family": "sans-serif",
    "font.sans-serif": ["Liberation Sans"],
    "text.usetex": False,
    "font.size": 5,
    "axes.titlepad": 5,
    "axes.titlesize": 7,
    "axes.labelsize": 7,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.labelweight": "bold",
    "axes.titleweight": "bold",
    "legend.frameon": True,
    "legend.fancybox": False,
    "legend.framealpha": 1.0,
    "legend.edgecolor": "#444444",
    "legend.facecolor": "white",
    "legend.fontsize": 5,
    "legend.title_fontsize": 6,
    "savefig.dpi": 300,
    "figure.dpi": 150,
    "svg.fonttype": "none",
})

# %%
# Define Snakemake inputs, outputs, and parameters
SAMPLING=snakemake.params.sampling
illumina_postqc=snakemake.input.postqc_txt
mapping_dir=snakemake.params.mapping_dir
clean_dir=snakemake.params.clean_dir
threshold_bases=snakemake.params.threshold_bases
REFERENCE=snakemake.params.reference
THRESHOLD_RPKM=snakemake.params.threshold_RPKM

out_raw_RPKM_file=snakemake.output.raw_RPKM_file
out_norm_RPKM_file=snakemake.output.norm_RPKM_file
out_raw_count_file=snakemake.output.raw_count_file
out_norm_count_file=snakemake.output.norm_count_file
out_coverage_RPKM_file=snakemake.output.coverage_RPKM_file
out_coverage_bases_RPKM_file=snakemake.output.coverage_bases_RPKM_file

out_filtered_raw_RPKM_file=snakemake.output.filtered_raw_RPKM_file
out_filtered_norm_RPKM_file=snakemake.output.filtered_norm_RPKM_file
out_filtered_raw_count_file=snakemake.output.filtered_raw_count_file
out_filtered_norm_count_file=snakemake.output.filtered_norm_count_file
out_filtered_75_raw_RPKM_file=snakemake.output.filtered_75_raw_RPKM_file
out_filtered_75_norm_RPKM_file=snakemake.output.filtered_75_norm_RPKM_file

# %%
# Load read counts and mapping tables
postqc = pd.read_csv(illumina_postqc, sep="\t")

# # create a new dataframe with columns for Filename, average sequence length, and total sequences from the postqc dataframe
read_stats_df2 = postqc[["Filename","avg_sequence_length"]]

# replace certain portions of the Filename column with standard suffixes (e.g. _forward -> _R1)
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_forward", "_R1")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_reverse", "_R2")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.replace("_unpaired", "_U")
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.split("_paired").str[0]
read_stats_df2.loc[:, "Filename"] = read_stats_df2["Filename"].str.split("_clean").str[0]

# create a new columns in read_stats_df2 for the sample name, based on the first part of the Filename (before the final underscore)
read_stats_df2.loc[:, "Sample"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[0]
read_stats_df2.loc[:, "Read_type"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[1]

# set the Filename column as the index of read_stats_df2
read_stats_df2 = read_stats_df2.set_index('Filename')

# rename the columns of read_stats_df2
read_stats_df2.columns=["length_post", "sample", "Read_type"]
read_stats_df2=read_stats_df2[read_stats_df2["Read_type"]!="U"]
read_length_paired=read_stats_df2.groupby("sample").mean(numeric_only=True)
read_length_paired.loc[:, "length_post"] = read_length_paired["length_post"].round(2)
read_length_paired
# Out:
# /tmp/ipykernel_224415/1061248802.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df2.loc[:, "Sample"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[0]
# /tmp/ipykernel_224415/1061248802.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_stats_df2.loc[:, "Read_type"] = read_stats_df2["Filename"].str.rsplit("_",n=1).str[1]
#         length_post
# sample
# vBRB         145.31
# vBRB_T       126.39
# vF1A         141.44
# vF1A_T       129.79
# vF1B         130.48
# ...

# %%
# Define the sample order
SAMPLES=read_length_paired.index.to_list()
SAMPLES
# Out:
# ['vBRB',
#  'vBRB_T',
#  'vF1A',
#  'vF1A_T',
#  'vF1B',
#  'vF1B_T',
#  'vF1C',
#  'vF1C_T',
#  'vF1aB',
#  'vF1aB_T',
#  'vF23',
#  'vF2A',
#  'vF2A_T',
#  'vF2B',
#  'vF2B_T',
#  'vF2C',
#  'vF2C_T',
#  'vF2aA',
#  'vF2aA_T',
#  'vF3A',
#  'vF3A_T',
#  'vF3B',
#  'vF3B_T',
#  'vF3C',
#  'vF3C_T',
#  'vFL',
#  'vFL_amp',
#  'vN1',
#  'vN1_T',
#  'vN2',
#  'vN2_T',
#  'vN3',
#  'vN3_T',
#  'vNW',
#  'vNW_T',
#  'vNWd',
#  'vNWd_T',
#  'vO1A',
#  'vO1A_T',
#  'vO1B',
#  'vO1B_T',
#  'vO1C',
#  'vO1C_T',
#  'vO1aB',
#  'vO1aB_T',
#  'vO2A',
#  'vO2A_T',
#  'vO2B',
#  'vO2B_T',
#  'vO2C',
#  'vO2C_T',
#  'vO2aA',
#  'vO2aA_T',
#  'vO3A',
#  'vO3A_T',
#  'vO3B',
#  'vO3B_T',
#  'vO3C',
#  'vO3C_T',
#  'vOL',
#  'vOL_amp',
#  'vS1B',
#  'vS1B_T',
#  'vS1C',
#  'vS1C_T',
#  'vS2B',
#  'vS2B_T',
#  'vS2C',
#  'vS2C_T',
#  'vS3B',
#  'vS3B_T',
#  'vS3C',
#  'vS3C_T',
#  'vSE',
#  'vSE_T',
#  'vSEd',
#  'vSEd_T',
#  'vSW',
#  'vSW_T',
#  'vSWd',
#  'vSWd_T',
#  'vWRB',
#  'vWRB_T',
# ...

# %%
# Calculate raw and normalized abundance tables
#!/usr/bin/env python3

# Written by Alejandro Reyes
# Reformatted & Edited Laura Forero

def normalise_rpkm_bt2(sample,all_file, toss_file, paired_len):
    all_df=pd.read_csv(all_file, sep="\t")
    toss_df=pd.read_csv(toss_file, sep="\t")

    all_df.columns=["ID", "Avg_fold", "Length", "Covered_bases", "Read_Count", "Variance", "Trimmed Mean", "RPKM_" + sample]
    all_df["Covered_percent"]=all_df["Covered_bases"]*100/all_df["Length"]
    all_df=all_df.drop(columns=["Avg_fold","Variance", "Trimmed Mean"])
    all_df=all_df.add_suffix('_all')

    toss_df.columns=["ID", "Avg_fold", "Length", "Covered_bases", "Read_Count", "Variance", "Trimmed Mean", "RPKM_" + sample]
    toss_df["Covered_percent"]=toss_df["Covered_bases"]*100/toss_df["Length"]
    toss_df=toss_df.drop(columns=[ "Avg_fold","Variance", "Trimmed Mean"])
    toss_df=toss_df.add_suffix('_toss')

    
    combined_df=all_df.merge(toss_df, left_on="ID_all", right_on="ID_toss")
    combined_df=combined_df.drop(columns=["ID_toss", "Length_toss"])
    
    combined_df["extra_reads"]=abs(combined_df["Read_Count_all"]-combined_df["Read_Count_toss"])
    combined_df["test"]= (combined_df["Read_Count_all"]* 1E6/((combined_df["Length_all"]/1000)*combined_df["Read_Count_all"].sum()))

    combined_df["toss_cov"] = combined_df.apply(lambda row: (row["Read_Count_toss"] / row["Covered_bases_toss"]) if row["Covered_bases_toss"] > 0 else 0, axis=1)
    combined_df["delta_map_base"] = abs(combined_df["Covered_bases_all"]-combined_df["Covered_bases_toss"])
    combined_df["needed_reads"] = round(combined_df["toss_cov"]*combined_df["delta_map_base"]*0.9)

    combined_df["extra"] = combined_df.apply(lambda row: min(abs(row["extra_reads"]), abs(row["needed_reads"])), axis=1)
    
    combined_df["cov_ratio"]=np.log10((combined_df["Covered_percent_all"]+1)/(combined_df["Covered_percent_toss"]+1))

    combined_df["needed_ratio"]=np.log10((combined_df["needed_reads"]+1)/(combined_df["extra_reads"]+1))
    combined_df["Read_count_norm_" + sample] = (combined_df["Read_Count_toss"]+combined_df["extra"]).astype('int')

    threshold = threshold_bases 
    combined_df.loc[(combined_df["Covered_bases_toss"] < threshold) & (combined_df["Read_count_norm_" + sample] > 0), ["Read_count_norm_" + sample]] = 0

    total_reads_map = combined_df["Read_Count_toss"].sum()
    total_reads_map=total_reads_map+combined_df["extra"].sum()
    combined_df["RPKM_norm_" + sample] = ((combined_df["Read_count_norm_" + sample])* 1E9)/(combined_df["Length_all"]*total_reads_map)
    
    combined_df["exp_ratio"] = combined_df.apply(lambda row: np.log10(100 * (1 - math.exp(-1 * ((row["Read_Count_toss"] + row["needed_reads"]) * paired_len) / row["Length_all"])) / row["Covered_percent_all"]) if (row["Read_Count_toss"] > 0) and (total_reads_map > 0) else 0, axis=1)
    
    combined_df=combined_df[['ID_all', 'Length_all', "Read_Count_all", "Read_Count_toss",'RPKM_'+ sample + '_all', 'Covered_percent_all' , 'RPKM_'+ sample + '_toss', 'Covered_percent_toss', "Read_count_norm_" + sample, 'RPKM_norm_'+ sample, "Covered_bases_all", "Covered_bases_toss"]]
    combined_df.columns=['Contig', 'Length_' + sample,"Count_" + sample, "Read_Count_toss_" + sample,'RPKM_'+ sample + '_all', 'Covered_percent_all_'+ sample , 'RPKM_'+ sample + '_toss', 'Covered_percent_toss_' + sample, "Count_norm_" + sample , 'RPKM_norm_'+ sample, "Covered_bases_all_" + sample, "Covered_bases_toss_" + sample ]
    return(combined_df)

# %%
# Define the coverage and abundance filter
def filter_abundances(RPKM, counts, coverage_bases, coverage_percent, contig_length):
    contig_lengths_6667 = contig_length >= 6667
    bases_covered_gt_5000 = coverage_bases > 5000
    percentage_covered_gt_75 = coverage_percent > 75

    # # Create a filtered abundance DataFrame with the same shape as RPKM_raw, initialized with zeros
    filtered_RPKM_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)
    filtered_counts_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)

    condition1 = contig_lengths_6667 & bases_covered_gt_5000
    condition2 = ~contig_lengths_6667 & percentage_covered_gt_75

    filtered_RPKM_df[condition1] = RPKM[condition1]
    filtered_RPKM_df[condition2] = RPKM[condition2]
    
    filtered_counts_df[condition1] = counts[condition1]
    filtered_counts_df[condition2] = counts[condition2]
    
    # threshold_RPKM=THRESHOLD_RPKM
    # filtered_RPKM_df[filtered_RPKM_df<threshold_RPKM]=0
    # filtered_counts_df[filtered_RPKM_df<threshold_RPKM]=0
    
    return(filtered_RPKM_df, filtered_counts_df)

def filter_abundances_75(RPKM, coverage_bases, coverage_percent, contig_length):
    percentage_covered_gt_75 = coverage_percent > 75

    # # Create a filtered abundance DataFrame with the same shape as RPKM_raw, initialized with zeros
    filtered_RPKM_df = pd.DataFrame(0, index=RPKM.index, columns=RPKM.columns)

    filtered_RPKM_df[percentage_covered_gt_75] = RPKM[percentage_covered_gt_75]

    return(filtered_RPKM_df)

# %%
# Apply the filter to the complete sample set
print("NUMBER OF SAMPLES =" , len(SAMPLES))

n=0
for sample in SAMPLES:
    print(round(((n+1) * 100 / len(SAMPLES)),1), "%", end='\r')
    if len(REFERENCE)>0:
        all_file=mapping_dir + "/REFERENCES/bowtie2_" + REFERENCE + "_" + sample + "_" + SAMPLING + "_covstats.txt"
        toss_file=mapping_dir + "/REFERENCES/bowtie2_" + REFERENCE + "_" + sample + "_" + SAMPLING + "_unique_covstats.txt"
    else:
        all_file=mapping_dir + "/bowtie2_" + sample + "_" + SAMPLING + "_covstats.txt"
        toss_file=mapping_dir + "/bowtie2_" + sample + "_"+ SAMPLING + "_unique_covstats.txt"
    
    read_len=int(read_length_paired.loc[sample]["length_post"])
    count_df=normalise_rpkm_bt2(sample,all_file, toss_file, read_len)  

    if n == 0:
        df_RPKM_norm = count_df[["Contig", "RPKM_norm_" + sample]]
        df_RPKM_raw = count_df[["Contig", "RPKM_" + sample + "_all"]]
        df_count_raw = count_df[["Contig", "Count_" + sample ]]
        df_count_norm = count_df[["Contig", "Count_norm_" + sample ]]
        df_RPKM_cov = count_df[["Contig", "Covered_percent_all_"+ sample]]
        df_RPKM_cov_bases = count_df[["Contig", "Covered_bases_all_"+ sample]]
        df_RPKM_len = count_df[["Contig", "Length_" + sample]]
        
    else:
        df_RPKM_norm = df_RPKM_norm.merge(count_df[["Contig", "RPKM_norm_" + sample]], on="Contig")
        df_RPKM_raw = df_RPKM_raw.merge(count_df[["Contig", "RPKM_" + sample + "_all"]], on="Contig")
        df_count_raw = df_count_raw.merge(count_df[["Contig", "Count_" + sample]], on="Contig")
        df_count_norm = df_count_norm.merge(count_df[["Contig", "Count_norm_" + sample ]], on="Contig")
        df_RPKM_cov = df_RPKM_cov.merge(count_df[["Contig", "Covered_percent_all_"+ sample]], on="Contig")
        df_RPKM_cov_bases = df_RPKM_cov_bases.merge(count_df[["Contig", "Covered_bases_all_"+ sample]], on="Contig")
        df_RPKM_len = df_RPKM_len.merge(count_df[["Contig", "Length_" + sample]], on="Contig")
        
    n=n+1

df_RPKM_raw=df_RPKM_raw.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_norm=df_RPKM_norm.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_count_raw=df_count_raw.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_count_norm=df_count_norm.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_cov=df_RPKM_cov.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_cov_bases=df_RPKM_cov_bases.rename(columns={"Contig": "vOTU"}).set_index('vOTU')
df_RPKM_len=df_RPKM_len.rename(columns={"Contig": "vOTU"}).set_index('vOTU')

df_RPKM_raw.columns = df_RPKM_raw.columns.str.replace(r'^RPKM_', '', regex=True).str.replace(r'_all$', '', regex=True)
df_RPKM_norm.columns = df_RPKM_norm.columns.str.replace(r'^RPKM_norm_', '', regex=True)
df_count_raw.columns = df_count_raw.columns.str.replace(r'^Count_', '', regex=True)
df_count_norm.columns = df_count_norm.columns.str.replace(r'^Count_norm_', '', regex=True)
df_RPKM_cov.columns = df_RPKM_cov.columns.str.replace(r'^Covered_percent_all_', '', regex=True)
df_RPKM_cov_bases.columns = df_RPKM_cov_bases.columns.str.replace(r'^Covered_bases_all_', '', regex=True)
df_RPKM_len.columns = df_RPKM_len.columns.str.replace(r'^Length_', '', regex=True)

df_mean_coverage_raw=df_count_raw.div(df_RPKM_len)
df_mean_coverage_norm=df_count_norm.div(df_RPKM_len)

df_RPKM_raw.to_csv(out_raw_RPKM_file)
df_RPKM_norm.to_csv(out_norm_RPKM_file)
df_RPKM_cov.to_csv(out_coverage_RPKM_file)
df_RPKM_cov_bases.to_csv(out_coverage_bases_RPKM_file)
df_count_raw.to_csv(out_raw_count_file)
df_count_norm.to_csv(out_norm_count_file)
# Out:
# NUMBER OF SAMPLES = 89
# 100.0 %

# %% [markdown]
# ## Subsampled

# %%
# Build the subsampled abundance tables
df_mapped_sub=pd.DataFrame()

if SAMPLING=="sub":
    mapped_pair=[]
    sub_reads=[]
    for sample in SAMPLES:
        content = open(mapping_dir + "/bowtie2_flagstats_filtered_" + sample + "." +  "sub.txt").readlines()
        mapped_pair.append(int(content[1].split()[0]) / 2)
        content2 = open(clean_dir + "/" + sample + "_sub_sampling_reads_final.txt").readline()
        sub_reads.append(int(content2))

    df_mapped_sub["sample"]=SAMPLES
    df_mapped_sub["mapped"]=mapped_pair
    df_mapped_sub["sub_reads"]=sub_reads
    df_mapped_sub["viral_reads"]=df_mapped_sub["mapped"]

    df_mapped_sub["%mapped"]=df_mapped_sub["mapped"]*100/df_mapped_sub["sub_reads"]
    df_mapped_sub.loc['mean'] = df_mapped_sub.mean(numeric_only=True)
    df_mapped_sub=df_mapped_sub.sort_values(by="viral_reads")
    # df_mapped_sub.sort_values(by="viral_reads").style.set_precision(2).background_gradient(cmap="RdYlGn", vmin=0)
df_mapped_sub.style.background_gradient(cmap="RdYlGn", vmin=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_94037">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ## RPKM-normalized versus Raw
#
# Percentage of contigs with zero coverage after normalization.

# %%
# Compare normalized and raw RPKM

df_RPKM_norm2=df_RPKM_norm.copy()
df_RPKM_raw2=df_RPKM_raw.copy()
df_RPKM_cov2=df_RPKM_cov.copy()

col_names_norm = [col + "_norm" for col in df_RPKM_norm.columns]
col_names_raw = [col + "_raw" for col in df_RPKM_raw.columns]
col_names_cov = [col + "_cov" for col in df_RPKM_cov.columns]

df_RPKM_norm2.columns = col_names_norm
df_RPKM_raw2.columns = col_names_raw
df_RPKM_cov2.columns = col_names_cov


max_val=max(df_RPKM_norm.select_dtypes(include=[float]).max().max(),df_RPKM_raw.select_dtypes(include=[float]).max().max())
min_val=min(df_RPKM_norm.select_dtypes(include=[float]).replace(0, np.nan).min().min(),df_RPKM_raw.select_dtypes(include=[float]).replace(0, np.nan).min().min())
merged_df = df_RPKM_norm2.merge(df_RPKM_raw2, left_index=True,right_index=True).merge(df_RPKM_cov2, left_index=True,right_index=True)


# Determine common axis limits for log scale
max_val = max(df_RPKM_norm.select_dtypes(include=[float]).max().max(),
              df_RPKM_raw.select_dtypes(include=[float]).max().max())
min_val = min(df_RPKM_norm.select_dtypes(include=[float]).replace(0, np.nan).min().min(),
              df_RPKM_raw.select_dtypes(include=[float]).replace(0, np.nan).min().min())

# Set the limits to be the same for x and y axis
axis_limits = [min_val, max_val]


n_columns=4
# Set up the subplots
len_samples=len(SAMPLES)
if len_samples == 1:
    len_samples = n_columns +1


fig, axes = plt.subplots(nrows=(len_samples + n_columns-1) // n_columns, ncols=n_columns, figsize=(n_columns*3.74, ((len_samples + n_columns -1) // n_columns)*4.5), sharey=True, sharex=False)

# Your existing loop for plotting...
for i, sample in enumerate(SAMPLES):
    row = i // n_columns
    col = i % n_columns
    ax = axes[row, col]
    print(round(((i+1) * 100 / len(SAMPLES)),1), "%", end='\r')
    percent_0=round((len(merged_df[merged_df[sample + "_raw"]==0])/len(merged_df)-len(merged_df[merged_df[sample + "_norm"]==0])/len(merged_df))*100,2)
    ax.plot([-2.5, max_val-0.5], [-2.5, max_val-0.5], 'r--')
    ax.scatter(x=merged_df[sample + "_raw"], y=merged_df[sample + "_norm"], s=2, alpha=0.3)

    ax.set_xlim(axis_limits)
    ax.set_ylim(axis_limits)
    ax.set_title(sample)
    ax.set_xlabel("RPKM raw")
    ax.set_ylabel("RPKM normalised")

    ax.text(0.95, 0.05, str(percent_0) + '%', transform=ax.transAxes, ha='right', va='bottom',fontsize=6, color="firebrick")

    
    # Set the same ticks for both axes
    ax.set_xticklabels(ax.get_xticks(), rotation=90)

    ax.set_xscale('log')
    ax.set_yscale('log')   
    
    ax.set_xticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])
    ax.set_yticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])
#     ax.set_yticks([10**i for i in range(int(np.log10(min_val)), int(np.log10(max_val))+1)])

 
    
if len(SAMPLES) % n_columns != 0:
    for i in range(len(SAMPLES) % n_columns, n_columns):
        fig.delaxes(axes[-1, i])
        
plt.tight_layout()
plt.show()
# Out:
# 5.6 %
# /tmp/ipykernel_224415/2698746834.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_224415/2698746834.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_224415/2698746834.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# /tmp/ipykernel_224415/2698746834.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=90)
# ...

# %% [markdown]
# ## Length and raw RPKM of removed

# %%
# Summarize lengths and RPKM values removed by filtering
len_df=df_RPKM_len[SAMPLES[0]].to_frame()
len_df.columns=["Length"]

merged_df = merged_df.sort_index()
len_df = len_df.sort_index()

len_samples=len(SAMPLES)
if len_samples == 1:
    len_samples = n_columns +1

fig, axes = plt.subplots(nrows=(len_samples+ 3) // 4, ncols=4, figsize=(16, ((len_samples + 3) // 4)*4.5),sharey=False,sharex=True)

n=0

for i, sample in enumerate(SAMPLES):
    row = i // 4
    col = i % 4
    ax = axes[row, col]
    zero_df_len=len_df[(merged_df[sample + "_raw"]>0) & (merged_df[sample + "_norm"]==0)]
    zero_df=merged_df[(merged_df[sample + "_raw"]>0) & (merged_df[sample + "_norm"]==0)]
    print(round(((i+1) * 100 / len(SAMPLES)),1), "%", end='\r')

    percent_0=round((len(merged_df[merged_df[sample + "_raw"]==0])/len(merged_df)-len(merged_df[merged_df[sample + "_norm"]==0])/len(merged_df))*100,2)
    bin_edges = [i * 1000 for i in range(0, 50)]
    ax.scatter( x=zero_df_len["Length"],y=zero_df[sample + "_raw"],)
    ax.set_title(sample)
    ax.set_xlabel("Contig length")
    ax.set_ylabel("RPKM")
    ax.text(0.95, 0.05, 'n=' + str(len(zero_df)) , transform=ax.transAxes, ha='right', va='bottom',fontsize=6, color="firebrick")

if len(SAMPLES) % 4 != 0:
    for i in range(len(SAMPLES) % 4, 4):
        fig.delaxes(axes[-1, i])
        
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Coverage and RPKM Filtering

# %%
# Export coverage- and RPKM-filtered tables
filtered_RPKM_raw_df,filtered_counts_raw_df=filter_abundances(df_RPKM_raw, df_count_raw, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_RPKM_norm_df,filtered_counts_norm_df=filter_abundances(df_RPKM_norm, df_count_norm, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_75_RPKM_raw_df=filter_abundances_75(df_RPKM_raw, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)
filtered_75_RPKM_norm_df=filter_abundances_75(df_RPKM_norm, df_RPKM_cov_bases, df_RPKM_cov, df_RPKM_len)

filtered_RPKM_raw_df.to_csv(out_filtered_raw_RPKM_file)
filtered_counts_raw_df.to_csv(out_filtered_raw_count_file)
filtered_RPKM_norm_df.to_csv(out_filtered_norm_RPKM_file)
filtered_counts_norm_df.to_csv(out_filtered_norm_count_file)
filtered_75_RPKM_raw_df.to_csv(out_filtered_75_raw_RPKM_file)
filtered_75_RPKM_norm_df.to_csv(out_filtered_75_norm_RPKM_file)
